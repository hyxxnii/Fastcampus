# %% [markdown]
# ### 1. 대화내용 불러오기

# %%
import pandas as pd
import numpy as np
import pickle
from pprint import pprint
import re

# %%
with open("data/cleaned_data.pk", "rb") as f:
    data = pickle.load(f)

data.reset_index(drop=True, inplace=True)
print(data.head())
print(data.info())
# Out:
#              Date User                Message
# 0  2018. 5. 3. 00  주현                엥 결국 안먹음
# 1  2018. 5. 3. 00  주현    너 그 야구부 엠티는 가는거야 그래서
# 2  2018. 5. 3. 00  현영                      안가
# 3  2018. 5. 3. 00  현영        근엄마한테갈거라고말해놓긴햇는디
# 4  2018. 5. 3. 00  현영                  보내준다허면
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22914 entries, 0 to 22913
# Data columns (total 3 columns):
# Date       22914 non-null object
# User       22912 non-null object
# Message    22914 non-null object
# dtypes: object(3)
# memory usage: 537.2+ KB
# None

# %% [markdown]
# ### 2. 초록 없는 데이터 제거  및 분석시기 설정하기

# %%
# 시간정보 열 datetime 정보로 변환
data['Date'] = pd.to_datetime(data['Date'])
# 인덱스 넣기
data = data.set_index('Date')
data.head()
# Out:
#            User                Message
# Date
# 2018-05-03  주현                엥 결국 안먹음
# 2018-05-03  주현    너 그 야구부 엠티는 가는거야 그래서
# 2018-05-03  현영                      안가
# 2018-05-03  현영        근엄마한테갈거라고말해놓긴햇는디
# 2018-05-03  현영                  보내준다허면

# %% [markdown]
# #### 연도별 대화내용 분리 (DTM 분석을 위해)

# %%
year2018 = data['2018-01-01' : '2018-12-31']
year2019 = data['2019-01-01' : '2019-12-31']
year2020 = data['2020-01-01' : '2020-12-31']

# %%
# 제대로 분리되었나 확인
print(year2018.head())
print(year2019.head())
print(year2020.head())
# Out:
#            User                Message
# Date
# 2018-05-03  주현                엥 결국 안먹음
# 2018-05-03  주현    너 그 야구부 엠티는 가는거야 그래서
# 2018-05-03  현영                      안가
# 2018-05-03  현영        근엄마한테갈거라고말해놓긴햇는디
# 2018-05-03  현영                  보내준다허면
#            User                Message
# Date
# 2019-01-01  지이    얘두라 따랑해 새해복 많이받아❤️☺️
# 2019-01-01  현영             사랑해 민나상 모두들
# 2019-01-01  현영                    오메데또
# 2019-01-01  현영               앗 언니자화상이다
# 2019-01-01  지이                     졸귀탱
#                     User        Message
# Date
# 2020-01-01 00:00:00  현영            고구마
# 2020-01-15 18:00:00  영현             늼들아
# 2020-01-15 18:00:00  영현    우리 설끝나고 모이자
# 2020-01-15 18:00:00  지의             그러자
# 2020-01-15 18:00:00  지의              제발

# %%
print(year2018.info())
print(year2019.info())
print(year2020.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5991 entries, 2018-05-03 00:00:00 to 2018-12-31 23:00:00
# Data columns (total 2 columns):
# User       5991 non-null object
# Message    5991 non-null object
# dtypes: object(2)
# memory usage: 140.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13858 entries, 2019-01-01 00:00:00 to 2019-12-31 23:00:00
# Data columns (total 2 columns):
# User       13856 non-null object
# Message    13858 non-null object
# dtypes: object(2)
# memory usage: 324.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3065 entries, 2020-01-01 00:00:00 to 2020-06-17 17:00:00
# Data columns (total 2 columns):
# User       3065 non-null object
# Message    3065 non-null object
# dtypes: object(2)
# memory usage: 71.8+ KB
# None

# %% [markdown]
# ##### 시기별로 나눠서 데이터 저장하기

# %%
# time_slice별로 데이터 갯수를 저장할 리스트 생성
time_slice = []


slice0 = list(year2018['Message'])
slice1 = list(year2019['Message'])
slice2 = list(year2020['Message'])

# LDA 분석할 때와 비슷하게 모든 분석 대상 텍스트를 담는 리스트 생성
tokenized_data = [msg.split() for msg in (slice0 + slice1 + slice2)]

# 각 slice에 들어 있는 갯수를 원소로 갖는 리스트 생성
time_slice.append(len(slice0))
time_slice.append(len(slice1))
time_slice.append(len(slice2))

# %%
print(len(tokenized_data))
print(time_slice)
print(slice0[:5])
print(slice1[:5])
print(slice2[:5])
pprint(tokenized_data[:5])
# Out:
# 22914
# [5991, 13858, 3065]
# [' 엥 결국 안먹음', ' 너 그 야구부 엠티는 가는거야 그래서', ' 안가', ' 근엄마한테갈거라고말해놓긴햇는디', ' 보내준다허면']
# [' 얘두라 따랑해 새해복 많이받아❤️☺️', ' 사랑해 민나상 모두들', ' 오메데또', ' 앗 언니자화상이다', ' 졸귀탱']
# [' 고구마 ', ' 늼들아', ' 우리 설끝나고 모이자 ', ' 그러자', ' 제발']
# [['엥', '결국', '안먹음'],
#  ['너', '그', '야구부', '엠티는', '가는거야', '그래서'],
#  ['안가'],
#  ['근엄마한테갈거라고말해놓긴햇는디'],
#  ['보내준다허면']]

# %% [markdown]
# ### 3. Dynamic Topic Model 돌리기

# %%
from gensim.models import ldaseqmodel
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary, bleicorpus
from gensim.matutils import hellinger
from gensim import corpora
from tqdm import tqdm_notebook
from time import time

import os

# %% [markdown]
# ##### dictionary와 doc2bow 만들기

# %%
# Create Dictionary
if not os.path.exists('kakao(DTM)_dict'):
    dictionary = corpora.Dictionary(tokenized_data)
    #dictionary.filter_extremes(no_below=5, no_above=500)  # 이 줄의 코드는 n회 미만 또는 n회 이상을 지울 때 사용
    dictionary.save('kakao(DTM)_dict')
    print(dictionary)
else:
    dictionary = Dictionary.load('kakao(DTM)_dict')

# Term Document Frequency (convert tokenized documents into a Document-Term Matrix)    
if not os.path.exists('kakao(DTM)_corpus'):
    corpus = [dictionary.doc2bow(doc) for doc in tokenized_data]
    corpora.BleiCorpus.serialize('kakao(DTM)_corpus', corpus)
else:
    corpus = bleicorpus.BleiCorpus('kakao(DTM)_corpus')

# %%
# dictionary함수로 만든 사전에 있는 단어들 모두 볼 수 있는 기능
print(dictionary)
for idx in dictionary:
    print(dictionary[idx])
# Out:
# Dictionary(24575 unique tokens: ['결국', '안먹음', '엥', '가는거야', '그']...)
# 결국
# 안먹음
# 엥
# 가는거야
# 그
# 그래서
# 너
# 야구부
# 엠티는
# 안가
# 근엄마한테갈거라고말해놓긴햇는디
# 보내준다허면
# 개이득
# 파리타임
# 마커롱
# 먹고싶따
# 마카롱임
# 바보야
# 야웃김
# 고딩때보내줫는데
# 내
# 내친구가
# 리얼
# 얼굴이
# 프라이팬
# 아개웃곀
# 그린줄
# 동그라미임
# 컴퍼스로
# 뭐지
# 반응은
# 고딩때야
# 개똑같아
# 지금이랑
# 귀엽지
# 얘그라
# 이거어때
# 똑같다니
# 야
# 귀여오
# 시부랭
# 이주희
# 작가임
# 에바참치쌈싸서
# 저얼굴이면
# 지금도
# 한입에털어넣야됨
# 털어넣으셈
# 근데
# 똑같음
# 참치쌈싸서
# 털어놓어야함
# 똑같다고
# 레알
# 개충격
# 시방
# 컴퍼스
# 잠깐만
# 레알똑같넼
# 시부랰
# 진현영대잔치
# 아닠
# 다른점
# 떡지고
# 안떡진고
# 앞머리가
# 개좋앜
# 앜
# 미틴
# 존나
# 행복하다
# 깜찍
# 왴
# 개욱겨
# 아근데
# 널
# 좋아해버렷
# 똑같이
# 생겼는데
# 똑같으면
# 쌈싸목는다
# 에바
# 쓸거얌
# 으로
# 저거
# 진짜
# 레알똑같을줄은
# 아니
# 자가
# 겟아웃오브히얼
# 이거
# 잘못하더거
# 단톡에
# 데사
# 보낼뻔
# 보내지
# 아
# 죽을뻔
# 죽일뻔
# 보내면
# 진현영
# 자퇴할까봐
# 휴학신청서
# 끄적
# 야주희
# 몰겠눙데
# 물어봐도되나
# 이런거
# 걍
# 물오봄
# 사귀제
# 정우철이랑
# 헐
# 눈치로
# 다아네
# 뭐야
# 나만눈치가
# 준내없엇군
# 언제부터야
# 준내
# 2주됫데
# 왜비밀로함
# 나도며칠전에앎
# 몰라이제
# 거의
# 공개임
# 애들다알어
# 나만몰랐쓤
# 나도몰랏음
# 야넌근데
# 17에도
# 몇명은
# 안댕
# 안다
# 난
# 말안해줙음
# 이걸
# 평생
# 이제물어본다고
# 썸인줄
# 젤늦게암
# 그리고
# 대답
# 내가할랬는데
# 니가말해
# 왜
# 언니그때
# 나
# 이언니
# 주현
# 화욜날
# 쉬는시간에
# 씨
# 웅웅
# 편의점에서
# 고백언헌더고
# 정우철한데
# 냐가
# 지랄할때
# 씨쉬는시간을쉬싸는시간으로봄
# 다웃었잖아
# 옆에
# 맞아
# 그때
# 말안해주고
# 배창현이
# 그썰들었다
# 지의야
# 너무허다
# 눈짓으로
# 개웃기네
# 보는맛에
# 조용히
# 하라고
# 함
# 비밀로
# 사겼지
# 개사악해
# 미친
# 소리나
# 다웃는거
# 그때는
# 몰랐는데
# 긱사와소
# 생각하니까
# 뭔가
# 이상하길랴
# 웃곀
# 정우철카톡상메보니까
# 되있길래
# 생일축하해
# 사귀는가
# 이랬씀
# 그것도
# 그럴수잇지
# 보면서
# 좋아하니까
# 이럼
# 드라마썼구나
# 헌자
# 스뱔
# 1도없어
# 진짜눈치
# 도토리묵임
# 현영이가
# 눈치은근잇는디스방
# 알았어야돼
# 젤마지막에
# 도토리묵
# 잠만
# 뭐옄
# 내가
# 너무
# 빨리말해줬다
# 말안해줘
# 개답답
# 당최
# 무슨비유냐
# 딱이야
# 윤지의
# 되게
# 관심이
# 많아보이길래
# 관심가지나
# 언제까지
# 궁금해소
# 방금
# 담푸허다가
# 만났는데
# 박도형
# 이제알았다니까
# 알았네
# 이제
# 담푸가
# 뭐여
# 아냐고
# 어떻게
# 담푸는
# 또
# 담배푸기
# 담배
# 퓌우기
# 푸기는
# 담푸라닠
# 피기도아니고
# 담피라하지않나
# 원래
# 기
# 담푸
# 이거임
# 푸
# 아니면
# 고
# 담타
# 나내일
# 개적절
# 짤
# 생리공결쓸래
# 오
# 엑스
# 부럽다
# 일찍일어나기
# 쥰내귀찮아
# 와
# 왤케마니쎀
# 시부랑
# 차라리
# 나는
# 써버려서
# 이미
# 저번주에
# 담주
# 불가능
# 뭐래
# 엠티때
# 한번씀
# 화욜날쓰지
# 그럼
# 담주화욜
# 금토일월화수
# 놀수있씀
# 언냐는
# 쩔수없이
# 흠
# 금토일월화숰
# 지림
# 화요일은
# 실습있응게
# 그냥
# 오늘쓸래
# 실습을
# 챙긴다고
# 문쓰발도
# 하야되서
# 나어차피
# 잠
# 화요일축제아님
# 첫번째
# 씨씨가
# 두번째
# 씨씨
# 있을꺼같으면
# 말쫌
# 미리
# 제발
# 나만
# 늦게암
# 맨날
# 두번째씨씨
# 진현영이항
# 민준
# 은비
# 각
# 탱
# 임그거
# 민준이오빠
# 각이야
# 아님
# 은비는
# 에이
# 지랄
# 레알임
# 설마
# 민준오빠가
# 러브
# 은비를
# 둘이
# 단둘이
# 술도먹고
# 밥도먹고
# 씨할때보니깐
# 민주니오빠가
# 활짝웃느면서
# 톡하길래
# 술밥
# 봣는데
# 얼핏봣을때
# 프사음비
# 활짝웃는다
# 그걸
# 니
# 훔쳐봄
# 민쥰상
# 왠만하면
# 범죄아님
# 씨할때
# 안웃는데
# 화알짝
# 가만냅도
# 뭘깡
# 대체
# 언제
# 연애할꼬여
# 현영이는
# 차가운
# 쥰상을
# 드라마쓴다또
# 진혀녕
# 혼자
# 그놈에
# 자연스러운만넘
# 웃게한
# 그녀는
# 누굴깡
# 아진짜
# 웃겨
# 니는
# 연애부터
# 해야되
# 염탐
# 쥰상
# 20년울
# 어떠케
# 모쏠이지
# 그정도면
# 윤지읰
# 수녀아님
# 모솔이
# 어때서요
# 욕을해
# 수녀
# 발락
# 수녀가
# 될거임
# 모쏠탈출프로젝트
# 해줘야험
# 곧
# 마법사되는거
# 센빠이
# 주형이
# 도와줘
# 주형센빠이는
# 얘들아
# 넘사벽임
# 쌉
# 넘사
# 도도
# 야들아
# 높이가달라
# 샙
# 샵
# 조교님
# 왜나옴
# 못만날것같어
# 샵도돜
# 언냐
# 언니
# 다아는거임
# 아래까지만해도
# 어제
# 귓속말로
# 영현이한테
# 했는데
# 모른다고
# 아무도
# 입닫으랬는데
# 벌써
# 말함
# 술자리에서
# 크게
# 다언덕
# 현영이
# 미팅하는거
# 소웨랑
# 거기서
# 잡아와야해
# 한명
# 미팅함
# 나도
# 미팅할래
# 과팅
# 소우
# 소웨
# 남친은
# 과팅할래
# 나고
# 분위기만띄워주고
# 쓸쓸히
# 퇴장각
# 남친말고
# 야너는
# 갈꺼임
# 뻘러
# 술존너
# 나단이나
# 어케해봐
# 다시안만나니
# 나단이
# 알면
# 버려
# 헤어짐
# 앵
# 감옥갔다왔나
# 어디
# 제일
# 엥또리
# 서로
# 감옥
# 언젠데
# 헤어진지가
# 긘까
# 모르냐
# 우리
# 이건진짜
# 시방감옥
# 사귄지가
# 비밀도
# 아니었는데
# 모르지
# 그니깐
# 말안했자너
# 2주
# 되지
# 않았나
# 지의도
# 몰랏는데
# 세상물정을
# 에쎄꽁인데
# 넘었쓸껄
# 이주
# 에쎄꽁
# 개쩐당
# 나갈랭
# 미팅
# 간편
# 미팅쫌
# 접아조
# 날짜
# 언제잡아
# 놀다오게
# 남았니
# 자리
# 낼
# 내말이
# 안돼
# 자리없어
# 갈꼬임
# 미띤
# 물어보면
# 영주언니한테
# 직빵임
# 윤지의몰래
# 갈거임
# 안친해
# 야야야야
# 않아
# 친하진
# 술
# 나이제
# 코다나아서
# 미띤넘
# 되겄지
# 먹어도
# 의사가안됀데
# 안되징
# 안된다면
# 너빼고
# 응
# 그리구
# 난낼
# 약속있다
# 누구랑
# 철’s랑
# 내일
# 면접가야되내
# 알바
# 철수
# 철숰
# 철수는
# 누구옄
# 철이와주희
# 철쭈
# 하앜
# 모해
# 문쓰발하고
# 과외감
# 쓰발
# 과외쓰발
# 놀자
# 제발류
# 내일과외잇음여
# 밤에
# 술목저
# 닌
# 술못먹잖아
# 어자피
# 아맞다
# 가
# 영현이랑
# 주햔언냐
# 오늘
# 웅
# 변씨랑
# 술먹은거
# 어땟음
# 개웃김
# 변씨
# 그조교이름
# 변씨임
# 변준영선배라고
# 잇음
# 웃긴선배
# 조교는
# 반영준이랑
# 잊어
# 변준영이랑
# 반영준
# 구분못함
# 실화냐
# 변준영
# 미친것같어
# 변준영이
# 왜구분안돼
# 니들이
# 엠티갔다와소
# 하도
# 거리길랴
# 에이이잉
# 구분언됨
# 반영줔
# 그거
# 다
# 변준영이야
# 아존니욱곀
# 얘기함적도
# 없다
# 사고회로
# 정지
# 1도안함
# 얘기
# 도랏나
# 이름
# 비슷함
# 왜이래
# 반영준그아이는
# 왜말하는걸까
# 자꾸
# 그정도는
# 아니거든
# 얘기하는거는
# 변씨라고
# 생각해
# 기웃깈
# 하
# 먹자
# 술쩜
# 내일은
# 20살
# 우리가
# 해야될일은
# 마자
# 참으렴
# 밖에
# 술먹는거
# 없어
# 박도령씨랑
# 먹어
# 본업에
# 우리의
# 충실하자
# 아닠오타
# 존웃
# 박도형이
# 있었네
# 박도령
# 괜찮다
# 먹으러고
# 박도령이라고
# 부르자
# 뭐가괜차낰
# 정말재밌겠따
# 글고
# 양씨
# 1도
# 안채해서
# 올듯
# 정영현씨
# 긱사애들이랑
# 모여서먹어
# 기숙사
# 만들어
# 팸
# 음
# 나혼자
# 먹으란말이랑
# 긱사팸
# 존내부럽
# 술먹음서
# 친해져부러
# 심심함
# 흥
# 기회
# 흔치않아
# 긱사팸좋다
# 그치
# 서울에
# 없으니까
# 칭구
# 노잼임
# 왱
# 존잼인디
# 나두끼구파
# 나두
# 서개쫌
# 술잘마시는
# 노린다
# 다음
# 학기를
# 가지게
# 술친구로
# 잘마셔
# 주형쎈빠이
# 그이는
# 그분이랑
# 갑자기
# 이렇게
# 먹다가는
# 건드리지마
# 그이를
# 뷰른다구
# 있씀
# 체할슈도
# 만듬
# 불편하게
# 사람을
# 저
# 뭐야갑자기
# 임티자랑
# 아종나
# 아니주현
# 개약오른다
# 인절미
# 임티
# 완전
# 인절미아니야
# 자기자신임
# 햄토리야
# 나라니
# 머줌
# 인절미임
# 누가봐도
# 햄스터야
# 쩔쩔이야
# 언니임
# 얘두라
# 기엽찌
# 비숑
# 키우고파
# 정우철이
# 존나많이쓰는거임
# 아싸발
# 안어울려
# 때려야겠다
# 왜욕하는뎈
# 바로
# 욕나오눈거봐
# 겨워💕
# 겹따
# 강아지
# 더사고싶따
# 한마리
# 뭐야저마시멜로는
# 말티푸개기여움
# 말티즌데요
# 병신아
# 말티즈랑
# 푸들썪은거
# 말티푸라하거든
# 아까부터
# 쩝
# 모를꺼같나
# 이것도
# 오타났는데
# 5인줄알아
# 초
# 초5
# 마카롱이란당
# 액희야마커롱아니구
# 말티푸
# 미쳤음
# 졸귀임
# 미쳤네
# 개깜찍
# 갈색강아지가
# 예쁜듯
# 많으니까
# 모르는사람
# 아직도
# 티내지마라
# 누구있씀
# 염기웅씨
# 나열
# 개뜬금
# 박정욱씨
# 다알지
# 빼곤
# 안음
# 에바야
# 많아
# 말은
# 알라그랭
# 하지말구
# 이샛기
# 염기웅앀
# 염염염염염
# 묘하게
# 중독되는
# 언제자게
# 더
# 일어나야되자나
# 일찍
# 통학이면
# 공결할래유
# 난아직도
# 폰중
# 냠냠
# 공결
# 눈뜸
# 지금
# 나도공결쓸래
# c도
# 공결내게
# 너네
# 파이썬이랑
# 아오늘
# 파이썬있구나
# 공결이지
# 뭐
# c
# 는
# 당연히
# 씨도
# 나더
# 일어남
# 씨끝날때쯤
# 학교갈거
# 지이언니도
# 공결낼거야
# 파이썬도
# 아니면메닐만보내
# 파이썬은
# 듣자
# 주섬주섬
# 준비하자
# 공결애아깝
# 공결내면
# 하루종일
# 다빠질수
# 있는거
# 웅다빠지기가능
# 이주히
# c끗낳때
# 왜와
# 학겨
# 문쓰발해야되긴함
# 문쓰발이요
# 현영그럼
# 파이썬우짤꺼
# 습
# 기말
# 조질라햇는디
# 언니는
# 파이썬들을
# 정도는
# 하루수업
# 이유가
# 잇자나
# 독학으로
# 커버가능
# 엑슼
# 독학
# 없음
# 의지
# 또가면
# 수업때
# 저번
# 냉고
# 숙제
# 안해왔다고
# 지랄비랄하겔지
# 안갈래
# 숙제있어
# 검사맡고가라한거
# 저번에
# 안가야지
# 옹
# 다들
# 빠지는군
# 아예통째로
# 흠냐리
# 좀
# 죄책감이드는디
# 너네가
# 근데공결신청서
# 언제까지내는겨
# 10일
# 오늘부터
# 이내
# 같이사는언니
# 알람겁나울려서
# 못자겠음
# 언니가
# 꺼줘
# 갈래
# 씨는안가곸
# 그건뭐야
# 우리과톡에
# 잘못보냄
# 공결썻는데
# 금같은
# 다오지마
# 그닠가
# 개아까워
# 결석한번으로할까
# 미적
# 공결쓰지말고
# c는가게
# 고민되는데
# 씨는
# 가지말자
# 다가지말쟈
# 날씨
# 미친거같음
# 우박떨어짐
# 천둥번개
# 개무서워
# 대박
# 무서워
# 아아아아
# 무서워아아
# 신났지
# 차지이
# 꼭
# 나갈거면
# 들구나가
# 우산
# 개아파
# 우박
# 언우박맞아썽
# 나갔는데
# 비오늘
# 알구
# 없어서
# 줄
# 아팠어
# 개웃겨
# 주워왔는데
# 우박녹았어
# 개신기해
# 신났냐고
# 지이언니
# 천둥친다
# 천둥미쳤다
# 배고픈가봄
# 아미쳤냐고진짜
# 여기서
# 우오
# 안둘림
# 천둥소리
# 집에서
# 곳이야
# 신기한
# 우리집은
# 정말
# 뭔뎈
# 갇혀사는거아니지
# 단절되있어
# 세상과
# 언니집이
# 위험해
# 여기
# 잠자는데
# 최적화된
# 모르겠다
# 핵날라와도
# 미쳤어
# 핵
# 우박뭐얔
# 랰헥
# 도랏나진짴
# 나중에
# 어케낙냐고오오
# 천둥좀안치게해봐
# 우박보다
# c교수님이
# 더무서움
# 존내오늘
# 애들왜이러케
# 안왓냐고
# 지롤하는거아님
# 정신이잇는거냐없는거냐
# 무서웡
# c듣는중
# 머야
# 중이었는데
# 포켓몬고
# 와이파이개안잦혀
# c수업
# 갓음
# 문쓰발땸시
# 학교오는길에
# 아뭐야혼자출석하구
# 배신자엑스
# 어차피
# 저기
# 죄송합니다
# 언니도
# 문쓰발혀
# 내일발표야슈발
# 대본도없는데
# 패고싶다
# zzzzz우리도지금
# 백지상태임
# 오늘시작
# 우리도
# 지금시작
# 몰빵에서
# 문쓰발
# 센이랑
# 하러공
# 백지
# 같이
# 나방금
# 들었느데
# 사는
# 언니한테
# 무시하고
# 술팔지말라는
# 인하대에서
# 했다가
# 3000만원인가
# 5년이랑
# 막
# 먹었대
# 벌금
# 인하대
# 징역
# 회장
# 다른대학교들도
# 미쳐따
# 아예
# 안한대
# 주점
# 홀
# 미친거아냐
# 술을
# 안팔다니
# 너네어떠조싶음
# 안하고싶은데난
# 난쉽게결정못하게써
# 장사안될거같음
# 저러면
# 열정페이야
# 적자에바야
# 그건맞아또
# 된다고
# 먹는건
# 사와서
# 하지만
# 내년에
# 할수도있고
# 굳이
# 앗
# 잠시
# 물리
# 출튀
# 할꺼얌
# 선수치기냐
# 고민중
# 물리출튀하고주현
# 언니집가고싶다
# 누워있씀
# 아직
# 걍나거소
# 다시
# 들와소
# 이상태로
# 잘꼬임
# 출석하고
# 멋지다
# 아나지금지하철탐
# 늦을까
# 니가
# 알잖어
# 얼마나걸림
# 아나11시에
# 지하철에서내릴거같은디
# 샹
# 지하철
# 군자임
# 쉬부랭
# 쉬팽
# 준내뛰어가서
# 출튀해야겟다
# 오분까지하묜됨
# 출석부른대
# 에반데
# 20분까지
# 들어와
# 진심
# 오바야
# 진짜야
# 봐주면
# 들엉면
# 교수님이
# 글케말했어
# 봐준데
# 띠로리
# 아니냐
# 찍히는거
# 니깐
# 들어가는거잖아
# 얼굴
# 찍히고
# 1번인데
# 결석
# 1번은
# 괜찮지않을까
# 출석불렀씀
# 20분에
# 부른대
# 씨발
# 같네
# 짐다시가는겔
# 1번
# 상관없지않냐
# 짐출석부름
# 왔는데
# 출석안부름
# 뭐임
# 걍헌말인가
# 마칠때하는가
# 짐부름
# 후
# 출튀함
# 옹옹
# 다들오댱
# 쓰는사람없지
# 아이폰6
# 요기
# 케이스
# 진자
# 폰바꿨거든
# 3개나
# 주문시켰따고
# 나한테
# 말해조
# 살
# 의향있으면
# 혹시
# 어떤건뎅
# 많아져서
# 구래
# 보여주께
# 근데취소해도
# 되지않아
# 도착
# 해외배송이라
# 너무바빠쪄
# 봤당
# 앉아서
# 자리에
# 개이뻐
# 채도
# 첫번째꺼
# 6쓰는애들한테도
# 물어봥
# 일단
# 헤
# 모야
# 바꿨는데
# 자랑안하는건
# 폰뭘로바꿈
# 오오오옹
# 바꿨더
# 아이폰x로
# 155만원
# 개쩌러
# 155
# 개쩜
# 마쟠
# 성공했어
# 성공
# 와앙
# 수업
# 안듣는애없어
# 앉아있어
# 언니빼고
# 못들어가
# 이꼬라지로
# 뛰유왔더라
# 목에끼우고
# 시밤
# 현타오어
# 같애
# 개쪽팔릴
# 것
# 안니
# 안들어오겡
# 어디야
# 수업중인데
# 들을
# 필요없는득
# 밥먹고있었어
# 어때어때
# 과팅어때
# 핫하냐
# 재밌냐
# 개
# 꼴아서
# 보내야돼
# 집
# 누구
# 합류함
# 김유현
# 보냈어
# 진현영도개
# 빠꾸없쥬
# 어댜
# 나집이야
# 많이마신거야
# 얼마나
# 누웠써
# 씻고
# 집도착해서
# 잘해써
# 괜찮겠지
# 안갈레
# 한번하는거
# 비에바쎄바
# 안가고싶다
# 많이
# 비
# 들은것같기도하고
# 새벽에
# 지금은
# 콧물정도밖에안옴
# 근데즈금은
# 많이옴
# 엇
# 난공걀
# 씁니다
# 개꿀
# 안오는거
# 나만옴
# 1분전에
# 도착함
# 존나뛰어
# 은비릉
# 잘했어👍
# 일님
# 파이썬도안오냥
# 지각해서
# 눈치보여
# 관성모멘트
# 어케
# 표
# 해
# 배끼면된댕
# 인터넷검색해서
# 아씨
# 감
# 나갈사람
# 선착한명
# 나감
# 나랑
# 언니랑
# 나가장❤️
# 선착끝남
# 누구랑가냥
# 미팅킬러야
# 누구만났다명
# 미팅에서
# 전에
# 공부했다는소문을
# 도서관에서
# 들었징
# 맞앝
# 미팅킬러랰
# 수업해
# 물리실험
# 하자너
# 끝나고
# 목요일
# 술먹는거당
# 학생회
# 회의
# 꾸역꾸역
# 무려
# 알바끝나고
# 양주영
# 여권들고
# 온다니까
# 언제정함
# 잉
# 빠꾸치는
# 알게
# 흑우없는덜로
# 인증시험
# 미적다끝났는데
# 당연한거아니냐고
# 그럼나출입되는곳으루다가
# 민증구해와
# 귀차늠
# 기냥안갈래
# 앙대
# 학정원인사람
# 건대
# 벎서
# 건대병원땜에
# 건대야
# 밍
# 병원감
# 슈발
# 자고싶다
# 공강에잡고
# 시부레
# 시험을
# 지롤이람
# 슈팜
# 그래도
# 씨수업
# 없는거
# 남아야되눈거
# 회의때매
# 개빳침
# 아앀
# 극혐
# 엘티안가
# 못가
# 주말알바라
# 그렇네
# 시댕
# 알바잡을라했는데
# 주말로
# 알바잡고
# 엘티가지마
# 별로없어서
# 이득본거
# 주점으로
# 가는거
# 아냐
# 우리돈으로
# 돈없닥
# 그럴깡
# 엘티갈돈으로
# 가고말래
# 다른여행을
# 엥레알
# 고거인덩
# 정
# 야우리
# 이득40마넌바께없데
# 40마넌
# 긍얘기함
# 숙소잡으면끝이네
# 그걸로
# 떡꼬치하나씩
# 사먹으면
# 끗날듯염
# 슬리퍼신고가면
# 욕할고임
# 치마에
# 안하는데
# 욕은
# 눈으로
# 이상한
# 쳐다볼게
# 가자
# 여행이나
# 우리끼리
# 근데이미
# 내자신
# 익숙해진
# 돈벌고
# 물론
# 빕스
# 하기로한거임
# 갈수있먀
# 안제쯤
# 거의확정이얌
# 노는거도
# 마지막이댱
# 이번주가
# 할
# 그럼에번주
# 존나너라
# 허어어겅
# 알바얼른구해야지
# 빨리와
# 김여면
# 김영현
# 어디얌
# 학관1층카페이
# 두개인사람
# 이어폰
# 하나만
# 빌랴주
# 갈려공
# 하납니다
# erai
# 두개임
# 1
# 빌려줄게
# 왓더
# in
# life
# my
# 땡큐
# 한
# 3시쯤갈듯
# 갈궹
# 만나서
# 세은이랑
# 그러려무나
# 몰빵왔슈
# 얌나
# 오다가
# 전민규만나서
# 이어폰은
# 간다
# 몰빵
# 스읍
# 아니다
# 안쓸래
# 딱히
# 안쓸랰
# 피료없어서
# 1차
# 것이
# 꼴찌
# 대단합니다
# 면했다는
# 생각해보면
# 인증때
# 점수를
# 못했다고
# 생각했나보다
# 어지간히
# 그런가봐
# 계절학기도
# 면할수있을까
# 계절학기만
# 소원이
# 안하면
# 없게따
# 암사동가면
# 이거사주냐
# 현영아
# 꺄
# 개유명함
# 개뚱뚱하고연
# 마카롱
# 세로로
# 존맛탱
# 안먹어봄
# 한번도
# 먹고싶다
# 근처던뎈
# 우리집
# 개맛있을거같아
# 그치하앍
# 부자되면
# 하나씩
# 돌릴께
# 사와줘
# 시팡
# 과외쌤이믄서
# 돈벌면
# 사죠잉
# 대리구매라도
# 마저
# 고램
# 10가능이구연
# 대리구매는
# 두둑히
# 심부름값
# 쳐야됨
# 띠용
# 언제야
# 미팅인뎁쇼
# 담주토요일
# 다음주
# 아니었어
# 이번주
# 다음주라했으니까
# 이번주인거지
# 저번주
# 토요일에
# ♥️
# ❣️❣️❣️
# 감동이여써
# 고마워어
# 고마웠어
# 고맙고
# 고맙구
# 너무고마워써
# 덕분에
# 돈도
# 못보겠디많
# 바쁘고
# 부끄러워써
# 뻔히
# 사랑행
# 생각해줘서
# 생파안하냐고
# 술먹어준주희랑
# 아는데
# 안아주고싶었는뎅
# 얘두람
# 어무너무
# 요새
# 이랑영현이랑현영이도
# 이쁜편지써준주현
# 잘자
# 정맣
# 즐거워
# 지나진짜
# 질리겠디만
# 쪼달리는거
# 챙겨줘서
# 최고입니당
# 폰없러
# 학교다니는게
# 한명씩
# 해야하지않냐고
# 희희
# 💕💕💕
# 😘😘
# 3
# 생일추카해
# 옷예쁘게봫
# 귀욤땅
# 룰룰라라
# 소감문
# 쓰니까
# 이롷게
# 고맙당
# 생일
# 쓰구
# 이거까지
# 정성스럽게
# 축하해😍
# 이태원죠앙
# 강주현오쟈
# 클럽
# 겁나이쁘뮤
# 술집도
# 웅웅👍
# 과팅중
# 오때
# 누구누구갔유
# 지의주현
# 현영
# 연락되나
# 페메하던디
# 앜페케
# 페메
# 연락안되는데
# 지의만옴
# 뭐얔
# 3대2임
# 나름
# 재밌다
# 너래
# 부름
# 비투비
# 노래방감
# 웅웈
# 월요일에
# 과애들불러서
# 어케생각해
# 한강가는거
# 구랩
# 이야데사소풍이당
# 있는
# 지이언니집에
# 대여가능
# 돗자리
# 오개좋아
# 예에
# 낼도가는데
# 얄루
# 이틀연속간다
# 오올
# 재밌겠다
# 부탁인데
# 꼭보셈
# 독전
# 영화
# 아아
# 온국민한테
# 존잼
# 홍보하고싶을지경
# 아까
# 윤지의도
# 쟈밌다하던데
# 재밌나보네
# 무조건
# 봐
# 더볼려고
# 안보면
# 한번
# 보러갈게👌
# 노라
# 친구랑
# 아마따
# 이태원
# 흔들어제껴
# 어때써
# 다이뻐써
# 이쁨
# 진짜이뽀
# 가기로해땅
# 꺄아아아
# 마쇼야지
# 저녁에
# 칵테일
# 부롭다
# 개존예인데
# 지이
# 프사
# 부뉘기
# 인져엉
# 시간보두
# 구
# 쪼앙
# 나도볼까
# 보자
# 내공포량홰못보는걀
# 불참
# 종퐁
# 참여
# 물어봐줄수있낭
# 종강총회
# 뒷풀이까지
# 다간대
# 감사힝
# 어디감
# 출튀했냐
# 김영현이름불렀던데
# 15일
# 낼수있어
# 뒤에
# 낼수있움
# 지나면
# 어디나와있어
# 공결신청하는
# 페이지에
# 고마웡
# 아항
# 너네는
# 마피아인항거얌
# 게임중
# 게임으로는
# 안해봐썽
# 도륵
# 재미떠
# 안할려
# 이주희하자
# 레벨업해야되는데
# 마지막은
# 너하면
# 도형이가
# 이거한데
# 일어나서
# 수업마치겠다
# 애들까는즁
# 여덟명다참
# 영현주희오면
# 이러다
# 각인디용
# 깔았는데
# 마칠
# 안깔려
# 절대
# 뭐함
# 마치고
# 약속이쓰
# 물리시험어떠케
# 15이상이라고
# 레벨
# 안들어가짐
# 초보채널
# 밥안먹지
# 밥머근지
# 세시간됐어
# 딴애들은
# 금요일까지네
# 안먹엉
# 저녁
# 6월1일까지
# 미쳤다니까
# 좆같네
# 할꺼개많아
# 개많다고
# 물리말고
# 뭐있어
# 6월5일까지임
# 최종이
# 에바네
# 개많음
# 대구가서
# 주말에
# 할꺼가
# 노는거아님
# 그니까
# 놀아야되서
# 많다고
# 춡석했
# 출튀했어
# 오홍
# 닭갈비드실분
# 점심
# 얌마들아
# 문쓰발과제
# 개인
# 내일밤까지임
# 내일밤12시까지
# 낼세시
# 3식까지
# 개미텼네
# 죽어도끗내야되네
# 불나게
# 해야됨
# 밤샘각탱방귀
# 웅으
# 밤새자
# 밤샘팟
# 모집
# 아마도
# 문쓰발따위때문에
# 밤을
# 새야한다니
# 옥희메랏
# 밤샐래
# 저도그럴라햇는뎁쇼
# 영현이
# 학교왜안왔냐
# 잤데유
# 늦잠이랭
# F만
# 되지뭘
# 린정
# 가는즁
# 얼렁와
# 러블리
# 아이스크림이네
# 턱레알
# 쉬팡
# 주인
# 저요
# 에인절
# 키스
# dream
# 어케이
# 까묵엇다
# 주인찾으려고
# 찍어놨는데
# 버릴뻔
# 주인없데서
# 개마니찍어놧넼
# 노래동영상있쑴
# 공유
# 노래는
# 맨날들어서
# 실물로
# 노래동영상이유
# 제
# 볼사람
# 공유해
# 참고로
# 개빠겜
# 보고
# 부르는거
# 옆에서
# 주형이오빠가
# 자다들
# 닌텐도위로
# 춤춘거보여드릴게요
# 친구집에서
# 동영상
# 발령
# 약간
# 엉덩이
# 주의보
# 치명적이야
# 후훗
# 엉쓱
# 것좀
# 그만해
# 노래부르는거보고싶어
# 주형쎈빠이가비웃은거에바참치링임
# 개쪽탱
# 후비적
# 보내도되
# 뭘
# 구램
# 궁뎅이잘흔드네
# 여따올려
# 나지금
# 김비서
# 1롸보는중
# 개꿀잼
# 박서준존잘탱
# 물리시간에
# 뭐하냐
# 뒤에서
# 엎드려자는척하면서
# 김비서봐야되나
# 잘꺼임
# 부산행나옴
# 티비에
# 못자게써
# 찌밤
# 나진짜
# 살려줘
# 룸메언니있잖아
# 우리낼
# 종강임
# 안가두되
# 가야하지않아
# 내일까지
# 다른반이라
# 모루게쑴
# 우린
# c언어
# 몽미헤헷
# 셤범위
# 배열부터
# 배운데까징
# 그냥배열
# 다차원
# 다차원아니야
# 그치다차원배열이랑
# 구거나
# 구거낭
# 배열
# 배열은
# 포인터
# 끗
# 공부하나
# 땡kiu
# 컴학원
# 파이썬
# 파이팅
# 끝내고
# 빨리
# 케이무크
# 씨공부하고싶다😭
# 왓
# 잇츠
# 케이묵
# 두개다
# 드뢉더빝
# 과제
# 안많아
# 미적부터
# 어우
# 할래
# 미적이
# 더극혐띠
# 투표했엉
# 오오오옹우와어디서해써
# 군자동주민센터
# 우와
# 바로앞에
# 화양동주민센터에서도
# 갔어
# 그까지
# 하지않나
# 군자동이더가까워서
# 지굼
# 학교라
# 가까워
# 우리집쪽이랑은
# 화양동이
# 대신받아줄수있는분
# 택배
# 영현이야
# 택배대신받을사람
# 나오면
# 카톡해밥먹쟝
# 나랑윤지의랑기다림에지쳐먼저먹는중
# 앝뭐먹냥
# 제육보끔
# 후문
# 제육볶음
# 강주현
# 안나와
# 미르띤
# 어늘
# 없제
# 특별한거
# 되제
# 출튀해도
# 출석
# 불럿엇데
# 공부하디싫다아아아아아아
# 모해얘주라
# 아아아아아아아아아아아
# 현영이는페북중
# 답장개빠르다
# 아니구나
# 어
# 찡긋
# 두시간반밖에
# 안지났네
# 밖에라니
# 밥안먹엉
# 집갔다올게
# 미적강의실로오삼
# 님들
# 노트북으로
# 볼수
# 생방
# 이씀
# 폰이나
# 그럴껄유
# 공중파
# 홈페이지
# 오옹
# 고마오
# 어플로보는즁
# 하시
# 헷헷
# 뭔생방
# 하트시구널
# 비의야
# 동노가자는데
# 박도형이랑
# 안갈거지
# 정영현이
# 고민즁
# 가고싶다
# 코노
# 글서
# 밤샘할
# 팟원구한다
# 쩌여
# 샵검색
# 보러갈
# 종강하고
# 정우철이요
# 쉬러시러
# 샹칼
# 😝
# 캡쳐
# 웅이미보여쥬써
# 머옄
# 제목이짜증난다
# 근데나연극죠아행
# 구할거야
# 다른친구
# 아니넌저런걸
# 남친이랑
# 봐야짘
# 몇일이야
# 언제얌
# 6월안에만
# 보면될걸
# 알바하니까
# 금욜가능
# 목욜이나
# 야너알바잘하고잇냐
# 싸네
# 나오늘도오지게실수많이해서
# 우울한현양
# 또엎고
# 방울토마토
# 파스타소스
# 흘리고
# 사람들이랑
# 존나부딪힘
# 공짜표있어서
# 보러가자는거
# 띱
# 공짜면
# 무조그언
# 와공짜에
# 넣어죠
# 후보에
# 머쓱타드
# 옥히
# 나중에대결해서
# 주인공을뽑자구
# 점수임
# 어떡해
# 내점수지못미
# 난줄
# 눈에
# 다래끼
# 삼립종이래
# 알았는데
# 아긴맣맠
# 거소가모
# 모래는고여
# 너눈
# 손꾸락이
# 아프니
# 대단
# 물리점수
# 확인하러간것도
# 공부하러
# 오는김엧
# 헐주현
# 가려궄
# 고름만
# 떼구
# 뺀거라
# 한시간있다
# 창토라오세염
# 삼립종이뭐여
# 산립종이랰
# 잘못알아써
# 깜짝놀랐는디
# 지방종이라
# 찾아보니까
# 콩다래끼라는데
# 같은건가바
# 안없어지는
# 잘
# 오미
# 아니언니요즘너무빡공해서그럼
# 그랬는뎈
# 다래끼갘다고
# 별로안심한
# 아니였어
# 옮긴거아님
# 옮은건강
# 나앗다구
# 약먹고
# 왜생긴거짘
# 가야게따
# 몰빵인
# 사람
# 없젱
# 주희는
# 창토라야
# 누구게
# 아조씨
# 원주민
# 흑인
# 생김
# 한대치고싶게
# 누군지
# 몰라도
# 정우철
# 마즘
# 아니샹칼
# 존똑띸
# 니들
# 창토라
# http
# 같이사실분
# 사싀른
# 페북대란템이거든
# 111
# 진행중이거든
# 밀착력과
# 커버력
# 동시에갖췄거든
# 좋음
# 닥터자르트
# 라인계속탈래
# 방귀
# 쳇
# 프사잘나왔다
# 오늘그소리만몇번짼지
# 머쓱
# 나눠써
# 리필이랑
# 본품이랑
# 주는데
# 리필가질게
# 헤헷딴데끼워씀되징
# 야야
# 성적나옴
# 봐봐
# 특히
# 개빨리나와
# 없었나봐
# 채점할게
# 강의평가
# 되는거아냐
# 하면
# 88
# 왜안나와
# 개좆가틈
# 의견등록했는데
# 안되지
# 다들나옴
# 의견등록하구
# 밑에
# 주관식도
# 해야돼
# 주관식이
# 객관식임
# 주관식말구
# 나왴
# 동거동락해야지
# 성적메이트
# 알려줘
# 못봐
# 알바끝나서
# 지슴
# 세종
# 학사정보
# 들어가야해
# 아머야
# 뭐나왔써
# 개행족해
# 디
# 목표고
# 씨가
# 예상이었는데
# 키키
# 비나옴
# 제로
# 비쁠이라도
# 소박한행복
# 애들다
# 행복해
# 비제로
# 개만족
# 비플이라고
# 씨플
# 진현영이랑
# 씨플나와소
# 재수강아니라고
# 좋아했는데
# 비나왔네
# 씨플이어이뎌
# 어뎌
# 개궁금해
# 물리학점
# 믿는다
# 날실망시키지말기를
# 너만큼은
# 잘봤거드
# 뭔데빨리
# 현기증남
# 집와서
# 곧확인할게
# b이요
# 지렸다
# 에이스
# 역싀
# 중간고사
# 0점
# 개웃갸
# 아나
# 가능해
# 몇점인데
# 0점이
# 아니라고
# 5점
# 50점
# 49점인데
# 종강
# 1점만
# 더맞으면
# 될수있었던건깡
# 쁠
# 과제나
# 실험에서
# 영현
# 깎인거아님
# 깎였나보다
# 못본
# 오지게
# 퀴즈
# 비쁠메친
# 개부럽당
# 똑같앸
# 언니나랑
# 물리메이트하쟈
# 개높아
# 퀴즈점수가
# 0
# 좋아좋아
# 높은데
# 퀴즈는
# c떠라제발
# 미적나옴
# 안나옴
# 물리재수강아니다
# 살았다
# 못나올삘
# 물리는
# 오히려
# 재수강하면
# 개어려웠어가지고
# 불안
# 이번에
# 개망함
# 내학점
# 미적근데
# 다어렵대
# F각
# 미적도
# F각이야
# 미적은
# 가럼
# 영화인보고
# 마셔
# 술만
# 안볼것같앵
# 옹키올티
# 실화야
# 학정
# 밥먹으러
# 정영현이랑
# 학교왔는데
# 김민준한테말해
# 개뚜드려맞았잖아
# 김민준이
# 말했어
# 앝무한루프오졌네
# 갈사람
# 건대쪽에
# 쇼핑
# 이쑴
# 기말점수나옴
# 님덜
# 뒷북인가
# 나온댕
# 월욜에
# 학점은
# 아근데왠지보기싫다
# 으앜
# 지냄
# 끄앙니뜰
# 축구봄
# 보구있었으
# 한골먹힌거
# 축구재미없더
# 규냥
# 자려궁
# 대한민국
# 대한미국
# 짝짝짜까짞짞
# 짞짞짜짜까까
# 술마셨어
# 티비에서
# 소리들려서
# 열기에
# 취했어
# 다보나봐
# 재미없어두
# 이기지못해
# 볼필요없어
# 이아으
# 한번만이기자
# 손흥민
# 멋있었는데
# 애지게
# 못넣겠지
# 한번더는
# 개감동
# 흥아
# 고민
# 말아야하나
# 봐야하나
# 수욜에
# 나누볼거야
# 독일
# 봐야겠지
# 체념하면서
# 수욜몇시임
# 발
# 11시
# 밤
# 11시에
# 끝나는뎅
# 와야겠네
# 호다닥
# 개반전
# 이기면
# 기대하고
# 개개개반전
# 그럴리없으니깜
# 그럼또욕하겠지
# 맘편히보자
# 뭐했냐고
# 지금까지
# 어키
# 수발
# 잘한애들은
# 잘했는데
# 마쟈
# 축구연습하자
# 엥도리
# 위에내용안보고
# 축구연습하자는거만봄
# 축구를이럼
# 헤헷
# 본가
# 있다면
# 천국이
# 술먹것네
# 친구들이랑
# 조아
# 야야야
# jojo
# 샤이니
# 알아몰라
# 띵곡이자나
# 왜몰랑
# 구치
# 역시👍👍
# 분이
# 어떤
# 처음듣는다고
# 하셔서
# 조조가뭐셈
# 아침영화는알아도
# 개띵곡
# 조조
# 왜몰라
# 나옴
# 미적분
# 성적
# 헐랭
# 에프아니다
# 나오자나
# 잘나왔우면
# 좋겠다양심
# 생각보단
# 넹
# 오오올
# 축하축하
# 나와쑈
# 무섭다
# 보기
# 씨쁠
# 만족함
# 에프나올줄
# 등급은나오는데
# 엥근데
# 중간기말점수는비공개지
# 비공개야
# 점수
# 그러겡
# 생각보다
# 잘나왔지만
# 비공개
# 졸라찜찜쓰하다
# 개이드으으
# 우왕
# 좋다
# 공차없음
# 근처에
# 내집
# 게임닉네임추천좀
# 간zi공듀a
# zZ광진구피바라기Zz
# 어떰
# 갈
# 지렷
# 얼마야
# 왕김하온보고싶다
# 캐츔마
# 여긴어쩐일로
# 티켓있삼
# 애져
# 죤나가고시픈데
# 나저때
# 제주도알바임
# 아진짜깨비
# 말해줭
# 공짠겨
# 현영이유
# 너랑
# 근데언니
# 티켓어디서남
# 알반데
# 토요일
# 썅칼
# 김하온이랑
# 보고싶은데
# 빈첸은
# 조나
# 안보고싶
# 아우
# 그럼진현영도
# 몇시시작인디
# 세시
# 뺄수있으몀
# 어께이
# 심심하다
# 같은조
# 그녀랑
# 사귀냐
# 그렇다더라구
# 9일됐대
# 호호우
# 야어리
# 베트남
# 여행가자
# 난좋아
# 가이드도
# 있어
# 현지인
# 개꿀딱이냐
# 뭐야베트남친구있어
# 베트남에
# 살아
# 분위기있당
# 예뻐
# 한강갬성
# 갬성갬성
# 갬성조아
# 요고쥬요거쥬
# 배경은
# 천안에
# 칵테일바
# 예뻐서
# 옥상에있어서
# 찍어쩡
# 하늘
# 천안오면
# 델꼬가줍니당
# 천안
# 웅융
# 놀기좋아
# 두정동
# 가보장
# 런닝맨
# 있대
# 체험하는데
# 앵쮸우한디
# 모여
# 이게
# 개신기햐
# 만이천원이래
# 성인
# 어플로
# 예약
# 놀쟈
# 알바중
# 요즘
# 맞다
# 헉
# 안되겟넹
# 난수요일안더
# 가능
# 금
# 수
# 화
# 고고링
# 금요일
# 앵쭈
# 야옹
# 쪼아
# 가능한분
# 손들엉
# 쏴리질러우어어엉
# 뭔데뭔데
# 20일
# 공연해
# 그날
# 보러와
# 공연연습하는걸
# 본적이
# 없는데
# 많이했어임마
# 모습
# 본
# 낄낄메라
# 야들아근데
# 우리수걍신청은
# 언제여
# 있었는디
# 학교홈페이지
# 학사일정에
# 까먹음
# 일케나와있당
# 고마워유
# 땡큐베리감사띠
# 손들어어어
# 🙌🏻🙌🏻
# 수강신청
# 같은과목하장
# 꾤꾤꾤앵간띠
# 근데우리2학기도어느정도
# 몇개만
# 정해져잇어
# wow
# 겟또뤼한
# 사건
# 오마이
# 왔습니당
# 전달하러
# 지송한
# 참말루
# 금요일에
# 재수하는
# 친구만나기로함
# 까먹고잇엇던
# 고늑힘
# 런닝맨가눈거
# 앰쏘소리
# 가겠넹
# 지이만
# 주희
# 지이언니는
# 공연
# 메라
# 가겠넼
# 쥬희영현
# 참여할
# https
# 1억준대
# 상금
# 나와
# 들어가서
# 로그인하면
# 링크
# 신청하는거
# 노랩
# 르고
# 춤추는거
# 맞앜
# 하는거아니구
# 다같이
# 하는거랭
# 재밌을것같지
# 이뭐야
# 단톡두개에보냈구나
# 숫자가
# 안읽은노란
# 삼십몇개라서
# 깜짝놀라네
# 재밌겠넼
# 빨리빨리
# 신청해
# 신청
# 언제까진지몰라
# 난쉴게
# 아왜
# 다른애들
# 할게
# 신청했엌
# 중학교
# 친구
# 한다그래서
# 했는
# 걔
# 잡혀서
# 저게뭐야
# 보면
# 알아
# 가수랑
# 떼창하는거래
# 노래
# 상금타는거임
# 잘부러야
# 캄
# 떼창이면
# 별로
# 상관없지않을까
# 잘부르는가랑은
# 다른
# 될걸
# 맞추기만
# 사람이랑
# 1억인데
# 하자
# 죽을맛이야
# 다할수있어
# 돈벌수있는건
# 이거말고
# 수영장알바아님
# 마자마자
# 발권
# 수영장에서
# 알바했었는데
# 구명조끼
# 그런거
# 대여해주고
# 야외로
# 옮겨가서
# 접고
# 파라솔
# 피고
# 하는데
# 관두게
# 넘
# 힘들어서
# ★☆★☆【1달뒤개강】★☆★☆
# 웃겨섵
# 이해못했어다
# 순간
# 쭈굴됐잖아
# 개강
# 한달
# 휴
# 다들햄볶는
# 방학보내고계신지
# 나심심행
# 다이어트
# 들어감니다
# 전
# 갔다왔우
# 전시회
# 놀어와써
# 홍대
# 재밌오
# 서울이야
# 엥주현
# 놀러옴
# 돌려줘야돼서
# 유니폼
# 돌아가야돼
# 깎는대서큐
# 안가져오면
# 알바비
# 오늘부터다욧
# 들은
# 말씀메라
# 수만번
# 개잔인하다
# 메친
# 알바비깎는뎈
# 구니까
# 에바얔
# 개강하고
# 넘멀다잉
# 대구
# 되는데
# 생일추카
# 생일파티하자
# 지의
# 추카추카🔥🔥❤️❤️❤️
# 파티해저야
# ❤️❤️❤️❤️❤️
# 달리고
# 더운데
# 생파하쟈
# 신나게
# 오오
# 우리랑도
# 있겠구만
# 잘보내고
# 잘지내
# 재밌게
# 졸라
# 축하해
# 과도한노출
# 생일축하해생일이라고
# 술들이붓기엑스야생축💕🙋
# 윤지의생일이넼마
# 클럽엑스
# 돌았나
# 마
# ❤️❤️
# 걸쳐주길바래
# 어서
# 핰
# 개죠아
# 술은조심해
# 하태하태
# 술조심못해
# 청개구리
# ♡♡
# 생일빵맞자
# 서울와
# 못봐서
# 보고싶당
# 생축❤️❤️❤️
# 오래
# 잘지내😍😍
# 들으실겅가염
# 케이묵하기시러
# 케이묵은하기실탕
# 나걍
# 듣고싶은
# 생각중
# 수업들어볼까
# 성과문화
# 개꿀띠
# 띠용이네
# 마지막날에
# 강의
# 나눠주는
# 콘돔
# 개꿀딱
# 어허
# 어따쓰려고
# 들을분’
# 영어수업
# 지능기전
# a비율이랑
# 늘어난대
# 들으면
# 들읍시당
# 받는
# 비율
# 엄청
# 되는고야
# 들어도
# 김재우꺼
# 다른과거
# 들어야대
# 안들을라묜
# 강의얌
# 무슨
# 난영어죠아해
# 10시반부터
# 12시까지
# 하는거
# 화목
# 같이할
# 아싸
# 친구생겼담
# 학점되는지보규
# 해야할듯
# 논패아서
# 서고강
# 공업수학
# 말한검데
# 들어야되는겈
# 안구래도
# 외국어수업얘기하던대
# 영어로업하는거
# 높아져서
# 좋대
# 학점
# 고랭고량
# 어예
# 화목이야
# 개좋아했는데
# 화공강있는줄알고
# 화공강인데
# 공업수학들으려면
# 공강없어짐
# 시바
# 구래두
# 듣구
# 자면돼
# 집가서
# 김재욱이여가지고
# 하필
# 이상하대
# 공개도
# 맘대로
# 하고그런대
# 관심없지만
# 점수공개는
# 부끄러운게
# 성적낮은건
# 아니야
# 꼴등일거
# 다아는데
# 사실
# 금요일도
# 영현이가
# 이걸루
# 있댐
# 하장
# 12시에서3시
# 개빡센데
# 세시간을수업한다고
# 갯또리
# 교수가
# 외국인이랰
# 구래서
# 들을라구
# 교수
# 뇌국인
# 화목도
# 영어수업는거얌
# 한국인이
# 버리실꺼
# 화공강
# 아무생각없는사람
# 저능기전이
# 좀더
# 좋을거같긴해
# 학점따기
# 망시간표
# 나오늘
# 생일인데
# 축하해주겠니
# 안해놔쏘
# 카톡에
# 표시를
# 왔담
# 일산
# 킨텍스
# 짜야
# 뭐행
# 킨텍스에서
# 고마옹
# 히힛
# 방청하러
# 프로그램
# 올렸던거
# 짱재밌움
# 그거하구나
# 생일에
# 기억해두게씀
# 몰라써
# 티안나서
# 페북안하고
# 모를수가
# 노랑
# 짱짱
# ♡
# 몰랏다
# 안떠서
# 온니
# 재밌게놀아
# 추카해
# 후기말해주공
# 알려줄겤
# 이따가
# 후기
# 8시부터
# 녹화안해쏘
# 방청객으루
# 보내넹
# 우왕생일을
# 앙
# 존잼이야
# 개재밌겠당
# 개신낰
# 재밌고
# 아이콘이랑
# 존멋이야
# 휘성
# 갯또리방구
# 몰라서
# 미얀해
# 머박적으로
# 뿡뿡하고
# 생일남은시간
# 축하방구
# 햄볶하게보내
# 축하
# 말을
# 아니얌
# 안했는골
# 잘놀으껭❤️❤️
# 뽀뽀
# 되있는거지
# 이고는
# 자동으로
# 윤지의죽은줄
# 화이또
# 뭐들을고야
# 화이띵
# 단발쳤나봐
# 공수머듣냐고
# 지기
# 오호
# 그러네
# 영혀니프사
# 지금봄
# 1순위
# 악
# 우리과꺼
# 긍데
# 이런거있더라
# 다른반거
# 안될구같긴한데
# 나돔르게써
# 모르겠어
# 저건
# 첨보는데
# 수강재한
# 이과목만
# 있긴하던데
# 다르다고
# 특성마자
# 저것만
# 저렇데
# 홀랭
# 대
# 그러면
# 우리과거는
# 가르쳐주고
# 그러나
# 빅데이터
# 연결해서
# 별차이
# 없을삘이야
# 별차이없을듯
# 공업수학인데머
# 위해
# 거기서거기일삘
# 포기
# 못듣게하면
# 우짬
# 지기꺼
# 어쩔수없이
# 데사야
# 안와
# 잠이
# 해볼거
# 흑
# 우찌하지
# 한다
# 바꾸면
# 성공하쟈
# 교양은
# 에프뜬거
# 재수강
# 에프떳어
# 나혼자했던거
# 있우
# 됬써
# 빡센거
# 올클
# 나둨교양그냥
# 싸강신청함
# 쉽다
# 왜왓나싶다
# 피시방
# 안경안가져와서
# 피시방에
# 게임못해
# 개빡쳐
# 난이제할거임
# 비오는
# 태풍때문에
# 내동생데려옴
# 옵치하게
# 옵치할거
# 하실
# 엉껄껑
# 옵치는
# 롤하자낰
# 안있어야할듯
# 쫌이따
# 가끔해
# 옵치
# 태풍올걸
# 저런
# 비와
# 색채했씀
# 서울
# 잠잠하냐
# 색채말고
# 다른거함
# 엿내
# 음악감상의이해
# 색채
# 해봤거든
# 비즈니스
# 전략
# 콘텐츠산업의
# 됨
# 샏채
# 없냐고
# 한사람
# 몆초만에
# 수강여석없데
# 노예다
# 케이묵의
# 성공함
# 닌성공함
# 큰일날뻔
# 햇으면
# 놀이치료함
# 현영모함
# 색채가
# 핫했어
# 나만몰랐나
# 놀이치료
# 재밌겠네
# 오그것도
# 음악감상
# 둠칫
# 왜이렇게
# 공수는
# 다뭐함
# 놀이치룤
# 예술적인건데
# 공수
# 데싸
# 나랑영현이그냥
# 화공강만들라구
# 널널함
# 우리과거함
# 우리과거가
# 공강포기
# 김재우꺼맞제
# 목욜날
# 연강이기도하고
# 우리과거
# 교수님한테맨날뇌물공작때리면
# 에프는피하겟지뭐
# 김재우
# 우리과거임
# 아진쨔
# 앵쮸메라
# 뭐했음
# 몰라
# 아니냐고
# 친구없는거
# 송진우거
# 꺼
# 좋았어
# 주혼이도
# 이도
# 좋아
# 다행히
# 아니구망
# 혼자는
# 잘됐넹
# 수업언어
# 영어야
# 겠지
# 믿을게
# 말이되냐
# 말이됨영어로수업한다고
# 말이되냐는거지
# 영어가
# 개소리
# 뤼얼
# 부들부들할뻔했네
# 그나마
# 나을듯
# 한국인이라서
# 한국어로해도
# 부들메랔
# 안들리는건
# 똑같아서
# 한국교순데
# 영어로
# 같은느낌으로
# 미적과
# 한다고
# 왜안들리냐곸
# 한국언데
# 개웃경
# 그게뭐람그사람
# 외국살다왓데
# 다르던디
# 뷴반
# 영어
# 조윤식교수님께도
# 하는말이야
# 19
# elp
# 20이다
# 영어분반
# 문쓰발때랑
# 뷰
# 똑같을걸
# 서양철학은
# 13이던뎅
# 도
# 14
# 아개시러
# 헐그러네
# 나이뜨
# 13
# 서양철학
# 개나이쓰
# 다다름
# 영현아
# 아니네
# 14네
# 헤헤
# 개좋다
# 갑분영
# 희롱잼
# 이엘피
# 같은반
# 헤헷둥이
# 러쟈라징릊
# 다다르댘
# 울겟노
# 왜우노
# 같당
# 영어는
# 헤헷쓰
# 2학기때
# 공부개열심히할거임
# 서철은주현
# 이
# 있으니깡
# 말리지마셈
# 자는삘인데
# 전화도안받고
# 올에이쁠이다
# 지랄이야
# 금마는
# 방학때까지
# 미친넘
# 알아서하라해
# 수강신청은햇데
# 난몰라
# 안되니까
# 연락이
# 에바다
# 됐넹
# 졸리무서움
# 개운하게
# 아침에
# 일어났는데
# 기분이
# 싸
# 일어나자마자
# 댔다
# 이느낌들거같은데
# 어떡햌
# 자는거맞다
# 사고강
# 실패했옼
# 졸업못할듯
# 고전강독
# 언제하지
# 그거그냥
# 잘보며되는거아냐
# 너도
# 못해써
# 못한줄
# 시도도
# 안했어
# 다행이다
# 나도시도안함2학눀때늨
# 되겟지
# 슈방
# 신청한거
# 잘받자
# 학점이나
# 2학년때
# 다들하는걸로
# 이학년때
# 21학점
# 신청한것도
# 우와아
# 21학점이야
# 짱이다
# 게임합니당
# 피씨방온김에
# 현양은
# 서고강함
# 게임합니다
# 이번에는
# 논패받지말아야지
# 쩐다
# 졸업전까지
# 이런거안하면
# 계절학기들으면
# 되던데
# 동생데려옴
# 계절학기
# 그롬
# 들어야겠다
# 세종봉사도
# 알지
# 잇는거
# 그거는
# 해따
# 나1학기세사봉논패
# 겨울방학에
# 세사봉
# 아마쟈
# 졸업
# 누구패스한
# 사람있기는해
# 없나봄
# 시간은
# 천천히하지모
# 새내기
# 이럴때만
# 방계약함
# 샌액희
# 방
# 어디쪽으루
# 했어
# 후문쪽
# 됬제
# 야뚜
# 놀러갈게
# 노셈
# 우리과
# 울집와서
# 자고
# 얼마냐
# 월세
# 개재밌겠다
# 50
# 6마넌
# 관리비
# 인데
# 5060
# 술파티
# 옵치중
# 계속
# 아뉘
# 지기만해서
# 노잼이라
# 하자고
# 할랬는데
# 쪕
# 코쓱
# 등록금
# 27일부터라는데
# 잘모르게쏘
# 윤지
# 햄스터티유쟈
# 키우자
# 졸라귀엽지
# 귀엽다
# 짠거
# 털실로
# 햄스터인형같암
# 햄찌두마리키웁니다
# 이거삼
# 햄스터볼
# 존나귀여워
# 학교데랴와
# 졸귀야
# 프사모얔
# 몰까
# 고소했다는건가
# 날
# 누가
# 뭐징
# 잘못보낸거래
# 전화해밨더니
# 놀랬어
# 너의결혼식보러옴
# 옥히메라
# 재밋을거같음
# 1위거둔
# 재밌음
# 공작도
# 재밌엉
# 공작
# 꿀잠잠
# 내용
# 너무어려워
# 개슬퍼
# 너의결혼식
# 재밌어
# 나이거쓰고다니면
# 어떡하꺼야
# 여기까지
# 우리인연
# 우산이야
# 저게
# 우산이래
# 손잡이
# 요란하다
# 반짝반짝
# 비오는데
# 빛날듯
# 왐마링
# 바뀜
# 화공강이었잖아
# 뭐지해는데
# 그대로였음
# 학사정보가니까
# 오류난겅가봐
# 뭐해
# 나얔
# 고터
# 고터가
# 고속터미널
# 가장
# 술먹자구안함
# 애들이
# 괜춘
# 화욜도
# 내일언젱
# 끝나구
# 앵간
# 가아으을오옷사아아자아아
# 돈도없음
# 뿡
# 중요한건
# 헤헷방구
# 말투
# 껄껄
# 근데주현
# 강아지한테
# 술을권하면
# 친구가
# 한거야
# 귀욥지
# 강아지도
# 내일개강을
# 마치
# 알고잇는듯
# 안쓰러워보여
# 표정이
# 아존나웃겨
# 감성이냐구
# 싸이월드
# 고느낌임
# 새벽갬성
# 싸이갬성
# 휘유
# 때
# 운거야
# 왜그래
# 표정
# 개강이라니
# 기억안나는데
# 학교다니는법
# 이욜
# 구경만함
# 옼
# 개맛있겠다
# 오오오
# 맛있겠닼
# 치명적인
# 웃긴데
# 이뻐
# 이쁘다구
# 만날꼬
# 몇시에
# 고터야
# 아닝
# 집와쏘
# 일곱시쯤이라
# 하지않았낭
# 7시에
# 만날까
# 오킹
# 고터에서
# 말했는데
# 머거서
# 못갈거같아
# 미아내
# 타이레놀
# 빠꾸
# 이미예상했어
# 예상했대
# 집갈거같다길래
# 피곤해서
# 이랬움
# 푹쉬어
# 머거
# 어디서
# 재레가자
# 아배고파
# 고랭
# 치
# 치킨먹고샆다
# 어나도
# 수프림양념치킨
# 미쳤다
# 국물뚝뚝떨어지는거
# 도랏다
# 치킨
# 모르는데
# 어딘지
# 째레
# 치가
# 가치가자
# 알쏘
# 내뭔뎈
# 째레갓음
# 노놉
# 화심
# 거기서안주뭐먹음
# 메르스띤
# 먹고
# 뻗었을때
# 소주
# 아니메친
# 고요하다
# 가릴걸그랫나
# 스티커로
# 언니미앙
# 귀여오서
# 찍었엉
# 갔었는데
# 그근처에
# 들릴걸
# 편의점
# 너네보러갈까생각해었는데
# 맛잇겟다리얼
# 너무햌
# 없자나
# 필터도
# 미안
# 큐
# 보는걸루
# 우리끼리만
# 머리아파
# 8500씩
# 주세용
# 화심간사람
# 04
# 072525
# 091801
# 국민
# 보내쓰
# 보냈쏘
# 모해다들
# 동아리갔다가
# 영화보러감
# 뭐보러강
# 뿡퍽
# 프사존예방구
# 서치
# 인정
# 존예야
# 감사
# 서치보고싶다
# 강주현나랑서치보기로했자나
# 담에
# 딴거보자
# 명당보러가장
# 롯시표있대성
# 쏴리
# 아냨
# 보러가장헤헷
# 보구싶다
# 보러갈레
# 금요일낮에보면
# 참석가능
# 허헛둥둥이
# 낼보자
# 2
# 내조
# 병아리
# 뿔난
# 다이소갈라했는데
# 아낼
# 존나많네
# 엉
# 녀러분내일
# 노트북안챙겨두되죱
# 블랙보드올러옴
# 챙기라고
# 어라라
# 고급씨
# 웅장문정
# 강의실
# 못바꾼대
# 에이씨팡
# 백팩하나
# 장만하셈
# 나도사고싶다능
# 백팩
# 벗
# 현양잔고빵원
# 알바비들어온다얄루
# 빵원
# 개강기념으루
# 얘드라
# 담주화요일에
# 롯데월드
# 어케생각
# 머임
# 키즈앤틴즈
# 교복없겠네
# 롯데월드메친
# 고딩때도안맞아서
# 나교복레알
# 졸업하자마자내다버림
# 그뜻으로
# 말한건
# 아닌데
# 또륵이다
# 교복
# 따흐흑
# 나둥
# 평상복
# 교복갈거면
# 가야해
# 추석이후에
# 뭐더라
# 유명한거
# 개슬펏는데
# 못타서
# 탈거얼마업던데
# 아트란티스
# 자이로스윙
# 후렌치
# 점검
# 이랑
# 탈거없지만
# 바람
# 환상의나라
# 가는거지뭐
# 맨날해
# 뭄
# 비안오냡
# 화욜
# 가서
# 기분내는고
# 헙
# 그건몰라
# 에버랜드가
# 가면
# 에버랜드
# 체력개거지되던데
# 상으로는
# 아이폰
# 맑대
# 다행스
# 놀이공원은
# 어딜가든
# 체력거지림
# 바람은
# 갈거면
# 말해야함
# 빨랑
# 빼야돼
# 앝
# 아메친현양은화욜에과외잇음
# 워루
# 워후
# 오늘도햇는데까먹엇네
# 오키
# 아침일찍가서
# 개마니하는데
# 돈
# 왜0원이냐곸
# 돌아오는건
# 수업할때
# 넘나촉박이냐
# 왙
# 돌았냨
# 넘나촉박
# 개꿀잼일듯
# 아슬아슬도착
# 아니먄
# 되자나
# 안먹으면
# 수업끝나고
# 월요일
# 4시이후
# 롯월
# 그거끊자
# 미련쟁이
# 갈지안갈지
# 말헤
# 아재믹겟다
# 미야옹
# 그만큼
# 움직이는대
# 고딩친구
# 바께
# 쟤
# 넘행
# 진현영앙가면
# 죄송염
# 헤헷둥둥이
# 네
# 나도안갈랭
# 프사랑
# 똑같죠
# 괌
# 말하섬
# 친목도모좋은지
# 여자같은여자는
# 현양은준비가덜됨
# 여자같은여자가아니고
# 원시인같은원시인임
# 부담같지마소
# 갖
# 인데요
# 먄
# 갖지마소
# 부담
# 부담이고뭐고
# 아직현양은
# 원시인이라안됨
# 개조앜
# 못간다구
# 했넹
# 뜨끔메라링
# 대충봐서
# 잘못봤다
# 갓다와
# 괜스레미안해지는현양
# 너가
# 가지뭐헤헷
# 오잉
# 가는거임
# 빠꾸없는거야
# 물
# 은듯
# 애
# 잘생겼다
# 이준기닮아따
# 뮤대
# 이쁘게잘생겼다
# 친구임
# 아마
# 안될듯
# 알바하느라
# 개무섭다
# 딱무서움
# 저런스타일
# 한마디도못함
# 말걸엇다가
# 식도에펀치꽂힐거같음
# 생긴사람
# 저렇게
# 처음봐서
# 스타일인지
# 저귀걸이
# 숫자4도무서워
# 넌
# 죽엇다
# 요뜻
# 과대해석
# 죽어
# 암튼
# 준내무서움
# 나라는그릇에담기엔
# 너무큰아이들
# 아레나
# 엠디래
# 노는애네
# 진짴
# 거봐
# 큰애라햇지
# 컴공임
# 컴공
# 지렷다
# 퀴즈로
# 술게임
# 하셈
# 죽인딬
# 개에바자나
# 개싫어
# 가서아무고토
# 못하죠
# 공공칠빨
# 침묵의
# 하게생겼내
# 상처만남은술게임
# 또로록
# 땀
# 감자전만듬
# 개발했쑴
# 개잘한다
# 요리
# 닉값하시네연
# 서치보러갈사람
# 답장않해
# 안볼래유
# 어제밤에심야로봣다
# 대존잼임
# 너의걀혼식
# 개눔
# 밤에보고
# 울엇다고
# 보다가
# 잤음
# 중간에
# 수업열삼히들어
# 김재우교수님
# 설명은
# 앵간쓰레빠앵쮸인거같은디
# 멸치에
# 안경쟁이같았는데
# 이름만
# 닮으심
# 덩치잇고
# 마이크로닷
# 옱봏음데
# 금붕어인
# 눈이
# 부엥
# 언제마쳐
# 붕어닮음
# 수업안헐줄알었는데
# 시바루
# 언제나침
# 세시간꽉꽉채우면
# 붕어식도에펀치
# 게
# 못가르친다는
# 무슨말인지
# 알것같움
# 붕어머쓱
# 존나웃겨
# 애바
# 첫수업인데
# 언제까지함
# 몰빵이얌
# 몰빵으로
# 찡구들
# 구럼
# 몰빵갈겡
# 잘만들옸제
# 거임
# 올리는
# 이시간에
# 레시피
# 알려죠
# 맛있어보임
# 맛있겠다
# 잘만들었네
# 쿠킹마마임
# 이야
# 김치찌개는
# 비비고꺼임
# 만든거
# 야내일
# 잊지않았지
# 카레
# 시로
# 갈꺼야
# 수업전까지
# 자다
# 같이갈사람
# 구함
# 빡셀것같은데
# 같이가준다고
# 그럼학교는
# 그건
# 잘모르겠음
# 내생각엔
# 써야될거같은데
# 송재윽교수님이니까
# 월욜은
# 씨만
# 하루빠지고
# 지의갈거임
# 공강이자낭
# 너어차피
# 저길왜가
# 세종사회봉사
# 나근데
# 30시간
# 채워야되제
# 16시간주면
# 앵간꿀이지
# 안햇는디
# 봉사해놓고
# 다음학기에
# 제출해도
# 되지않나
# 잘모르게따
# 가능하나
# 그러게
# 신청을
# 안햇는데
# 정보바람
# 정확한
# 물어보삼
# 선배한테
# 아는선배
# 기획부자나요
# 단발칚가
# 귀찮으면
# 머리감기
# 자르는거추천
# 귀찮은거보다
# 머리감는거
# 예쁜거
# 뭐가더나을까
# 가을이니까
# 긴머리
# 단발한
# 없쏘
# 못해주게써
# 단발할꺼면
# 결정이야
# 큰
# 앞머리를
# 내리시오
# 앞머리
# 없는단발
# 안됨
# 중요합니다
# 너는
# 쪼매나서
# 괜찮을듯
# 단발은
# 없는게
# 젛음
# 단발
# 이쁘다
# 저사람얼굴이다함
# 이뿌니깐
# 주먹만하구
# 10가능일듯
# 10가능이래
# 단발햇을때
# 옛날에
# 삼각김밥
# 조만해
# 되서
# 화들짝
# 놀램
# 그뒤로
# 절대무리
# 아니양
# 중고딩이라그래
# 고민되
# 순간적으로
# 너인줄
# 보낸
# 알았음
# 잘어울릴것같은데
# 느낌이
# 다를것같아
# 성숙하고
# 세련됐는데
# 발랄하고
# 어려보일듯
# 저단발치면
# 원하는댜로
# 같은데
# 단발이
# 치고나면
# 후회할꺼같고
# 선택장애
# 근
# 치면
# 후회안할듯
# 개편해서
# 편한거보다
# 예쁜걸
# 추구함
# 예쁘고편함
# 개웃곀
# 낫다
# 단발치고
# 맨날고민하지말고
# 안치고
# 후회하는게
# 개이득이구
# 후회안하면
# 마음으로
# 요런
# 편한
# 단발하셈
# 머리
# 질리자나
# 하나오래하면
# 머리가
# 안길거든
# 질림
# 긴머리하고싶을때
# 붙임머리해볼라고
# 안하고싶을듯
# 개비싸잖아
# 붙임머리
# 비싸도
# 어쩔수없지
# 하고시면
# 대한
# 염색에
# 진지한
# 암것두아님쓰
# 하고나면
# 할머니되면
# 햇는데
# 50년
# 늙어보이면
# 어캄
# 머
# 백발할라고
# 단발친다
# 이색
# 존예임
# 워매
# 개이쁘다
# 단발치거
# 염색도할거
# 아나도
# 염색해야되는데
# 뿌염
# 다른색깔
# 뿌염하고
# 개별로야
# 머리색
# 너내일
# 데이터사이언스특강
# 아혀녕
# 파마
# 단발하까
# 중발할까
# 첫번쨔
# 두번째머리는
# 안어울릴삘
# 데사특강
# 1번머리하렴
# 가지말까
# 귀찮은데
# 나안갈꺼임
# 갈랭
# 몇신데그거
# 1시
# 농활갈사람은
# 농촌봉사
# 하고싶긴한디
# 그거인정될지모루것음
# 세사봉신청안해서
# 찾아봤는데
# 1학기에
# 2학기에
# 있는데
# 한거는
# 1학기로
# 2학기꺼는
# 안된대
# 아고래
# 그럼안되는건가
# 안했으면
# 식팡
# 눈물
# 프사개귀엽다
# 귀여움
# 똥꼬도
# 말
# 수강신청안해서
# 어늘했씀
# 예
# 그거언제까진데
# 몰라우
# 말똥꼬
# 인가
# 그거3학점임
# 1학점인데
# 3학점이면
# 나못하는데
# 이건
# 개앵간이다
# 추가할수있음
# 들음
# 변준영오뻐헌데
# 기본학점에
# 안들어가
# 세사봉은
# 나도지금해야지
# 안드가더라
# 뭐죠
# 단발하고싶데섴
# 뭐가좋냐고
# 이중에
# 물어보려고
# 다이쁘지만서도
# 다예쁨
# 겨울
# 여름
# 저만보면
# 겨쿨이
# 존예자나
# 변경마감이엇네
# 아니미친
# 오늘12시까지가
# 물건너간현영이
# 귀찮아서
# 그어차피
# 안할득
# 이번학기에도
# 아메친
# 개인정
# 다채우겠어
# 이번학기에
# 위안이되네염
# 진짜로
# 못채워서
# 졸업까지
# 졸업못하는사람도
# 봉사하는
# 멘토링같은거있아서
# 어차피할더면
# 그거하면서
# 좋을덧
# 채워도
# 멘토링은
# 멘토되는거임
# 공부잘해야
# 멘토할수있는거
# 고교
# 수업가는거
# 절대안가
# 초교는
# 유교나
# 교육은
# 나랑안맞아
# 몰라튼
# 초교인가
# 왜요물어보면
# 개째려볼거같음
# 왜모르냐
# 가르쳐주면
# 잘알려주거든
# 친절하게
# 가르쳐줬잖아
# 몇번말해야되
# 어우답답해
# 그럴거같긴함
# 똑같은거
# 쿠
# 음성지원
# 개쩐다
# 그랬다고
# 자신은
# 윙크
# 불독키우고싶다
# 예쁜불독이다
# 쟤네는
# 느낌개좋으뮤
# 만지면
# 불독
# 강아지다좋아하는데
# 무섭메라
# 불독은
# 눈빛이
# 세종원거서
# 머글사람
# 짜장면
# 헤헿
# 쌩깐주제에
# 카레약속
# 진현영당첨
# 나낼
# 바쁘거든
# 절대엑스
# 밀가루
# 덩어리
# 냠
# 다여트
# 뽐뿌온다
# 현영이보면
# 개망햇음
# 마지막
# 살존느찌게
# 생겼네
# 살찌게
# 생긴거맛있게
# 놀람
# 살덜찔느낌임
# 생식
# 그러케
# 좋은방향으로
# 생각할줄이야
# 겁나양념되잇음
# 밥에
# 요가다니자
# 존맛
# 우리다같이다이어트하자
# 쳐
# 치팅데이라고
# 의지가
# 훨씬
# 될
# 매일매일이
# 치팅이면
# 큰일
# 큐난
# 문제임
# 안해서
# 운동을
# 짜장면먹고싶다
# 세종원가자
# 다이어트임
# 언제부터
# 따라하는거니
# 그래
# 우리함께라면
# 무엇도
# 두렵지않다니까
# 다욧해요
# 미소
# 밥사먹는다
# 무조건이다
# 집밥먹을거임
# 양상추삶은거에밥싸서
# 기숙사라소
# 사먹음
# 존노맛각임
# 갸맛있는데
# 간장넣어야
# 갸맛임
# 간장살쪄
# 밥싸먹고
# 삶은거
# 양상추
# 간장안너음
# 간장은
# 빛
# 유일한
# 간장살쪄서
# 넣으면안됨
# 긍데좀넣음
# 집임
# 간소하게
# 먹을거다
# 라면지금머글까
# 머그면
# 더부룩해
# 잘때
# 없음요
# 간장도
# 살찌냐
# 안찌는게머야
# 답정너잖아
# 맛있으면
# 다찜
# 먹고시픈데
# 팔뚝보고
# 참고있는데
# 엥오늘
# 이승준생일이네
# 라면하나가지고
# 살안찐다
# 이런
# 합리화하고있씀
# 쪄
# 먹는데
# 하나
# 살이찜
# 살찜
# 자면
# 승준이
# 갠톡으로
# 생일추카를
# 해줘야하나
# 하나먹고그뒤로이주는먹으면안됨
# 갠톡
# 나사실
# 갠톡할만큼
# 친하지
# 않은디
# 없
# 해본적
# 그냥내일
# 묻어갈까
# 애들축하해줄때
# 낼보면
# 말해
# 그래야겟다
# 룰루둥둥
# 라면한갸먹으면
# 기다려봐
# 널위한
# 영상이
# 잇어
# 예전에본거임
# 지금라면먹고
# 굶어야겠다
# 내일도
# 먹겠지
# 시부렠
# 지금끓이는중이니
# 끓일라고
# 앉았는데
# 배보고
# 참음
# 배고플땨
# 우얌
# 먹었써
# 개쳐먹엇당께
# 저녁5시
# 5시에
# 먹었으면
# 그거먹고
# 이디야
# 치즈케익스틱
# 배존나
# 아아니
# 닭가슴살소시지
# 친구랑나눠먹고
# 고프다
# 졸라고픔
# 인내
# 그것만이살길
# 배고프면
# 잠이안옴
# 내일아침에
# 빨리자고
# 미취겠네
# 라면
# 먹으셈
# 내일아침에라면먹는
# 행복한상상을하며
# 잠드세요
# 어떻게해
# 들먹고
# 슈뱅
# 운동
# 그것만이
# 교과서적방법
# 어느정도
# 하루에
# 운동해
# 근데요즘
# 일주일동안은
# 망햇는데
# 그전에는
# 몇시후에
# 안먹고
# 았잖아
# 저녁으로
# 6시에
# 단백질
# 쉐이크먹음
# 밥은반공기만
# 점심은
# 집밥
# 아침점심은
# 아침은
# 근데가끔친구랑
# 맛잇는거먹음
# 밥반공기
# 국물안먹는게포인트
# 로스트치킨먹음
# 샌드위치
# 서브웨이가서
# 졸라먹고싶을때
# 은근존맛탱구리임
# 국물없으면
# 밥못멈
# 김치찌개준내먹고싶음
# 나도나
# 아휴
# 맛있는게
# 세상에
# 왜이래많지
# 😷
# 야나는
# 니정도만됫음좋것다
# 뺄거없음레알
# 갸많음
# 숨겨진살
# 허벅지랑
# 조땜
# 팔뚝
# 내친구들
# 놀러오는데
# 월화수목
# 못할꺼가튼데
# 미치것네
# 먹을까
# 다다음주부터
# 열심히해
# 다다음주
# 부턴
# 담주먹으면
# 도루묵이셈
# 지금해도
# 버틴다
# 식단만으로
# 생활운동
# 계단오르기
# 광개토
# 7층까지
# 엘베
# 사용금지
# 그러자
# 물올림
# 개맛있게
# 단무지랑
# 모거야지
# 신라면
# 그옆에
# 김치찌개
# 시선강탈
# 배고프니까
# 자겠어
# 왜안와
# 710호
# 나혼자임
# 가늠중
# 얼룽와
# 다들머해
# 칭긔칭긔
# 만나러
# 밥먹고
# 집갈라고
# 집또갘
# 집가
# 아닠알바라고
# 만둠
# 쏘야
# 나는김치참치햄보끔밥이얌
# 아맛있겠다아아가
# 배고파
# 악수함
# 타블로랑
# 내친구
# 슬라임카페에서
# 알바하는데
# 다만났댘
# 타블로강혜정하루
# 세종대에
# 시발왜
# 알바일때
# 에픽하이옴
# 나두봤다
# 대박이다
# 슬라임카페
# 악수
# 다음주는
# 어떠신지
# 죄송합니당
# 가는거얐어
# 몰랐나여
# 나돜
# 까먹었군
# 다행메라
# 그거취소된거아니였냨
# 오디야
# 광개토관가있게
# 지의랑
# 긱사
# 곡관인뎈
# 광개토관에서
# 구경하고있옸어
# 씨케이
# 식케인줄
# 개깜놀
# 출튀할꺼임
# 글램핑가면
# 괜찮을까
# 씻는데는
# 화장실이랑
# 찾아보고있었는데
# 단체로
# 들어갈만한데
# 있는지
# 여러곳
# 씻는것도
# 진쨔씻는곳시설
# 개열악함
# 169000원이고
# 네명에
# 이런데
# 금액가능
# 에라모르겠다
# 기획이랑
# 빠꾸치고
# 사무부가
# 안되겠다
# 알아서
# 찾아보고
# 투표끝나고
# 하겠지모
# 4명에
# 16만원
# 마돌앗나
# 파티룸좋은거같음
# 글램핑에투표해놧는데
# 파티룸도
# 안에
# 노래방
# 기계도잇구
# 잼날거같온디
# 고기구워먹구
# 파티룸
# 제대로놀수만이쓰면
# 재밌지않을까
# 기본
# 바다나
# 엠티방가서
# 캠프파이어하고
# 그러고싶댜
# 캠프파이어
# 깡통가져가서
# 쥐불놀이할거임
# 불꽃놀이
# 필수
# 존잼이겟다
# 폭죽도
# 사가야됨
# 들엇는데
# 선배한데
# 글램핑을
# 에바고
# 엠티로는
# 같은거
# 펜션
# 마즘개에바임
# 숙소
# 잡고
# 노는게
# 좋데
# 근처
# 바다
# 져녁에놀구
# 바다했음
# 구럼나도
# 바다해쏘
# 이번엔
# 그럼나조바다
# 갈겊
# 3시전엔
# 올수있남
# 못가유
# 빠꾸충이야
# 아진심
# 3시전에
# 갈라면
# 개일찍가야함
# 안가앙가
# 너어챠피
# 간다맼
# 웅꺼져
# 목고싶다
# 삼겹살
# 미친미친
# 귀차나서
# 안감
# 모름
# 홀난
# 안갔을듯
# 알았으면
# 가려고했다가
# 안갔겠지
# 고것
# 닭발
# 조지러옴
# 언니어디서하기루함
# 나일단
# 지하
# 학정와써
# 박도형오빠여자친구임
# 뭐가
# 박도형오빠의
# 프사를
# 확인하고오시오
# 걍친구라곸
# 허허
# 심상치
# 않은데
# 게다가
# 잘어울림
# 저번에도
# 나까지
# 혹했다가
# 아니었자나
# 저걸
# 잘어울리는걸
# 봨
# 친구로
# 친구라고
# 노웨이
# 남녀칠세부동석
# 박도형이야
# 상대는
# 몰랐으면
# 생각핥번
# 여친이라고
# 남녀는
# 이세상
# 진짜친구인
# 능력
# 만날
# 저런여친
# 음흠
# 없습니다
# 눈이있다거
# 여자애도
# 여자친구올시다
# 의심의
# 뿌리를
# 뽑을것이야
# 부수는
# 뼈
# 수준이야
# 동참하실분은
# 일어나주세요
# 청자켓까지
# 매너봐
# 벗어주는
# 지꺼야
# 다님
# 박도혀오빸
# 청자켓입고
# 벗어줌
# 이요르
# 벗어준거라고
# 미이친
# 미친미친미친
# 없슴니다
# 와우
# 친구사인데
# 거울셀카까지게다가
# 그것을
# 벗어주고
# 청자켓
# 프사로
# 남녀칠세부동석의
# 원칙에따라서
# 이것은
# 아니하다
# 무기징역일세
# 생각으로
# 이상한거야
# 남자사람친구가
# 옷벗어줄수있씀
# 추우면
# 그랬지
# 뭐라
# 올리는사람
# 승헌쓰
# 유투브에
# 폴킴폴킴
# 오키염
# 정주행하시오
# 모하슈
# 밥하고이썽
# 나갈준비쓰
# 어디가
# 가쟹
# 코다차야
# 조지고올게
# 치즈야
# 김볶으로
# 유명하길래
# 먹구있어
# 빈곤하게
# 이런거하자나
# 홍보알바
# 건수
# 잘땡기는중
# 거기
# 관둠
# 얘기해줄겡
# 아낰오키
# 난빙수먹으러갈건데
# 서울빙수추천좀
# 설빙
# 빙수먹고싶다
# 개맛잇어보임
# 김볶
# 쉬부레방구
# 어때
# 후기좀
# 개존맛탱
# 같이가자
# 야한거야
# 개야해
# 각인디
# 야동이라매
# 긱사안드감
# 집감
# 놔두고
# 멀쩡한
# 어디서잠
# 노노
# 밤샐라고
# 주희어대
# 어대
# 탐탐
# 보리잉줄
# 귀욥다
# 짱
# 왜저길올라갓냨
# 햄스터가
# 그러고보니
# 교수님
# 수염짜름
# 들었나
# 말하는거
# 미스터선샤인
# 종방
# 꼽준
# 닮지않음
# 꼽줬어
# 신발
# 우산이랑
# 챙기기
# 공지
# 톡게시판
# 메모장
# 똑같다
# 사는거
# 모햐
# 보구옴
# 쇼미더머니
# 갓겜
# 쇼미달려야지
# 오늘밤
# 퇴근
# 뺏기는중
# 필기
# 베끼는중
# 누가뺏엌
# 매일밤
# 안부물어보넼
# 윤지의는
# 물어보고는
# 아무대답없음
# 내말잌
# 놀러
# 델꼬가
# 둥둥둥이
# 둥둥둥두루둥둥이
# 배경이랑
# 프로필뮤직
# 공차사이즈업해서
# 지하철역에서
# 마감할인하길래
# 빵
# 나도모르게
# 이끌려서
# 빵먹고
# 미친년
# 이제는
# 이별을
# 선언한다
# 놨는데
# 헬스장가보니1키로쪄잇엇음
# 쉬부레
# 이틀만에
# 메로나도
# 쓴고임
# 내자신에게
# 약속겸
# 퀴즈결과나옴
# 건대에
# 개콩
# 떡볶이
# 콜
# 안자구
# 머거봐써
# 맛있음
# 👍
# 엽떡보다더
# 안좋아해서
# 엽떡별로
# 그런느낌
# 신전파
# 엽떡보다
# 매움
# 엄청난
# 정돈아니고
# 맴단계
# 안맵고
# 있을걸
# 정할수
# 떡볶이야
# 맛있는떡볶이
# 느낌이면
# 늘러붙은
# 엽떡이
# 퍼지고
# 생생한
# 쟨
# 표현죽이네
# 와윤지의
# 입맛
# 존떡이냨
# 지각임
# 존에
# 쫌
# 긱서임
# 김
# 나아직
# 지각
# 통계학개론
# 도착안함
# 이제출밡
# 같음
# 사투리
# 북한말같음
# 티안남
# 사투리라기보다
# 어눌
# 그런건가
# 참는다고
# 과
# 보내줬는데
# 애가
# 애하는거
# 지
# 대구사람이니까
# 안쓰는거
# 궁금해서
# 보냄
# 서울애들은
# 어떨지
# 답이없냐
# 높낮이는
# 볼때는
# 사투리가
# 아닌갓같은데
# 지방
# 말끝이
# 이래서
# 임다
# 북한말같어
# 북한말
# 듣기엔
# 말끝좀
# 서울말가튼데
# 흐리긴하는데
# 괜찮은걸구하장
# 어차피한국말이니까
# 안아팠오
# 헐뚫었메
# 두개나뚫었어
# 개아팠을것같애
# 술먹우면
# 덧나는거아님
# 나랑같이뚫지
# 갠츈
# 쫌아팠는데
# 2주한달
# 먹지말라던데
# 그래놓고
# 무섭다고
# 안뚫을거잖아
# 간파당함
# 배고파서
# 풍선껌
# 징징이같음
# 껌씹으면
# 배고프디
# 또륵아
# 뻥안치고
# la갈비
# 먹고싶다생각함
# 룸메한테
# 키우자고
# 햄스터
# 룸메도
# 생각해보기로해따
# 긱사에서
# 키울수잇어
# 햄스터도
# 키울랬는데
# 키우다
# 걸리면
# 퇴사디
# 안걸리지않을까
# 안걸리면됨
# 정기검사때만
# 되잖아
# 빼놓으면
# 정기검사때
# 안고
# 키우겠다는
# 퇴사위험을
# 가방에
# 나와야됨
# 넣어서
# 들고
# 퇴사되면
# 노답인뎈
# 방에
# 본다고
# 나가게
# 박스같은데
# 놓지마셈
# 풀어
# 개작은
# 틈에도
# 들어감
# 아맞아
# 일이년
# 키웠었음
# 나오게
# 룰루
# 먹을거로
# 유혹해야지
# 개귀엽겠다
# 구경갈래
# 둘다
# 죠앙
# 어떤종류키워
# 두마리
# 키우는중
# 현양도
# 내이어폰잇지
# 지이언니한테
# 엏
# 납치오져따
# 낼주껭
# 오키루
# 루팡녀주현
# 마우스
# 언니에이은
# 루팡녀
# 키득키득
# 도벽터졌다
# 2차루팡한거
# 갑자기주현
# 룸메마우스
# 생각나서
# 개빠갬
# 두번이나
# 변준영선배
# 마우스를
# 가져가서
# 돌려주려고
# 마우스챙겨나왓는데
# 낰돜
# 돌려막기
# 지렸음
# 나놀러갈뤵
# 햄스터케우면
# 삼처넌이던데
# 이마트에서
# 보통일아님
# 이주에한번씩은
# 톱밥
# 갈아줘야됨
# 냄새
# 안그럼
# 오졌다리오졌다임
# 데려오면
# 마트에서
# 애들
# 스트레스받고
# 살다와서
# 열악한
# 환경에서
# 무서운애들일듯
# 찾아보게
# 말고
# 햄스터공장같은데
# 쓰다듬으려시도했다가
# 순한
# 손
# 절단
# 납치해와
# 자연에서
# 기르던거
# 예전에
# 데려온건데
# 문방구에서
# 기르고
# 세제통에다
# 많이줘서
# 양배추
# 불쌍햌
# 살개찌고
# 만지려하면
# 물고
# 세제통
# 갖다버림
# 엄마가
# 왠말이얔
# 양배춬
# 밥
# 원래뭐야
# 전용사료도잇고
# 야채조아하는듯
# 당근이랑
# 양배츄
# 아몬드
# 맞네
# 잘준건
# 오지게좋아함
# 해바라기씨를
# 너무먹었어
# 슨데
# 기니피그급으로
# 찜
# 살찌므로
# 좀만줘야함
# 기니피긐
# 해바라기씨
# 기니피그
# 살까
# 기르고싶은데
# 토끼나
# 금마들
# 똥우줌
# 못가리니까
# 윤지의카톡말투
# 카톡말투랑
# 똑같
# 현실말투
# 그녀
# 그니깐카톡에서도
# 사투리쓰는
# a
# its
# like
# tobaki
# 토박이
# 토박감성
# 나타나네
# 안느리냨
# 타자치는거
# 귀찬아서
# 나라면
# 열정대단
# 치다가
# Be
# English
# careful
# hi
# is
# joo
# 트럭운전중
# 개재밌땅
# Ok
# good
# 배그느낌난다
# 트럭운전
# 긴급서철
# 표절도검사
# 몇나옴
# 64프로나왓는데
# 높음
# 60몇퍼랬음
# 70퍼나왔다
# 정영현도
# 줄여서
# 첨에
# 아직안해봄
# 47퍼래
# 그래60몇퍼면그냥
# 안고쳐도
# 이주이
# 표절검사가
# 진행중이라고떳는데
# 블랙보드를
# 나갓다가
# 다시들어가니깐
# 됫음
# 다시들어가도
# 말해주
# 몇펀지
# 46임
# 떴는데
# 47
# 개적네
# 구글링하긴
# 했지만
# 구글링까지했다고
# 34퍼
# 지금냈는데
# 고쳐야되나
# 귀찮은디
# 와씨
# 60퍼나오고
# 고쳣나
# 물어봐주라
# 정영현
# 헿헤헤헷둥이
# 60나온겨
# 70에서
# 고쳐서
# 데
# 아그리고
# 꼭줘라
# 총총
# 아미칭
# 생각할겜
# 개기여워
# 괜스레
# 신비로운
# 오리들의
# 자태
# 본지
# 오래됏다
# 오리
# 없다고
# 할사람있다고
# 있오
# 10월
# 2일
# 겹치는거
# 교수님이랑
# 서철
# 시간
# 23일
# 겹치려낭
# 선택하게
# 시간이랑
# 신청하는데
# 해줭
# 링크보면
# 설명있음
# 방송은
# 아니제
# 계좌보내조
# 1002458184614
# 우리은행
# 마넌
# 보내조
# 주희도
# 올마욨지
# 얼마였2”
# 17000원
# 나왔었제
# 보내쑤
# 방송안
# 니지
# 보낼겡
# 택시비
# 상황이야
# 실제
# 개쪽팔려
# 메일
# 와있었음
# 송
# 앤젤
# 개친절햌
# 스윗
# 쏘
# tmi
# 이게바로
# 티티엠아이임
# 아미친웃겨
# 추석잘보냉
# 나온
# 마당을
# 수탉
# 다쳐먹음
# 아침으로
# 즐츄
# 안쪄
# 추석엔
# 정상이잖아
# 처먹는거
# 추석에
# 나야나
# 먹은거
# 보쌈에
# 산적이랑
# 한공기
# 개부럽
# 진수성찬이다
# 달보고
# 소원빌어
# 달이
# 안보여
# 여기는쿠
# 이뿌다
# 보름달이야
# 왕커
# 왕맛있다
# 왕크니까
# 언닠개뜬금
# 건대랑
# 체육대회암한댕
# 건대총학에서
# 문제생긴둣
# 난리다
# 난리야
# 그거말하는거지
# 줄다리기
# 그거도긇고
# 전부다
# 다취소된긋
# 온다는거도
# 유명한비제이
# 에라이
# 흐르수
# 달님제
# 식욕을
# 일반인수준으로만
# 줄어주세요
# 배경보니까
# 성공하셨나봐유
# 90점나옴
# 썅
# 나도임
# 80점
# 절대안고쳐져
# 변튜터가그러는데
# 문자안넣으면
# 0이
# 나와야된데
# 어디까지
# 80점나오고
# 문제도안읽음
# 잣돰
# 괜차나애둘아
# 아직월욜이야
# fuck
# programming
# u
# 포기할래
# 다못끝낼것같앸
# 어디까지했어
# 못하겠어
# 하고
# 할시간엊구
# 포기해야겤어
# 장문정
# x
# 생각이
# 0나오게하니까
# 백점뜸
# 야시부레
# 도전
# 진짜나도
# 우리삼촌
# 주목
# 주먹
# 도라에몽
# 주먹임
# 애기손같앸
# 개커
# 내손이랑
# 비교해서
# 찍을걸
# 안커보여
# 하나도
# 긴급사건
# 5번
# 되는교
# 안풀어도
# ※
# 가능하면
# 문제는
# 번
# 아래
# 옵션이니
# 풀어보세요
# 꺄아아아아아아아아아악
# 잌
# 안해도되는거맞쥬
# 대바가아아아아아앙
# 혹시모르니껜
# 다룬애들한테도
# 물어봐죠
# 3개나있잖아
# 4번
# 수요일
# 오늘한개
# 한개
# 되지않을까
# 를
# 목표로
# 굳
# 교수님한데
# 물어봐야되지
# 안을까
# 오번
# 2번하신분
# 다했을껄
# 이번
# 물어봄
# 긍정적
# 기대해봅니다
# 답변
# 놀러갈
# 땨람
# 올림픽공원
# 뭐햌
# 할거없나
# 안가봐서
# 가보고
# 시퓸
# real
# 거기가서
# 좋을것같은
# 줄다리기하면
# 평화로운분위기
# 갈수있을덧같은데
# 동아리
# 모르겠음
# 언제끝날지
# 놀러가장
# 이번주에
# 다음주도
# 빡세니까
# 엠티랑
# 이번주는
# 오키오키
# 귀여웡
# 잘어울려😆
# 해볼라는데
# 안남
# 엄두가
# 낼부터
# 할고야
# 남은거
# 맥주마셨는데
# 취해버림
# 동아리에선
# 술먹은뒤엔
# 누워있엉
# 잘자💕
# 큐티걸도
# 미쳤냐곸
# 쩔쩌리언니두
# 쩔쩌맄개오랜만
# 아진짜캐톡할때마다
# 이주히프사젤리퍼먹고싶음
# 책임져
# 목요일날
# 줄까
# 앗다욧트중인데
# 머굴랭
# 가져갈게
# 나는그럼
# 크리스피롤
# 개맛탱이겟다
# 뭐아
# 케
# 한가지만
# 언행불일치
# 탄로난
# 괜차나
# 언행불일치여두
# 먹고싶은거먹구
# 운동으로
# 조져
# 운동하기싫어용
# 지년영
# 개잘쓰네
# 와아아아우어아아앙앙
# 내일헤헷둥이
# 내일해야징
# 버스타고
# 서울가는길
# 오빠랑
# 재훈이
# 버스냨
# 진짜같은
# 충주
# 휴게소임
# 때리는중
# 먹을거
# 휴게소에서
# 15분
# 먹고싶었는데
# 개아깝다
# 기사아저씨
# 야박하시다
# 때리고싶었눈데
# 핫도그랑
# 상상만해도
# 핫도그
# 행복함
# 때리는수준이아니라
# 두들겨패야함
# 앉았어
# 옆자리
# 심심하진
# 않겠다
# 같이가면
# 되겠넹
# 명절때마다
# 앞으로
# 안심심하고
# 좋겠다
# 키야
# 또만들었누
# 된장
# 아니라
# 카레가
# 개맛잇겟다
# 헐된장임
# 엘에이갈비
# 최고
# 학정원으로
# 공수안감
# 쪽지시험쳤는데
# 먼저냐고
# 학정원옴과제하러
# 갈라구
# 마침
# 시험치는즁
# 진현영아직시험즁
# 시잘
# 지겹다
# 몰겠읒
# 왜하는지
# 권지용
# 인지용어
# 개노의미
# 왜함
# 애들아
# 문열엊
# 문열어줘
# thing
# 다덜
# 들어보세요
# 신곡
# 연애하고싶다
# 잡아줄사람
# 갑자기염
# 인생
# 짱이쁘다
# 찍자
# 개조음
# 술머글사람
# 심심한
# 00이야
# 그르게유나어차피지금
# 알바가늨즁
# 고기
# 깍뚝
# 맛이쏭
# 누구누구가써
# 우리둘
# 가기러함
# 헌팅포차
# 놀기로했어
# 건대생
# 들어왔으면
# 잘생긴
# 헌팅
# 미팅을
# 잡짘
# 무슨미텡
# 아낰
# 썰푸러죠
# 헌포갔다와
# 올
# 일단주현
# 가까우면
# 좋은뎅
# 경희대
# 안멀어
# 아그래
# 중간에서모이삼
# 앵츈
# 되겠네요
# 왕십리쯤
# 중간이
# 선차한명
# 나주현
# 정민이
# 안되는데
# 하게
# 바빠서
# 바쁜척
# 뭐하눈데
# 욥주
# 토일
# 부산친구오기로
# 해서
# 금욜도
# 금토
# 놀거같은데
# 일욜에
# 확실하진않지만
# 시간안맞으면
# 나빼구행
# 나상관
# 보조개수술했다요
# 니들만
# 비밀이야
# 아셈
# 안아파
# 완성작궁굼허다
# 한달정도는
# 부자연스러워서
# 마스크끼고다뇨야함
# 한달동안이나
# 완성돠면
# 존예일듯
# 완전히
# 자연스러워질라묜
# 거의한달
# 와진짴별걸다햌
# 보조개까지
# 속눈썹연장부터
# 나도보조개생기고싶당
# 개이쁨
# 금방풀리면
# 보조개
# 어떠카지
# 간건데
# 자연스럽게
# 해주는데라고
# 녹는실이라
# 풀릴수있데
# 내친구는코수술햇는데자연스럽게해달랫는데
# 너무자연스러워서
# 사람들아무도못알아봄
# 경우보단
# 낫지않을까
# 적어도
# 돈공중분해
# 오와
# 비해서
# 않음
# 이런거에
# 잘됬지
# 자연스러워서
# 첫날치고
# 걱정이유
# 밑에사람은
# 바늘로구멍뚫어논줄
# 완전개잘됨
# 밑에은
# 구멍뚫은거같다
# 마장
# 자연스러운게
# 잘된거지
# 리터치
# 풀리면
# 해준뎅
# 내고
# 실값3만넌만
# 해준데
# 앵간뛰
# 10시30인가
# 10시인가
# 30
# 안잤네
# 엉니
# 두번돌리니까
# 빨래
# 빨래두번왠말이얔
# 일오남
# 없지
# 틀별한거
# 배우는즁
# 특별한
# 푸아송분포
# 분포
# 푸아송
# 귀여워
# 일찍끝내주신다면서흑
# 담주에
# 이항분포부터
# 하는가햇는데
# 공설기는
# 몇시에해
# 1시반
# 좆됨
# 늦게
# 안올거
# 공결낼라했는데
# 송교수님꺼
# 송교수님한데
# 몸안좋았다하고
# 공결내야겠다
# 출석처리해달라하고
# 겨수님
# 그렇게
# 해주려나
# 될수도
# 메일보내면
# 뭐라하지
# Elp는
# 가야겠다
# 몸
# 안좋았다해야지뭐
# 몸안좋아서
# 못갔는데
# 출석체크해달라고
# 버내지
# 괜찮아
# 교수님이라면
# 송재욱
# 인정해주실거야
# 뭐하시죠
# 니인스타염탐
# 정보보호
# 임
# 열
# 스캔
# 아는사람
# 윤정환이라는사람
# 내동생이랑
# 이름똑같고든
# 오젺다
# 우연의일치
# 나갈분
# 현영인줄
# 30분까지
# 개기면
# 모든학생이
# 뭔데
# 상관없는거
# 손드는새끼들
# 이대로
# 이라고
# 개겨봤자
# 메일로
# 보내라할꺼임
# 머리잘하는데
# 건대에서
# 머리햇는데
# 미룡실
# 이름까먹음
# 쿜
# 구조체에서
# 퀴즈범위에들어가
# 6중첩
# 구조체
# 구조체심화내용
# 및
# 자기참조
# 이러케써쟈잇는부분
# 안들어간데
# 필립메라가
# 몰라유
# 밥머글사람
# 창토라엠
# 밥지금안머굴래
# 놉
# 우리동네
# 먼저강
# 안기다려도돼
# 주희랑
# 다음에
# 목자
# 존맛이게따
# 에바참치꽁치
# 써야겠당
# 에효효
# 니랑
# 공수공부하자
# 가르쳐준데
# 배우거싶다
# 오빠가
# 갈켜줬데
# 영현이한데
# 갈켜주는거임
# 나한데
# 영화추천쫌
# 장르말해바
# 놋북으로
# 맥주먹으면서
# 설치한기념으로
# 영화보게
# 와이파이
# 월플라워
# 제대로넼
# 우리집에서
# 잘래
# 낄껴하고싶다
# 헉쓰
# 고민되게
# 만들지
# 통함
# 울집에서
# 일잔함서
# 이바구
# 털자
# 무서운거보자
# 무서운거에서탈락인데
# 개존잼이겟다
# 내일으
# 안돼지
# 오늘말거
# 공부할꼬임
# 밖에서
# 집말고
# 귀찮음
# 끝낼수있을까
# 서철을
# 한시전에
# 걱정임
# 그게
# 언제까지인데
# 제출
# 수업전인데
# 너네집에서
# 생각해보니까
# 해도디긴하는데
# 영화보다가
# 잘거같음
# 추천쫌
# 존나꿀잼
# 한국영호
# 미씽
# 소공녀
# 해어화
# 봄
# 개꿀잼이겟당
# 안녕나의소울메이트
# 존존존나재밌음
# 한국거는
# 볼려고
# 또써야됨
# 시로용난
# 토론조라
# 하기
# 아까썼지룽
# 바꿨다
# 이불
# 추워서
# 개앵간이었는데
# 화이트톤
# 갑분핑
# 추워
# 너옛날에
# 쓰던거네
# 갑분헬로키티
# 들두
# 오게
# 야그걸
# 어케들고와
# 부쳐야짘
# 택배로
# 잘어울리는데
# 헬로키티
# 재훈선배랑
# 들어달라하셈
# 겨울이불
# 들고오는거는
# 에바임
# 갑분재훈
# 택배부쳐야지
# 들어봐요
# 슨빼
# 이것쫌
# 으응
# 아닌가
# 제훈
# 재훈인가
# 마는
# 모냐
# 재후
# 제훈은
# 긁적
# 이름도
# 배우
# 재훈선뱈
# 물어봤자나
# 그거생각난다
# 박정욱
# 화냐
# 박정우라고
# 한거
# 이사람이고
# 하자낰
# 제훈제훈
# 암
# 이사람
# 당연하지
# 당연하짘
# 저건또모야
# 존나마니봤는데
# 줴훈줴훈
# 화났떫
# 요늑힘
# 개콘인가
# 웃찾사
# 코빅인가
# 결혼했잖아
# 쟤네
# 코빅
# 웃찾사임몰라
# 결혼
# 다른애랑
# 한거다
# 제훈이랑
# 한거아님
# 나오던남자
# 안했지
# 줴훈이랑
# 결혼함
# 이사람랑
# 인스타잇는데
# 보고싶다
# 낙
# 이런게
# 인생의
# 갈걸그랬다
# 고구마전
# 존맛탱인데
# 내사랑
# 육전
# 파전
# 맛있겠다아
# 역시
# 쿠킹마마👍
# 산거야
# 만든거야
# 헐러러렁
# 거짓말
# 넷플릭스
# 회원인사람
# 가져온거임
# 쿡
# 회원인데
# 속았다
# 난아직집
# 영화관
# 왕십리
# 이거주현
# 이꺼다
# 기엽다
# 사야겠다
# 저거늠
# 언닌데
# 생곀
# 집인데
# 금방
# 나갈게
# 겨울느낌
# 물씬
# 만들옷다
# 소떡소떡
# 허
# 개맛있어임
# 소스
# 개꾸덕꾸덕해보여
# 떡꼬치소스
# 만들었쑴
# 고기로
# 보이지
# 맛있어보인다
# 고프다는
# 배가
# 점
# 배는고프구
# 졸린데
# 너무너무너무너무
# 송쨩
# 야오늘
# 잘생김
# 발했다
# 빛을
# 잘생김이
# 잘생김의
# 정점을
# 찍음
# 아조땐다
# 핸썸가이
# 옷이
# 굳임
# 아주
# 빨리가서
# 봐야겠다
# 수염의중요성
# 오늘옷이
# 공설기때
# 디스하려는
# 마음가짐이
# 보임
# 개잘생겼다고
# 내친구한테
# 말하고있었는데
# 우리교수님
# 오겡끼데스
# 찌찌뽕
# 디스하려고
# 옷
# 입고왘
# 사회생활선배느낌
# 뭔지
# 알것같음
# 바지
# 핑크색인거지
# 말하고있었음
# 인디핑크
# 정도로하자
# 방금너무대놓고바지열심히쳐다봤어
# 송xx교수님
# 상상안되는데
# 공설기
# 디스를
# 쒸발년까짘
# 아니무슨
# 나한테만해줬면좋겟어
# 취향이
# 하드하네
# 뭐냐곸
# 씨발년아
# 남았어
# 발표조
# 거의다
# 끛난듯
# 긑남
# 안끝났눈데
# 1번째
# 하고있음
# 밥먹꼬가라니까
# 기다리더라도
# 어쩔수
# 머말하는거야
# 못내소
# 기다리고
# 끝나기
# 제출할라고
# 아직1조
# 우리3존데
# 발표말하는거야
# 난아님
# 발표
# 하앙
# 걸려
# 2번째조
# 발표시작할듯
# 2등
# 꼴찌에서
# 나임
# 개신기
# 꼴찌아닌거
# 가라앉았음
# 저밑에
# 끝나는게
# 맨늦게
# 시험기간
# 언젠지아는샤람
# 25일
# 예스
# 모두들
# 민나상
# 슬리핑중이니현영이랑
# 점심먹을사람
# 우리먹늘건데
# 엗
# 현양도껴줘
# 지금먹어
# 광토
# 임지금은
# 같이먹자
# 뭐먹어
# 학식
# 광토로
# 왕메뉴도정해와
# 수업긋남나갈게그럼
# 밥먹었제
# 안머금
# 먹을거야
# 공설기임
# 나공설기야
# 먼저머겅
# 꾸엥
# 자
# 아련하노
# 깜짝이야
# 만든거였구낭
# 진현영이
# 그랬구낭
# 나저거
# 민지가
# 선물해줌
# 쓰라고
# 뒷북이야
# ⠀
# 웰시코기
# 이거봄
# 케이스사고싶어서
# 개쫄귀임
# 딱
# 현영이같아
# 개무셔
# 메이크업한줄
# 스노우임혼자
# 스노우야
# 쓸데없는말해
# 왜자꾸
# 한조꺼읽는데10분걸리네
# 일부러
# 쓸데없는말해서
# 시간끄는듯
# 진짜겁나시간꽉꽉채우심
# 갈싸람
# 셤끝나고
# 너네집갈꼬임
# 저기말고
# 저기랑
# 핑크뮬리보러가자
# 개웃걐
# 뱃놈각
# 개좋아하잖아
# 노는거지
# 시험끝나고
# 일요일날
# 나일요일에알반디
# 고고행
# 마쟈마쟈
# 툐에
# 토욜에
# 보러간다묭
# 주히
# 해리포터
# 그거도
# 맞는데
# 어쩌지
# 밤에보러가는거라고
# 한강이키마쇼
# 자전거타자’
# 따릉이
# 꺄호
# 칼로리불태워버렷
# 니동생임
# 다이어트중
# 동생도
# 미안하다
# 음식보고
# 하는거임
# 쪽팔렼
# 뭐야진짜나도첨봄
# 시작될라함
# 중2병
# 교복입을거임
# 받을때
# 보내당라하게
# 입고
# 입으면
# 없애버림
# 버렸다
# 없애
# 안보내줄텐데
# 어디까지임
# 통계시험범위
# 다라는디
# 렉처노트
# 6까지
# 챕터
# 웅마쟈
# 어휴
# 나왘
# 이종석이라
# 했던
# 나닼
# 맛있는거
# 머그러감
# 웬일로
# 공부하디
# 싫어서
# 먹으러갔다고
# 앙배불띠👍
# 남자애
# 저앞에
# 정영현이지
# 로이정
# 딱걸렸어
# 모야모야
# 눈치챈다
# 뒤늦게
# 둘이사겨
# 영현고기먹으러갔다매
# 윤지랑
# 야돈가지야돈
# 야돈
# 이벤트중이라서
# 1인분씩
# 공짜로줌
# 2이가면
# 2인분공짜
# 아늦게말해써
# 뭘사겨
# 밥먹으면
# 빠른년생
# 사기는거야
# 아니이주히가뒤늦게눈치챈다길래또사귀는거나만모르는줄
# 개웃
# 겨
# 편견없는
# 너네어서먹어
# 편견없는사람
# 깍둑갔어
# 다먹움
# 아직배부르다
# 깍둑
# 씨수넙
# 언니깨울라고
# 저나할라했는뎈
# 엌
# 긱사야
# 군자관
# 얼릉오슈
# 광토옴
# 인게
# 생각났어
# 오자마자
# 갔다오는중
# 계산기놓고와서
# 계산기
# 내꺼
# 군자가
# 어딤
# 나왔어
# 1층
# 오늘씨수업없지
# 씨수업있어
# 없겠지
# 여러분
# 추억이다
# 아시밬
# 아시발
# 양치하다가
# 존나웃겨서
# 치약삼킴
# 목표가
# 사업가인
# 필립씨는
# 알바를
# 피씨방에서
# 우교
# 이거도있음
# 나고딩때
# 안드감
# 쪄서
# 증말
# 풋풋했섰눈데
# 왘
# 학생같음
# 존너귀얍다
# 공부
# 어디서하는즁이얌
# 수특
# 개추억
# 나돈데
# 읭
# 밥은
# 개귀엽다
# 배창현
# 졸라웃김진심
# 과톡방에올려도됨
# 뭐머글건데
# 먹으면
# 먹음
# 뿌링클
# 올려도
# 캡쳐한거라고
# 하지마라
# 추천골
# 잘가
# 춘천골
# 먹
# 야무지게
# 이거보니까
# 치킨먹오싶다
# 공수팀
# 밤샘
# 하시나여
# 통계점수나옴
# 목표는
# 밤샘인데
# 공수버릴까
# 푹자고
# 행복할까
# 나을수도있음
# 풀수임을지도
# 밑이야
# 통계도
# 평균보다
# 나두야
# 이런건
# 잘하면
# 기말에
# 잘하자
# 약속안할래
# 나두임
# 낮음
# 우리는
# 슬프다
# 존맛탱❤️
# 아아아아아아앋
# 뿌링클이냐
# 나도칰힌
# 붐칰힌칰힌
# 다들렸대
# 속이는거아니고
# 나보고
# 신났었냐하면서
# 왤케
# 안들릴수가없었다고
# 내용도
# 들었데
# 그런것같아서
# 안물어봄
# 자세히는
# 아닐텐데
# 아니지
# 정우철얘기
# 했었음
# 그거만
# 아니면됑
# 그거눈
# 모르겠는데
# 움
# 건이오빠가
# 들은건
# 확실함
# 어켘
# 뻥이지
# 어떻게알아
# 그런얘기했었넼
# 배창현싫다고
# 빡쳐있암움
# 뭐알빠야
# 그러면서
# 떠들었냐고
# 작게
# 빡쳤던거아닐까
# 시끄러워서
# 건이오빠
# 얘기는
# 들리면
# 그랬던것같은디
# 들림
# 딴내용
# 그거들리면
# 다들렸다는거
# 뭘안다는거
# 그니딴
# 상태보니까
# 저샛기
# 못들은듯
# 얘기한건
# 얘기가
# 컸대
# 목소리
# 구분도
# 안갔을걸
# 들었다고
# 백퍼
# 갱
# 말한거고
# 목소리만
# 정호가한
# 발음같운거
# 안들림
# 모를수도잇을걸
# 말조심하자
# 윤지의보고
# 4명이
# 말한건데
# 7명
# 됐음
# 수다떤꼴
# 졸지에
# 됐다
# 구란데
# 안들렸다는건
# 들리긴했을텐데
# 목소리는
# 백빵
# 들렸겠지
# 목소리를
# 만나는
# 자리있으면
# 데리고가달라
# 다른데로
# 진지하게
# 말했음
# 그런듯
# 불편할까봐
# 응응
# 그런얘기했다고
# 에이설마
# 들렸다고
# 들렸으면
# 들렸대
# 들린건데
# 다들린건데
# 몰래듣고
# 앉아있었을까
# 시끄럽네
# 관심안가졌을걸
# 정우철은
# 정확하게
# 안들을수가없음
# 그런가
# 안들렸다함
# 그런거같은데
# 안심시킬라고
# 들렸냐고
# 얘기해봐
# 진지빨고
# 물어보니까
# 빨았다니까
# 진지
# 얘기했다구
# 건이오빠말고
# 이거진짜
# 다들린간데
# 추궁해주현
# 추궁하면
# 다말하는데
# 다말할걸
# 걔는
# 못들었댜
# 야구본다구
# 팩트인둣
# 귀마개
# 끼고있렀는데
# 소리차단안됨
# 그정도였다고
# 무슨얘기했었는지
# 떠오름
# 말조심해야되나봅니다
# 학교에서
# 뭔얘기를한거야케
# 이런저런
# 다들렸던거
# 자는거야
# 갈게유
# 조두순
# 출소함
# 2020년에한대
# 구쁘다
# 졸리다
# 아니내친구가
# 이보내주길래
# 뭐냐고햇더니
# 시방개웃김
# 너같다
# 친구도
# 광토에서공부중
# 늬에
# 야아직도
# 대구애들이
# 이지랄
# 급재이
# 뭔소린가
# 한참생각했넼
# 외로워
# 우
# 술먹자술
# 2차갈때
# 불러줭
# 집갔누
# 딸국질
# 오지게나서
# 산책
# 노는즁
# 되는부분이냐
# 뛰쳐나가면
# 곧있음
# 끝나
# 걔도
# 있자너
# 자고싶은데
# 잠이안와
# 서비스
# 영해노래방
# 오지게주내
# 괜히
# 영해텔이
# 영해텔
# 신나노
# 일어난쨔람
# 고객님
# 왜유
# 뭐하나해서
# 아무것도
# 안하구싶다
# 일어났지만
# 가고싶었는데
# 뭐하기
# 일어났어
# 자다가
# 뭐할거야
# 안했다매
# 얼른끝내
# 방굼
# 헐나도
# 가즈아
# 보러
# 아멎다
# 영화보는거
# 오늘저녁
# 이었나
# 예매안했다는뎅
# 보러가고싶엉
# 즂댔네
# 아구랭
# 영화보러갈래
# 빨리해야개따
# 빨리해
# 안지웠는데
# 화장도
# 지워
# 트러블나
# 맞징
# 몇시인가욤
# 몰랑
# 개꿀잼이겠다
# 12시야
# 알바끝나고오면
# 헷
# 답해야
# 일어나면
# 할것
# 빠르다👍
# 실천력
# 잇을거에욥
# 집에
# 상관없
# 암때나
# 좋앙
# 물만두
# 우동연가에
# 먹어야겠다
# 우동연가
# 조아하는데
# 낮에만
# 봐도안봐도
# 상관없공
# 영화는
# 못노는거양
# 알바끝나구
# 놀수있긴행12시에
# 평일로
# 할깡
# 맞춰봐서
# 나빼고놀고있오
# 노노논
# 밥먹었오
# 아니아닝
# 안됐어
# 일어난지
# 한시간도
# 같이먹을래
# 이따
# 만날깡
# 말리면되기때문에
# 머리만
# 4시20분
# 빨라
# 안씻었거든
# 101호
# 15730원이링
# 옹기종기9380원
# 9280이라되있어서
# 9280보냈느데
# 일요일에
# 일요일
# 모이재서
# 옮겼는데
# 일요일로
# 토요일영화
# 핑크뮬리는
# 윤지의집에서
# 놀면안댕
# 쇼핑하기로했씀
# 올거야
# 그영화
# 별류야
# 짬뽕집
# 학교
# 게으름부려서
# 쉬었음
# 포기하고
# 귀찮지귀찮아
# 강남지하상가가서
# 옷사러갈사람
# 강남
# 누구랑가써
# 존나맛있겠다
# 강남역
# 리뉴를
# 보아하니
# 윤지의책상이야
# 이쑤시개
# 낼이나
# 언제든
# 이쑤시개가
# 면봉
# 아맞넼
# 오지네여
# 추리
# 와저걸
# 다고
# 말이돼
# 노랑색은
# 단무지야
# 그림맞추기
# 이런거하내고
# 가치갈랭
# 옷사러
# 웅갈뤠
# 강남가
# 고터는
# 마니갔오
# 갈때마다
# 옷찾기
# 커서
# 힘들었오
# 매운갈비찜도
# 먹쟝
# 링크보낸거
# 가좋아
# 링크어디
# 숟가락
# 실화
# 긔엽다
# 숙다랅
# 숙다락은
# 강남이얌
# 링크도
# 내일같이가장
# 갈고야
# 강남가볼량
# 구랭
# 서고강다하고
# 씻음
# 청소했오
# 날자고
# 이런데나
# 빨리가자
# 핑크뮬리
# 화요일
# 가자가장
# 존예탱
# 눈썹
# 도전하다가
# 정리
# 피오지게남
# 저빨간점들
# 피임
# 시불
# 나보는거갘잖아
# 로션발랏는데
# 세수하고
# 개따가워
# 미침
# 어쩌다
# 저래됨
# 면도하다가
# 울집오니까
# 해달라하지
# 면도기로
# 에
# 그건아니구염
# 말하라햇지
# 윤지의한테
# 해달라고
# 눈썹칼삼
# 다이소엘서
# 흙흥
# 뽑지
# 눈썹미는데
# 눈썹칼로
# 핀셋으루
# 피가나
# 뽑는건
# 조또무서워
# 월욜날
# 시험치는거
# 맞나봄
# 시발
# 시험이요
# sw
# 뭐시기
# 뭔
# 시험
# 못봐도
# 상관없잖아
# 미쳤나
# 헤이즈오는대
# 그게문제가아니고
# 헤이즈요
# 보고싶어
# 헤이즈
# 몊시야
# 10분까지
# 6시
# 입실하라던데
# 31일이라더니
# 왜죠
# 필수야뭐야
# 신청했으면
# 시험쳐야됨
# 왓을걸
# 접수됏다고
# 언니햇너
# 신청하라고
# 당부하던데
# 나신청안햇는데
# 신청하라그래서
# 했움
# 나왜안알려줫어
# 얘기했을걸
# 한것같은데
# 바보
# 두시에
# 늦지말고
# 및친
# 나빼고
# 다신청햇음
# 없나
# 학번만
# 안해두되는거임
# 결석처리되는걸걸
# 장학금준다고그랬음
# 못받겠지만
# 개꿀이러구
# 개꿀이야
# 꿀이지
# 받을수
# 있어야
# 슬퍼
# 개꿀이잖아
# 장학금
# 깔아주는
# 사람들이야
# 결석처리이런
# 씨방
# 무슨요일
# 결석처리
# 교수님한테
# 말씀드리면
# 될거야
# 현영쓰
# 욕을
# 먹지않을끼
# 안보면안돼
# 안보고
# 블랙보드에
# 빨간색으로
# 생리공결
# 무조건하라고
# 내면안됨
# 친구학교놀러갈건데
# 괜찮은방법인데
# 으음
# 시발시발
# 5분만에
# 나오면안됨
# 잘볼샌각없음
# 인증시험때처럼
# 시밬
# 1시간은
# 쳐야하는가아니냐
# 암맬도
# 없는디
# 없어졌나봄
# 2차인증시험날짜가
# 갑분싸
# 오져버림
# 떳음
# 개그지같다
# 1차인증
# 2차인증
# 바로다음날
# 예고하는
# 문정씨
# 같아
# 살인예고
# 욕쳐먹을지
# 상상도안간다
# 꼴등
# 꼴등이야
# 그거세지
# 빨리준비하라
# 살인예곸
# 첫날
# 운갈래
# 아음성지원
# 개싫엉
# 눈썹피보여주면서
# 슈불
# 잔소리하면
# 피보고싶지않으시면
# 그만하세요
# 한마디할거임
# 무섭넹
# 윤지의가
# 생각낰
# 개웃겼어
# 따라했던거
# 밤새떠0
# 왜새
# 샐
# 생각을
# 이틀연속으루
# 갈수있겠엉
# 쿠쿠쿠쿠큐큐큐큐쿠쿠쿠큨
# 쿠쿠쿠쿠큐큐큐큐큐큐큐큐큐큐큐큐큨
# 만날때까지
# 생각즁이야
# 안잘까
# 만나고
# 어떡할라구구
# 개고민됨케
# 밤새
# 피씨방있었어
# 밤안샜는데도
# 다섯시에나왔는데
# 한시간만
# 나왔으면
# 다섯시에
# 자지
# 조금이라도
# 일어날수있을까
# 생각하지말구
# 일단은
# 깨워줄게
# 한시간뒤에
# 미치겠
# 와너네
# 일찍일어난다근데
# 일어나
# 깜짝놀럈어
# 깬건가
# 오늘만
# 1시로
# 미뤗어
# 자러갑니다
# 2시에
# 나오면되는거임
# 내생각에
# 못나온다에
# 조심스레
# 오키쓰바리쓰
# 1표를
# 던지고갑니다
# 왜미룸근데
# 12시에
# 1표
# 왜냐면
# 졸려서
# 지금일어냤는데
# 침대에서
# 밍기적거리거싶어서
# 열두시에일어날게
# 봐영
# 공구하자
# 개꿀조합
# 침대감귤노트북
# sm타운왔써
# 갈겡
# 정우철꺼
# 그데
# 다름
# 쇼핑하지웅
# 쉬는즁
# 알바하고
# 존나힘달어보여
# 개웃은
# 정우철옷
# 전민규옷도
# 찾아봨
# 갈색가디건
# 갈색가디건인디
# 다룸
# 민규❤️영현
# 제송
# 데싱디바
# 윤지의의
# 착샷
# 오또신가요
# 너임
# 존예
# 나도하고싶
# 윤지의손이구나
# 오오오오오오
# 맞음
# 모이는거
# 나눈가능
# 집가는길
# 통화가능
# 어케됨
# 머가
# 노는거얌
# 못놀것같다던딩
# 지의가
# 모여서
# 술마시재
# 그랭
# 9시반에
# 헤이즈옴
# 그거보고
# 술먹자는거
# 그때보고
# 시험임
# 씨없고
# 우리오늘
# 아뉘용
# 씨수업도
# 당근
# 오늘함
# 사험
# 안치면
# 안해준더함
# 출석인증
# 실습
# 그걸로대체
# 을
# 일걸
# 아함
# 너넨튜터링
# 따라그렸을
# 상상하니까
# 뒤지
# 올블랙의
# 카와이한
# 프로페설
# 오늘떠러
# 프로쀄서
# 오랴함
# 왜이랴
# 죽겠구만
# 이렇게찍자
# 각자
# 수업마치고
# 집갈거
# 뭐하는더임
# 시끄러운데
# 여학생
# 올사람
# 휴게실
# 영혀니
# 밥모거
# 밥안먹었음
# 잠안와
# 집오니깐
# 나올꺼지
# 있다가
# 윤지의만남
# 머래
# 머해
# 비흡연자의
# 슬픔
# 또야
# 미쳨네
# 난빵쪼가리
# 먹었는개
# 튀김쪼가리
# 노는거
# 돈가스
# 영롱하다
# 저거보고
# 너무맛있어보야서
# 룸메랑
# 먹으러옴
# 언니룸메
# 긱사에서봤던
# 그분
# 만남
# 소융대부스에서
# 운동장이야
# 미쳤당
# 볼
# 싸라암
# 축제
# 😛
# 미팅할사람
# 목걸이
# 해리포터교수님
# 오디갔냥
# 우리밥먹으러나와써
# 먹을
# 생리달력
# 안나오지
# 찾다가
# 이러고있었어
# 송재욱교수님
# 날인데
# 리즈
# 외모
# 가는길
# 단톡보고
# 퀴즈본다는줄
# 식겁쳒네
# 날이라는게
# 보이는거죠
# 어딜봐서
# 먼저
# 이런거보면
# 쫄림
# 아니윤지의
# 안가져왔네
# 안민망하신가욥
# 있고든
# 꺼냈지만
# 놋
# 말에
# 북을
# 펴지는
# 않는
# 충격받음
# 물섭취량이
# 하루
# 2L래
# 2L먹다가는
# 매일매일
# 몰랐니
# 살아야하기때문에
# 화장실에서
# 그러지
# 삶을
# 않는것뿐
# 정상적인
# 먹지
# 물먹다
# 하루끝날듯
# 2L다먹었다
# 시간이
# 읏챠
# 존나가겠다
# 화장실
# 야드라
# 퀴즈야
# 아니라곸
# 긱사가는제
# 도형이오빠가
# 수업가는중이라는거
# 퀴즈라서
# 다시긱사간다
# 돌아가다가
# 진혀녕믿고
# 호새끼
# 구라친거
# 딱봐도
# 양주영걔네가
# 호구
# 개흐구
# 깜짝놀램
# 오늘퀴즈본다캐서
# 댔네
# 오지말까고민하다가
# 왔다
# 외모리즈래서
# 훌륭쓰
# 쌤외모리즈라매
# 오느
# 구라쳤어
# 엉엉
# 오늘아니양엉엉
# 분명
# 존잘이얶는데
# 통계
# 그렁가
# 맨뒤에서
# 봐서
# 통계때도
# 평타였는데
# 덜깬듯
# 아침이라서
# 구로지마
# 불쌍해
# 아맞는말
# 뎨둉합니다
# 팬심입니다
# 나보다
# 난리였다고
# 다재다능하다근데
# 쌤
# 섭렵하고있어
# 우리프로젝트하는거
# 퍄
# ⭐️다음주
# 불가능이랭⭐️
# 이론시간
# 2차모의문제
# 있는사람
# 블랙보드에없어
# ⭐️
# 감사링
# 없써
# 같던데
# 내린거
# 긴급
# 지도교수상담한다고문자온사람없어
# 하기싫은데
# 누구시죠
# 송교수님임
# 지도교수
# 누구시죸
# 개인적으로
# 오는구나
# 야어떡해
# 오늘학교안간다해
# 20분정도하는데
# 별얘기안한대
# 상담
# 걍해
# 언젠간
# 해야될거
# 다른날해도되냐고말함
# 오늘은
# 좀전에
# 죽어도귀찮아서
# 오늘학교안간다고구라침
# 구라쳐
# 어쩔려고
# 시간표
# 않을까
# 못간척하면되지뭐
# 아파서
# 데헷
# 문자
# 아무한테도
# 좋은거야
# 씨프로젝트방금다했다썅
# 주석달아야돼
# yes
# 뭔겨수님
# 나는조윤식교수님
# 일학기때
# 했구나
# 안한사람맘
# 일학기
# 하는고야
# 하겠네
# 모르겠고
# 송재욱교수님은
# 안할수도
# 일학기때했으묜
# 조윤식교수님은
# 시간안된다거하몀되지
# 군데
# 먼가
# 아닌것갘은뎈
# 예의가
# 물어보는건데
# 시간되는지
# 시간될때해야지
# 예의문제가
# 일정문제인듯
# 그랬더니
# 다른날에해도될까욤
# 알겟다하셧음월욜에해야것다
# 다른날한다고
# 그래야진
# 거절
# 나는또
# 돌려말하는줄
# 엌케
# 밥먹음
# 먹기로해써
# 봉사하는애랑
# 연락왔는데
# 폰고장남
# 고장남
# 폰
# 폰꺼짐
# 이제일어남
# 먹었디
# 누구랑먹움
# 영주언니랑
# 미팅나간
# 여신호
# 우리그떄
# 라온인지
# 몰겠는
# 오빠하나
# 많이머금
# 술냄새
# 올라옴
# 어웈
# 먹자길래
# 술개땡겨서
# 연락와서
# 영주
# 미치겄쓰
# 개웃기넼
# 멍함
# 않하고
# 일어나긴
# 재밌었겠다
# 한명괌
# 솜사탕
# 살수있데
# 저기가면
# 굿즈랑
# 개좋겠다
# 같이가장
# 사줘
# 솜사탕좀
# 대신
# 솜사타아
# 너솜사탕산다고그랬자나
# 마트에
# 안판다고
# 산다며
# 인터넷에서
# 단종돼어
# 그럴려구
# 결제
# 안해쏘
# 거야
# 그거랑
# 똑같은
# 카드결제귀찮아서
# 뚝딱허면
# 해야겠다
# 잊고있었네
# 먹는
# 솜사탕산다고
# 대공원
# 어린이
# 들어가있는거이씀
# 통에
# 파는거
# 너무멀엌근뎈
# 왜사먹어
# 갈꼬야
# 단맛만남
# 맛대가리
# 없고
# 단맛이
# 100퍼인데
# 가자가자가자가자
# 달달한거
# 많이먹고와야지
# 100퍼
# 갈건데
# 인증끝나고
# 안귀찮을때
# 나못먹으니까
# 언니다줄게
# 그렇다면
# 사양하지않을게
# 쓰고있어
# 레포트
# 전시회온니랑가자나
# 공부시작도안함
# 나듀
# 내는데
# 둘려고
# 의의를
# 잘써야지
# 에이준다그랬자나
# 이거가고싶은사람
# 말행
# 롱패딩각이구먼
# 호오올
# 날씨강애
# 가보고싶었눈뎅
# 디뮤지엄
# 25일날
# 갈수있어
# 끝나던뎅
# 보니까
# 마이크가
# 캐리하나
# 마이크
# 안나오면
# 듣기싫더진짜
# 다할듯
# 지지직거리면서
# 할말
# 말이
# 안되는게
# 내이름이
# 듣고암
# 수상
# 받아주지마셈
# 안받아줄꺼임
# 구리고
# 내가봐도
# 반할얼굴은
# 살면서
# 쌩얼인데
# 처음으로
# 첫눈에
# 미칭
# 아졸라웃김화장했을때봣겟짘
# 존나웃곀
# “제대로”
# 반한건뭐임
# 그랬음
# 얺음
# 읽어보지도
# 제대로
# 11
# 공구
# 펩타이드샷앰플
# 앰플살라는데
# 살사람
# 두개
# 사서
# 쓰고뭐
# 없으면
# 좋아보인당
# 피부관리안하는데
# 슬슬
# 예방좀
# 주름
# 할려고
# 살라했는데
# 앰플
# 오일
# 좋아보이넹
# 뭐가좋아
# 광나고
# 속건성
# 없애주자나
# 오일이
# 살라구
# 수부지라서
# 잡아줘서
# 저것도
# 8처넌씩
# 뿌엑
# 점검중이래
# 같이주문할사람
# 구함쓰
# 배송비반띵
# 배송비가
# 배꼽이큼
# 배보다
# 고민좀
# 사쟝
# 이제일어났네
# 계절
# 계절아님
# 언니300이잖아
# 350대던데
# 300
# 잘봤더
# 일차
# 조져서
# 300이면되겠지
# 110점이라구
# 소리야
# 300점대임
# 들어보니까
# 체념했고
# 술먹고싶음
# 술먹는대
# 승준이네
# 끼자끼자
# 승준이랑
# 누구누구
# 민철이랑
# 승훈이랑
# 현진이지
# 쥰내잘봤는데
# 잘본거얌
# 안심해
# 계절임
# 빼박
# 계절이몀
# 아까운데
# 내한데
# 전부
# 다들켰어
# 술먹냐이지롤
# 즤이야
# 개미쳤네
# 감자탕
# 씨부레
# 와사비장에
# 찍먹하면
# 개꿀맛
# 와사비
# 와사비가
# 겨자
# 간장
# 씌붕
# 오졌다리
# 아아아
# 달려가
# 달려달려
# 소쥬
# 소쥬한잔
# 탁털고
# 국물
# 한숟갈
# 호로록하묜
# 호로롥
# 개맛있겠네
# 케이러고
# 서철가야해
# 졸귀네
# Kia
# 뭐야너도갔냨
# 나랑주현
# 지이언니보고
# 급
# 먹고싶어서
# 노래방까지
# 잔다
# 발놓지마라
# 종아리사이에
# 집도착했써
# 너두
# 당욘허지
# 볼얼을것같애
# 오늘의
# 최고의관전포인트
# 개쩌렀씀
# 시켜만주신다면
# 하겠습니다
# 싸움나는줄알앗음
# 공설기마치고
# 지오가
# 투표하러가젱
# 구렙
# 조앗
# 늬
# 시간에
# 열어
# 투표
# 소융대
# 씨실습마치구
# 투표는
# 튜표는
# 항상열려잇지않냐
# 몰러
# 과투표는
# 시간정해져이써
# 욐오키
# 오마이켓도리
# 마치면
# 밥머겅
# 갈거지
# 세시까지할듯
# 어억
# 3시까지한대
# 그럴듯
# 봉사와소
# 데스크보규
# 안내
# 안내데스크요
# tmi여럼메라
# 개꿀이네
# 수업중
# 뭐였어
# 안오냐니
# 탈락했자마
# 2개
# 광고
# 유튜브에서
# 보내는데
# 응웅
# 맘에드는거
# 하나는
# 맘에안드는거
# 해가디고
# 이유도같이
# 보내여조
# 써서
# 아하아하
# 동생이랑하던게임인데
# 이거나어릴때
# 개재미쑴
# 개마니했는데
# 틀린그림찾기하는중
# 고무신던지는거아님
# 옛날에하던게임
# 찾고싶은데
# 못찾겠어
# 얼음땡도
# 개재밌었는디
# 왕땈
# 이름개웃곀밍밍과
# 10일에
# 12월
# 공모전이라고
# 그은사
# 참여해서
# 청중평가단으로
# 누구한명
# 영주언니가
# 영주언니혜정이언니최주형선배랑
# 참여하는데
# 같이할사람
# 좋겠다고
# 줬으면
# 참여하면
# 가치할사람
# 이렇대
# 참여만
# 하면돤댕
# ☀️언제나
# 라온하게☀️
# 에어팟
# 가치하자
# 하면돼
# 할꺼임
# 하려고
# 과외라고한다
# 봉사
# 이거함
# 만드는거
# 보조쌤
# 애기들
# 짱귀야웠겠네
# 만들었는데
# 시작해
# 노랑쪼끼입구함
# 사투리듣고
# 우는거아님
# 우왘
# 하는거야
# 요즘애등
# 장난옶음
# 우리때랑
# 싸가지
# 당돌함
# 많고
# 아는게
# 다안대
# 알거
# 애들도
# 요즘은
# 유치원생
# 당돌
# 잼나겟다
# 민우의
# 빠요엔의뜻은
# 과연
# 뭘까
# 뭐야저게
# 빠이팅
# 프사부터
# 하자는걸까
# 민우다
# 그것의
# 빠요엔
# 의미는
# 똑같은거같애
# 민우
# 표정이랑
# 그것보다
# 야이씨
# 왤케무섭냐
# 개무서움
# 준나
# 하지
# 대숲에올리면
# 난리날듯
# 말할
# 사람으론
# 식으로
# 안보였는데
# 났나
# 화가
# 불참눌럿는데
# 아나알바때매
# 좀무섭
# 너한테
# 욕하는거아니야
# 절라무서움
# 준내무서워
# 야식행사
# 참여못하는게
# 준내아깝
# 야식만
# 챙겨가
# 빠르게
# 6시까지
# 안될껄
# 알바라서
# 도르륵
# 밥먹을거야
# 똑같자나
# 저번주랑
# 대답해줄게
# 뜰푸넴
# 엽떡먹기로했
# 5장
# 배고파지죠
# 이밤에
# 오졌다
# 이선균
# 흔하지도
# 신기방기
# 개웃겼어진짴
# 16900
# 벌써다먹었구나
# 개많이먹음
# 코노도옴
# 집바로갈거양
# 먹으러갈게
# 애들이랑
# 110485527332
# 신한
# 11700
# 4장
# 올려도되는가용
# 이것들
# 인스타
# 엌개옛날
# 나개멋생겼다진짴
# 종강기냠
# 추억회상중
# 그러다또늦게자고
# 개피곤해할거면서
# 영화볼거라구
# 영화본댔지
# 경상도
# 티내기
# 집도착했넹
# 가는중
# 가이소
# 가이소시부렠
# 세차하고
# 오앙
# 잘다녀와💕💕
# 허엌
# 삼
# 에어프라이기
# 우리집에
# 개쩌네
# 너대구언제갔어
# 원래있다하지않았낭
# 저번에갓다온임
# 아니아니
# 자취방
# 본집말고
# 삿다고
# 자취방에
# 대구인줄
# 아빠가사주심개꿀이다
# 꿈꾸는
# 자취생들이
# 받어라
# 새해복많이
# 받구
# 복
# 새해
# 받아💕💕
# 새해복
# 2019년두
# 마니받앙
# 화이팅
# 복받아
# 1분남음
# 갸아아아악
# 따랑해
# 많이받아❤️☺️
# 사랑해
# 오메데또
# 언니자화상이다
# 졸귀탱
# 니들도
# 3했니
# 파일입출력
# 프로젝트
# 안해써
# 아애
# 안내줌
# 2까지여서
# 2만
# 제출은
# 하라고는
# 했을걸
# 옹마쟈
# 아니였음
# 의무는
# 없씀
# 갈수있는데
# 이걸해야
# 개에바개에바
# 강의노트
# 따라하면
# 안되남
# 어뜩해
# 따라
# 할수가
# 변준영오빠한데
# 받았다
# 일빠로
# 이거해바
# 보여조
# 일케
# 공설기생각나
# 하이거보니까
# 맞는
# 성격
# 찾구있어
# 찾아서뭐하겤
# 스카이캐슬보는사람
# 소외감오져버림
# 나만안봄
# 개지려
# 스캐
# 보는데
# 안간지
# 일주일됨
# 헬스장갈때만
# 안본사람이
# 말이있씀
# 젤부럽다는
# 17개나
# 볼수있는게
# 있으미까
# 정주행해
# 메친너도보냨오키슨
# 빨리낫는법
# 혹시다래끼
# 다래끼나써
# 약
# 아니칭구
# 안낫나보
# 약먹어도
# 다래끼는
# 답이다
# 째는게
# 미나상
# 배탈나서
# 화장실에서비둘기날라다님
# 푸드덕푸드덕
# 먼소린가했네
# 근데수학학원알바가서도
# 배에서
# 먼소리야
# 갈매기까지
# 날라다녔나봐
# 낫던데
# 초기에는
# 가지마
# 정안과만
# 믿거정안과
# 나지금주현
# 온니랑
# 헌포
# 개에바
# 왕대박왔는대
# 아니구
# 클럽도
# 감주
# 더에바임
# 흡연실은
# 똥냠샤남
# 똥쌌는거같음
# 드르라
# 엥시바
# 드르라가
# 무슨말일까
# 한참고민함
# 자취한당
# 골라써
# 계약지금
# 이제혼자사는겨
# 언니기모노존예다
# 오마이갓뜨
# 개존예다
# 엨
# 내집생긴거같아서
# 꿀이야
# 사는게
# 좋겟다
# 학교랑
# 너네집쪽에서
# 쪼오큼
# 너네집쪽이야
# 호엥
# 수술낚는대정샌이업음
# 헐야
# 수고해따진짜
# 개안나
# 몽롱하다
# 수면마취
# 요양잘하고
# 쉬어야대
# ★☆★☆【내일개강】★☆★☆
# 방학
# 순삭이네
# 쿠폰이냐
# 무시하고싶음
# 스팸이라고
# 인지용
# 1교시
# 좟같다
# 얘드랑
# 잘다녀와
# 고객님💦
# 큐⭐️
# 두식이
# 잘크고있냐
# 8장
# 예쁨
# 입에
# 톱밥묻히고있는것도
# 개귀엽지암냐
# 우리보리
# 포메키우고싶다
# 화이트아니라도
# 색깔진짜
# 이쁘네
# 개쥬아
# 갈색빛이
# 더좋아
# 화이트보다
# 베이지가
# 귀여운거같음오
# 따뜻해보이고
# 존귀
# 헝
# 가지말라고
# 하는거같움
# 가져가고싶음
# 손가락4개
# 가렇더라고
# 본명뭐지
# 두식이임첨알앗네
# 본명
# 아직못정해쑴
# 정해줘
# 어이
# 짱두식이
# 이래불러서
# 네개임
# 발가락
# 다섯개임
# 엄청작게있더라
# 두식인데
# 결정
# 차두식으로
# 탕탕탕
# 차두식에바얔
# 우리두식이
# 갑분정
# 제말하면
# 호랑이더
# 개웃겨💦
# 지금봣다
# 열시수업인줄알고
# 세종관와서
# 있었어
# 헤매고
# 잘됬다
# 채플인줄알았는데
# 에타보니깐
# 휴강이어서
# 김영현은
# 집가고
# 광개토5층카페
# IM
# SO
# alone
# lonely
# so
# 아침먹음
# 과학사놓침
# 과학사
# 듣고싶지않다
# 야매해서
# 정현이는
# 카페가긴
# 밥무러옴
# 정현이는누구삼
# 정현이
# 여자같네
# 1002
# 257365
# 758
# 오처넌
# 저거야
# 직젝앞
# 개웃기다
# 에코백들여다보며
# 집에서나올때
# 빠진거없지
# 완벽
# 공책
# 안챙김
# 앤나
# 필통
# 하고나왓는데
# 인공눈물
# 원래안챙기는거아니냐
# 근데우리
# 어디로
# 세종관
# 감쨔
# 팔로우
# 안자는분
# 미치겠씀
# 왜왜
# 권도윤센빠이앉아있는거
# 내앞에
# 지하철탔는데
# 시롸냐
# 지각할듯
# 놀라며
# 인사•••
# 나근데무거워서노트북안챙겼는데
# 실습아님
# 율곡관컴터로하지뭐쪕
# 내머리
# 삼각김밥임
# 율곡어디얌
# 새캠갈까
# 대구가기
# 치과는
# 째고
# 치과
# 오셈
# 갈수있씀
# 민페아님
# 학생회에
# 개좋아
# 오면
# 가야지
# 다보낼때
# 말해주께
# 23장
# 12장
# 에바z
# 개재밌어
# 보여
# ‼️
# 당장이라도
# 만남가능
# 같어
# 마샤써
# 안될
# 술마셨써
# 김민준
# 다시보니까
# 저리
# 단톡인줄케
# 학과
# 민줌오빠개웃기닼
# 받아라
# 얍☆
# 개짜증나
# 버스
# 10분은
# 더걸리난듯
# 예상시간보다
# 수업서하냐
# 몇호
# 백팧
# 현영현
# 엽떡
# 5000원씩
# 보내소
# 보내쓔
# 넵썰
# 자다가지금일오남
# 불냉면
# 송주
# 같이사서
# 5인분씩
# 나눌사람
# 없써수명짧아질일있냐
# 퓨
# 놀사람
# 10시수업잉즐알고
# 지금옴
# 지각개삘
# 술먹을사람구함
# 유력후부
# 후보
# 꾸며서
# 쓸데옶이
# 뭐든
# 싶음
# 12시내지1시
# 78시
# 까지
# 부터
# 개오래먹네
# 가두되고
# 더일찍
# 보구
# 어디샴
# 썩어있어
# 으리
# 창토라에
# 우리확통프교수님
# 인간수면제라는데
# 그얘기
# 망함
# 인간수면제
# 상모돌림
# 하위
# 꾸벅
# 지대로네
# 미친지금봄
# 냈어
# 등록금낼때
# 학생회비
# 냈음
# 나도냇움
# 그거내면
# 야식행사공짜인거
# 싶다
# 커피마실
# 커피안마시나
# 못마심
# 커피
# 잠못잠
# 안하지
# 갈까
# 보리보셈
# 데꼬와
# 보리
# 수업시간에
# 델꼬
# 옴
# 네일
# 다시함
# 옹욍
# 언제해보지
# 손톱너무
# 짧아졌씀
# 가실
# 크니까
# 낮춰서
# 보셈
# 소리
# 아미친
# 보리만
# 때림
# 저고양이
# 개윳기넼
# 진짜개웃김
# 또봐도
# 또웃김
# 뽀쨕하다
# 암것두못해
# 윤지이말이너무웃김
# 앜윤지의말
# 지금들음
# 아악
# 넣고
# 와랄랄
# 해버리고싶어
# 올리다가
# 찧었는데
# 캐리어
# 아픔
# 내가다아파
# 미췽
# 세수어케해
# 신기한게
# 따뜻한물에
# 씻으니까
# 풀림
# 피뭉친거
# 어우양아억
# 내가더아픔
# 으시부레
# 배고파죽겠씀
# 머좀사와
# 배고프댘
# 치킨팝
# 억
# 먹는거야
# 언니지금
# 먹고이떠
# 양념게장있따
# 밥먹을사람
# 개행복
# kia
# 간담
# 데리러
# 햄찌
# 또사러간다고
# 한삼십분있다가
# 너무귀여워
# 사는거야
# 우리햄찌도
# 찍어야겠다
# 고슴도치키울까
# 고슴도치키우려면
# 전기장판도
# 사야함
# 온도높은데서사는애라서
# 따뜻하게
# 해줘야한데항상
# 도치전기장판팔더라
# 걍안키워
# 유튜브보고
# 고슴도치
# 키누고싶었는데
# 개겨워
# 키우고싶운데
# 토끼도
# 심장병있다해서
# 동을
# 존나많이쌈
# 토끼
# 아맞네
# 컵안에버블먹고싶어서
# 사러가는길
# 와근데
# 날씨개좋음
# 옷입기귀찮아소
# 나시만입고
# 롱퍄딩입었는데
# 더워디지겠씀
# 돌앗냐
# 롱패딩
# 개꿀잠잣음
# 밤에잠안와서큰일나것다
# 횬용이
# 쇼필
# 존나하고있는데
# 살라하다가도
# 일반인후기보고
# 존나빠꾸침
# 블랙쿠션삼
# 몇호샀누
# 13호
# 21호
# 위에부터는
# 밝아지는게
# 톤이
# 갈라지는거래서
# 로즈냐
# 아이보리냐
# 15호는
# 핑크베이스라소
# 옐로베이스로13호삼
# 발강지는줄
# 다시골라야지
# 알아보고
# 고창석닮은
# 발견
# 유튭보다가
# 이메일인가
# 수업안온다고
# 개빡침
# 쉬벌
# 고무잇으신분없겠지
# 개시러
# 고무없냐
# 데분계
# 모르겠디
# 뭔말인지
# 영상
# 왜보는지
# 아느사람
# 수업만하면
# 심심하다고
# 지루하다고
# 의미없다
# 저게더
# 갑
# 시간보내기
# 의미없이
# 더심심하누
# 심지어
# 안보임
# 자막도
# 밑에잇어서
# 작게보여주지
# 화면
# 러시아언지
# 영어인지
# 인투루팟투루쉬멩슁엥
# 안봄
# 봣음
# 5번넘게본듯
# 오지게틀어줌
# 중딩때
# 먼데
# 세얼간이
# 보여줄때마다
# 짤라서
# 저장면
# 보여줌
# 세얼간잌
# 틀어는주는데
# 재미없을거같아서
# 개꿀잼이삼
# 엠티가니
# 술집
# 하굑근처
# 뚫리는데
# 엉맥
# 홍포
# 가도안하려나
# 소수로
# 모루겠는데
# 홍포는
# 엉맥은
# 기억하는데
# 없어진갈로
# dho
# tnfajrdmaus
# 나도갈래
# 술먹으면
# 과팅때문네
# 일학년애들
# 류준열
# 보자봅자
# 재밌는거
# 숏텀12
# 업
# 옥자
# 콜로니아
# 굿플레이스
# 미드는
# 잘안보는뎅
# 재밌대
# 맞을듯
# 취향에
# 굿플봤써
# 다봤어
# 볼래
# 재밌으면
# 보다
# 재미없어서
# 넷플릭스는
# 결말흐지부지하고
# 느낌없이
# 탄탄하다는
# 보는거임
# 저냥
# 코미디만
# 산타클리라타
# 개웃기고
# 거는
# 웃긴
# 크엑걸인가
# 웃기다던데
# 걸프렌드
# 크레이지
# 로맨틱한자세
# 상사에대처하는
# 배드맘스
# 대터하는
# 로맨틱한
# 상사에
# 자셐
# 개웃기지
# 같앜
# 내용을
# 알
# 스파이도
# 웃김
# 봤어
# 재밌엄
# 저거봐보
# 말도안되는거라고
# 소재가
# 재미없을꺼같은데
# 개윳김
# 감명깊고
# 끊었으니까
# 요즘일찍일어나시네염
# 객관적으로
# 말해줘
# 나은지
# 3번째
# 개이쁘네
# 4
# 5
# 2아님
# 내적갈등오지네
# 다르노
# 스트레스받라
# 결정장애라소
# 아으
# 올려버려
# 수렴해서
# 올렸쑨이다
# 의견
# 예뿌지
# 필터씌우니까
# 존예시네염♡
# 무엇인가염
# 인생렌즈
# 이거염
# 전나
# 낀듯안낀듯인데
# 안낀거
# 키레이네
# 렌즈사서
# 산더민데
# 실패한것만해도
# 드디어
# 인생렌즈삼
# 살라그럇는데
# 작은거
# 직경
# 어디까야
# 개눈되서
# 끼면
# 계속실퍄했눈데
# 개좋음
# 렌즈미
# 2마넌짜리
# 예쁠듯
# 안나는데
# 티많이
# 예뿜
# 나는거
# 안
# 찾고있었음
# 티
# 개눈됨
# 좀만
# 커지면
# 그랴서
# 렌즈걍
# 안꼈는데
# 못생겨보여서
# 4월에
# 산다
# 까먹지말기
# 겨드랑이에
# 파묻히겠는데
# 보리닮앗어
# 보리도
# 저럼
# 생리터져서
# 배아파서
# 일교시
# 배졸라고파
# 너네밥먹을거야
# 이수업마치고
# 난안먹울랭
# 뚝배기불고기먹고옴
# 아침
# 안먹어
# 지굼은
# 계란후라이
# 스팸
# gr이겠네
# jmt
# 웹프도
# 생리해서
# 안좋음
# 컨디션
# 써
# 메일보내면됨
# 메일로됨
# 확프도
# 써도
# 상관없지않음
# 달에
# 쓸수잇는거
# 2주에
# 한번쓸쑤있씀
# 갈라고
# 확프는
# 고생할만한데
# 말하시는거보면
# 여자친구가
# 뭐라캄
# 못들었는데
# 뭐라하는데
# 여자친구땜에
# 자기
# 힘들었다고
# 여자친구
# 그걸말해야했나
# tmim
# 근까
# 언제끝나
# 수업에반데
# 김민준은
# 이수업도듣나싶어서
# 김민준찾았음
# 니찾는다고
# 두리번댔고
# 아까는
# 다른거
# 하는듯
# 후에에에에에
# 생리
# 가고싶은데
# 좆같다
# 언제끝내줌
# 그만만들었으면
# 아기집쫌
# 자궁
# 남친도
# 헛수고
# 만들때
# 애기
# 알려줄테니간
# 작작했으면
# 보러갈사람
# 어스
# 영화관가면
# 요줌
# 고냥꿀잠
# 자버려
# 무서울듯
# 조온나
# 놀았써
# 몇시까지
# 마지막까지
# 기다리는중
# 집어는길임
# 버스기다림
# 놀이공원
# 놀아쎄
# 빡세게
# 놀았네
# 개재밋어보임
# 보니깐
# 어딨쌈
# 참여하지못한
# 톡방에잇엇는데
# 도착하자마자
# 이공육
# 조지기
# 안갈수도
# 80퍼
# 맘먹엇음
# 피곤할만함
# 나와라
# 심심하니깐
# 잤눈대
# 꿈꿈
# 무서운
# 좀비꾸
# 무섭더라
# 좀비가
# 자고일어났누
# 키크는거아님
# 무서움꿈꾸면
# 무사웠씀
# 절라
# 생생해서
# 깨고
# 했쑴
# 터져서
# 빌려서
# 어떤차를
# 도망치는데
# 다닫고
# 창문
# 가는건데
# 겨우
# 운전해서
# 꿈속에서도
# 가족들은
# 살아있을까
# 생각함
# 이란거
# 생생한뀸
# 데드라이프봄
# 웹툰
# 개쩔었씀
# 몰렸는데
# 사람들이
# 우리차
# 탈라고
# 닫아버림
# 열릴까봐
# 꽉잡고감
# 개무서웠겠다
# 으
# 극한직업
# 꿈꾸기
# 교내봉사할사람
# 나할까
# 뭔뎅
# 뭥밍
# 언젠
# 안남았가
# 이거밖에
# 다참
# 월수햇는데
# 할까
# 신청이라도
# 해놔
# 되니깡
# 취소하면
# 하기시름
# 4월2일꺼
# 연속으로두개신청함
# 화요일꺼
# 3자리남았음
# 게임중이라
# 신청한다
# 이거하고
# 그사이에
# 사라지진않겠지
# 세자리가
# 봉사해야하은데
# 뭔종사야
# 봉
# 나유체크
# 이의신청했는데
# 확통프
# 처리했습니다
# 라고옴
# 졸귀교수님
# 넹이래귀요미
# 세사봉이욤
# 교내봉사
# 두개함
# 혀녕나도
# 화욜거
# 같이안하면
# 봉봉봉
# 신청해놓고
# 앗싸뵹
# 우리여봉
# 덮친다
# 확마
# 으악
# 실습푸는중
# 3시에만나기로했는데
# 실습다못하면
# 잣됨
# 난걍
# 실습시간에
# 하겠어
# 어려움
# 에바적으로
# 절대못함
# eva
# 상상도못한정체냐
# 쉬바
# 실습다해도
# 한다던데
# 구라
# 9시반에깨워주심
# 아침먹고또잤는데
# 할머니한테8시반에깨워달라햇는데
# 두눈을
# 의심했음
# 날숨땜에
# 따스한
# 쪄죽겠음
# 마스크개싫다
# 마스크
# 미세먼지쓰
# 심각쓰
# 1번부터
# 막힘
# 나도1번하는데거의한시간걸린듯
# 5번이
# 장난아님
# 2차원배열쓰는거마즘
# 뒤집기정보
# 지려버림
# 뒤집는거
# 2차원은아닌디
# 일학년
# 2차원은
# 아뇸
# 풀었잖아
# 그때의
# 기억은
# 1학년꺼인거같긴
# 한데
# 기억이
# 없네
# 인증시험때인가
# 2번이
# 모르겠씀
# 기억에
# 안된다굿
# 의존해서
# 풀면
# 데분계시간에
# 고민하다가
# 3번만품
# 아닌뎁쇼
# 데분개임
# 데분계아니거
# 인뎁쇼
# 데분계랰
# 쟤맨날
# 변준영도
# 우곀
# 그랬는데
# 컴퓨터
# 파일
# 해놓은거
# 스발
# 대분개로
# 바꿔줌
# 맞는뎁쇼
# 아닌데유
# 데분개
# 이상함
# 데분개로
# 해줌
# 난지금
# 뭐라시는지
# 1도모르겟음
# 그림은
# 왜나온겨
# 추상
# 몬드리안
# 귀에
# 안들어옴
# 맞아따
# 몬드리안맞넼
# 맞춤
# 더할게요라니
# 조금만
# 시발방
# 언제까지해
# 볼게요
# 이것만
# 계속봐
# 유
# 휘
# 계속함
# 쉬불
# 너무무시하는건가
# 다들알죠
# 알아요
# 계속하시넴
# 당연한
# 얘기를
# 이것만빼도
# 벌써끝남
# 48번은한듯
# 저말만
# 위
# 더추가됨
# 사부레먹고싶다
# 거니깐
# 마치는
# 다끝내세요
# 이거피피티
# 사브레아는사람
# 과자임
# 여윽시
# 알앚네
# 알아주네
# 아도람
# 나도람
# z
# 모르면
# 사브레
# 개많이머금
# 초딩때
# 개많이쪄
# 다이제급임
# 맛있는건
# 갈색
# 배경의
# 빨간글씨
# 어디서봤어
# 달달구리함그거
# 옛날과자
# 고소미
# 관리잘못할거같으면
# 그만두
# 당장
# 남는게
# 시간이라소
# 눈
# 멀었지
# 인건비에
# 관리
# 잘하거든
# 영현이옆에사람도
# 손들엇는데
# 초스피드로
# 손듦
# 웃는데
# 개빨리들었어
# 치즈라면이야
# 이여
# 우리이거핳램
# 하자하자
# 메세지
# 보내떵
# 말해쥬
# 할사람
# 4월
# 오전이면
# 엔터식스갔넹
# 하냥대
# 갔는데
# 사려고
# 피규어
# 개비싸서
# 구경만
# 수업이떠
# 오전에
# 강주현바쁘게
# 다니는거봐
# 지땨
# 글쿠만
# 땜에
# 못찍겠다😭😭
# 널구있어
# 띵가띵가
# 저게뭐유
# 페북태그했자너
# 페북알람이안왘
# 보린데
# 얘도
# 보리랑
# 완전다른데
# 더예뻐
# 쟤가
# 더귀여워
# 우리보리가
# 너네오늘도
# 쥰내배고파
# 두식이랑
# 안날뛰누
# 꼬리털
# 고것만
# 유튜버접수함
# 교복입음
# 100만
# 유투버임
# 질올
# 질올이뭐냐고
# 놀리겠지
# 아싸네
# 개아싸
# 샘나누
# 유투버
# 오른팔걸께
# 정현이가
# 찍었다에
# 최소
# 댕강
# 말해봐
# 사실이야
# 정확한듯
# 지룠다
# 깜짝놀랬네
# 무슨얘기결론
# 1명
# 대답하는사람
# 물은사람0명
# 쉬밬
# 아니대답좀해달라
# 이거를
# 늘려서
# 말하네
# 몇배로
# 결론은
# 자기도
# 자신감을
# 키웠다
# 결론
# 최종
# can
# do
# it
# you
# I
# because
# 학교탈출
# 개아깝다고
# 생공쓴거
# 붕어빵
# 자색고구마
# 지금의
# 행복
# 먹고오세유
# 아침을
# 젭알
# 졸려
# 개잔와소
# 안씻고
# 출튀할까
# 잠깨
# 카톡보내다
# 출튀한다
# 출튀할바에
# 메일보내삼
# 얘드라수
# 가는게나음
# 안오고있잖아
# 들어가기좀그런데
# 출첵함
# 밖임
# 딱히안와도
# 미친근데
# 낮어서들어가기
# 늦게와
# 맨뒤에앉음
# 강의노트보면
# 이해가능
# 들어가기
# 뚫고
# 미앙
# 민망쓰
# 진혀녕빼고
# 맨뒤
# 앉아버리기
# 만나요
# 무슨날이가
# 늦었노
# 8시에일어나서
# 화장다함
# 1교시라서
# 개쩌네염
# 수업안듣고
# 화장함
# 웹프
# 메일보낼까
# 어떠케생각하니
# 개피곤
# 아사람
# 언젠지
# 우리무슨
# 있었지않냐
# 참여하고
# 휴강하는거
# 뭐했냐
# 웹프시간에
# 내일이라했잖아
# 웹프교수님이
# 휴강임
# 그렇다더라
# 참여해야지
# 휴강인거야
# 강의들어야됑
# 그대신
# 참여안하면
# 강의가
# 1도몰르는데
# 긍까
# 내일임
# 자료구조안가
# 12
# 오라카려나
# 시릇
# 휴강한데
# 개행복이데
# 빠지면
# 자료구조
# 실습안해도됨
# 개꿀딱지
# 들어야함
# 들으러
# 신청만할거임
# 마쳐
# 12시
# 이고
# 고를꼐
# 뭐냐
# 고르세여
# 사무부
# 입금해
# 송준규씨
# 님들아
# 과제에서
# 이부분
# 내부
# 참조라는말이
# 저건또
# 눌럿을때
# 어디다른페이지로이동하는게아니라
# 같은페이지않에서
# 또있씀
# 웹프과제
# 이동하도록
# 하는거냐
# 이번에한거
# 저거뭐엿지
# 눌렀을
# 뜨게하는건가
# 페이지
# internal
# reference면
# 다른페이지뜨는게아니라
# 같은페이지에서
# 뜨도록
# 하는거아녀
# 뭥미
# 혼란
# 모르겟다
# 안한것같은디
# 필수임
# 안함
# main
# page
# 설명하는
# 부분에
# 들어잇는거임
# 내부참조가
# 안에서
# 열려야함
# 웹페이지
# 거기로
# 누르면
# 열리는게아니라
# 이동하는거아니냐
# 몰라수벌
# 아몰라
# 안해야겠다
# 뭔지모라겠지만
# 안했음
# 교복입고
# 벚꽃보자
# 교복입자하눈데
# 빠꾸먹음
# 가져갈깨
# 낭없는데
# 어디가쑈
# 언니교복
# 버린지
# 양산에
# 털밀려서
# 왠모르는강쥐가
# 집에있씀
# 쳐다보면
# 무서움
# 보리아니지
# 쟤설마
# 마줌
# 충격이다
# 털빨
# 귀가
# 생쥐같앜
# 못생김
# 모르는강아지랰
# 들어갔는데
# 보리야하고
# 강쥐가
# 모르는
# 왠
# 있어서
# 잃은거니
# 충격에
# 보고깊다
# 하지마아영상
# 야하지마아
# 단단히
# 화났음
# 집착쩌네
# 친구들
# 마음이
# 착잡하다
# 나는근데
# 동시에
# 하는게
# 안그러냐
# 난중고등학겨애들이랑
# 무리로
# 안놀아소
# 가끔만남
# 구래근데너같으면
# 어떡할거같냐
# 이상황에
# 착잡
# 집착해줘
# 집착하
# 만들기
# 착잡하게
# 너왜
# 안널아
# 우리랑
# 남자친구
# 내상황
# 두명사귀는거같음
# 알바만가
# 왜맨날
# 고딩친구들이랑만
# 꽃구경
# 현영왜
# 연락와소
# 한빈이
# 술먹기러
# 했거든
# 준범이
# 01을
# 왜젛아하냐고
# 개무서워진짜
# 야이거봐
# 진지한데
# 쳐맞고있다고
# 야잔심
# 급인데
# 여친달래주는
# 남친같으멬
# 고칠게
# 오해풀어줘큐
# 다빠지것누
# 머리털
# 잘나옴
# 너무야해이자식아
# 쇄골까지
# 자르셈
# 이게더
# 저거보다
# 비슷
# 단발일때
# 개이뻐보임
# 주지마
# 혼란을
# 어진짜
# 예뻐보여
# 개빠앗는데
# 개이뻐보이지
# 해피엔딩
# 그저
# 멀리서
# 지켜본다
# 시롸야
# 군대가누
# 그러고있엌개웃겨
# 진현영은왜또
# 카톡안하는거
# 포기했던뎀
# 아씨발
# 개좆같음
# 기터브에
# 올리면
# 깨짐
# 자꾸이
# 나랑똑같네
# 나그래서교수님한테
# 메일보냄
# 보여드린다함
# 자꾸깨져서월욜에
# 그랫더니
# 그럼코드만이라도올려놓으래
# 계속해서
# 개빡칠뻔
# 집념의윤지의
# 어케고침
# 깨지는
# 들
# 지우고
# 다운받고
# 코드파일도
# 복사해서
# 코드만
# 파일지우고
# 새로만듬
# 복잡햇네
# 막노동
# 뒤질뻔함
# 좆같아
# 개같은코딩
# 이상해
# 개이쁜데
# 이쁜데
# 달라버옄
# 뭔가어두운색
# 좋았움
# 뭔말이야
# 케나도
# 해석쫌
# 말로못풀겠는뎈
# 어두운색인데
# 분위기가
# 좋았다
# 쨋든
# 좋은말이야
# 나쁜말이야
# 불호야
# 호야
# 이단톡은
# 예쁘다
# 케서
# 눈주변이
# 대구친구들한데
# 욕머금
# 욕먹을
# 셀고라캤다이가
# 별로임
# 실물보단
# 쎌고라고
# 실물이
# 은데
# 20장찍어서
# 건진거임
# 난뭔가
# 셀카
# 얼굴대칭이
# 젤중요한데
# 별루얌
# 이건별로야
# 늑낌이안옴
# 시강
# 어머니
# 튜터링하는건데
# 바탕화면
# 찍었네
# 도랏냐고
# 인스타에
# 업로드했다
# 별론가
# 아무말도안했는데
# 별로면
# 내리게
# 이뽀
# 개빨리
# 와버림
# 떠옴
# 투
# 하지마
# 누구냐
# 야근데
# 수열에
# 수열말고
# 어대나
# 한강가자
# 요렇게
# 흔적찾움
# 난지
# 어케앎
# 딱보면딱이지
# 못찾음
# 훃
# 못봤아
# 유니콘은
# 앗아
# 못봤어
# 솜사탕먹늠다고
# 가지런하다
# 우악
# 가치
# 버섯이랑
# 옴뇸뇸하고싶다
# 맥주도
# 버억
# 누구랑갔냠
# 동생각
# 내동생
# 초딩이라고
# 다커
# 초딩
# 아빠각
# 반응봐
# 이카다
# 남친생겨도
# 시벌
# 했써
# 공부함
# 뭐보고
# 오이고
# 비원안간이유
# 저거였구만
# 주히지금가는중
# 비원가는길이라고
# 나왔는데
# 에공
# 보고는시픈데
# 개피곤해서
# 꿀잠자
# 영화보면
# 재미없다는지
# 개무섭다아님
# 공포의묘지인사
# 많은
# 숨겨진게
# 영화라서
# 다보소
# 무서워서못보갰움
# 재밌겠데
# 영화임
# 해석찾아보는
# 그럴게
# 무섭진안음
# 사바하보다
# 안무섭
# 겟아웃보다
# 무섭지는
# 생각하게되는
# 걍봐
# 장난스런키스랑
# 보러감
# 장난스런
# 말싸
# 씻을까
# 까
# 씻어
# 넹0
# 이언니만남
# 아닌
# 구냥
# 남친생김
# With
# 씅
# 그겈
# 하는
# 한건뎅
# 슬프게
# 왜구레
# 남친업쏘
# 알았엌
# 지의안옴
# 앞줄에
# 퀴즈안봣으면좋게사
# 안볼꺼같음
# 안볼각이다
# 사랑해요
# 송재욱님
# 공부햇냐
# 긴장
# 늦추지마
# 아니근데
# 안볼각임
# 재욱상
# 훼이크의
# 달인임
# 10시에
# 마치지
# 안흐
# 봣엇자나
# 수업다하고
# 퀴즈보는날도
# 휘발
# 안볼듯
# 어대가서
# 볼각이라던데
# 벚꽃볼분
# 멀리서만
# 벚꽃
# 어대갔는데
# 주말내내
# 쥰내
# 쳐다보고
# 가자니까
# 수욜임여
# 그거끝나고
# 다녀오자할랬는데
# 웹프끝나고
# 호딱
# 수욜날
# 끝날시간아냐
# 오늘이
# 꾸미고온
# 몇안되는
# 알바간다고
# 진현영은
# 모간대
# 못간대
# 집착해주자
# 확통프끝나고
# 집착
# 왜수욜임
# 수업도
# 일찍끝나자나
# 화욜은
# 위에
# 올려봐
# 구지
# 확통프퀴즈끝나고
# 공부하려고
# 킨함
# 화욜에
# 영현이는
# 수욜이
# 잠시다녀올거아니얌
# 다녀오는거
# 찍을거
# 간다는데
# 끼삼
# 갔다오자
# 여유롭게
# 낄껴씹가능
# 난수욜좋아
# 가치가
# 그건너무니말툰데
# 뚜요일
# 야가치가
# 야하지마
# 이거가튼데
# 꾸미고왕
# 수욜에도
# 특징
# 이미놓쳐서
# 듣고싶다
# shi
# 송재욱님과
# 스바라
# 아이컨택
# 개불안하네
# 스바라쉬개웃기네
# 천둥번개침
# 아직그럼
# 놀건데
# 우이랑은
# 실망이다
# 개터졌네
# 스바라쉬
# 몇신데
# 바로일껄
# 6시까진데옹
# 바로가야댐
# 확통프4시에끗나면
# 5시까지는
# 볼수잇음
# 1시간있네
# 1시간동안
# 찍다가
# 나가던가
# 단톡방에서
# 눈감고찍을거면서
# 볼한쪽에올리고
# 손바닥하나
# 찍을때마다
# 씹소름
# 고정포즈
# 윤잘알
# 만점
# 테스트
# 팔불출인줄
# 안가리고
# 찍을꼬임
# 굴애
# 삼각대
# 없냐
# 나있는데
# 이쓸걸
# 갖고
# 오삼
# 버튼누르면
# 갈때
# 몇일전에
# 찾았는데
# 셀카봉
# 그거도있삼
# 없움
# 도라에몽이냐
# 가족들이랑
# 돈많이
# 만든사람
# 벌어서
# 외국으로
# 이민갔데
# 인생은
# 한방
# 그럴만함
# TMI긴한데
# 개발해야겠
# 뭐쫌
# 상식
# 위키백과임
# 삘받았누
# 재욱씨
# 나오니깐
# 외워둬
# 테스트에
# 아존나
# 에잉
# 멈출듯
# 에에에에에이
# 에이비
# 고양이
# 새끼
# 못됬씀
# 갔을떄
# 퀴즈x
# 물었씀
# 수고했대
# 모두의
# 빗나가는
# 예상을
# 송교수
# 탄식
# 나오는거뭐고
# 슈바
# 낮잠시간
# 강아진줄
# 귀읍다
# 아기들
# 존나큰애기
# 인나니까
# 수업이
# 만담하고있냐
# 끝나서
# 저말함
# 끝남
# 보내주지
# ppt
# 끝났잖아
# 그렇데
# 쓸데없는얘기
# 한마디로
# 잘하라는
# 어김없이
# 오늘도
# 계속하기
# 고대
# 연대
# 안물안궁인데
# 똥마려운데
# 그만
# 일곱시반에일어남
# 택배와서
# 뜯어
# 되던뎅
# 뜯으면
# 중간고사다음주라고
# 범위
# 아는분
# 어디까진지
# 얌
# 안찍재
# 비안와서
# 찍나
# 옷고민오지게하다가
# 청바지로갈아입음
# 하얀색치마입엇는데할머니가추운데미쳣냐해서걍
# 개춥다라니야
# 1도안추운디
# 그면
# 다시집갈거라
# 대충입고간디
# 가는데
# 못꾸미고
# 뭐라고
# 보낼지
# 말좀
# 퀴즈보몀
# 비와서
# 안댐
# 만족한다
# 벚꽃구경
# 이거로
# 아니하늘이
# 우아
# 먹물이네
# 졸려뒤짐진짜
# 12시에취침
# 기특하쥬
# 현영이는어제
# 기특메라
# 3시취침
# 주히는
# 지린다
# 맘터좀
# 생겼으면
# 이미있는데
# 투썸
# 개비싸
# 생각해봉까
# 깊티콘이나써야지
# 퀴즈봄
# 봤음
# 대따
# 다했따
# 실습12
# 과부화임
# 수고했수당
# 헐뭥미
# 공강시간에
# 벚꽃보러가자
# 어이거
# 클래식인가
# 나요즌
# 옛날로맨스영화에빠짐
# 존잼이야옛날거
# 내머릿속의지우개
# 보면됭듯
# 그거개슬퍼레알
# 현영이그거보고울뽄햇도용
# 불법링크개웃기넼
# 공결신청보냈는데
# 빨리준비했는데욥
# 족같네
# 싫어
# 무적권
# 애오늘
# 벚꽃보러가
# 다했어
# 못함
# 문제
# 읽지도
# 오예
# 남아있을듯
# 마지마갂지
# 저격하는듯
# 못따라가는
# 점점
# 니냐
# 우리모두
# 닌이거마치고
# 집안가지
# 이거마치고
# 점약있오
# 점약별다줄이다
# 별다줄
# 지는
# 그럼오늘
# 가안가
# 니실습함
# 벚꽃가자
# 왜안옴
# 윤지의어디야
# 할꺼없어서
# 할꺼
# 못할꺼같아서
# 상태로
# 집갈까
# 실습푸는즁
# 직접
# 컴터에
# 코딩치는거야
# 퀴즈처럼나오는
# 난몰름
# 실습조금
# 이론조금
# 파이썬시험처럼
# 에바아
# 코드외워야된다는소리
# cham
# chi
# 우리에겐
# 에이포한장이
# 시밬거기
# 안담김
# 조또
# 얼마나함
# 42가즈아임
# 11알바해서
# to
# 지쳐쓰러짐
# 42하는중
# 안씻고가서
# 집와야지
# 출튀하고
# 녹음가능
# 영현이도
# 맨뒤라서
# 출튀했는데
# 공사햐서
# 지하문쪽
# 들엄
# 센터
# 정문으로
# 나가라
# 쉅끝나고
# 열렸었눈데
# 올때만해도
# 내드갈때
# 문잠그더라
# 시작한다고
# 머글거
# 저거다
# 있는거임
# 안먹을거임즐대루
# 기부하면
# 받을래
# 생리대
# 개많아
# 보내줌
# 사촌이
# 회사에서
# 스바
# 하는중
# 가져감
# 큰박스에와서
# 개이덕
# 개마니조
# 미친거
# 저거유기농좋은거아니냐
# 김영현말투
# 방정맞앜
# 왜래
# 나도딥딥딥
# 이제봄
# 공짜라서
# 신났나봄
# 내공책에
# 막걸리먹고나서
# 시썼음
# 아빠
# 개웃기노
# 감성
# 폭발
# 감성폭발
# 리스트다나갓음
# 수업진도
# 나왜
# 다중리스트는뭐냐
# 들은기억이1도없지
# 덜나갔을껄
# 들은기억이
# 수업을
# 1도없는데
# 덜나갔지휘유
# 리스트
# 와진짜
# 뒤로갈수록
# 졸라어렵다
# 많음
# 안줄어듦
# 양도
# 니오늘
# 알바없씀
# 니알바요일
# 몇번이나
# 물어봐
# 갠톡에
# 공지해줘
# 내알바시간표
# 메모장에저장해놈
# 이주희는
# 메모
# 사라짐
# 월수토일인가
# 안갔자나
# 화금토일
# 맞지
# 수금토일임
# 아깝다
# 우야지
# 자구셤전날
# 스팔
# 햄
# 그짤그만
# 노이로제걸리겠음
# 은
# 언제쯤이면
# 춥다는걸
# 안느낄까
# 여름되면
# 느끼게해줄듯
# 쪄죽지않을까라고
# 한달전부터
# 봄옷
# 샀는데
# 못입음
# 추워사
# 그러다갑자기
# 날씨가마솥된다
# 명언이다
# 나를
# 땨에는
# 원망할
# 나자신을
# 남을
# 사랑하지
# 사랑할수
# 않으면
# 없다래
# 스바라shi네
# 있자노아
# 들어봣음
# 어디선가
# 지려버렷다
# 사람이
# 사랑할줄아는
# 자신을
# 남도
# 사랑할줄안다는거
# 어디갓어
# 니앞임
# 우리과방
# 몰랏네
# 메일쓰고안감
# 출튀도아니고
# 귀찮아
# 왴출튀도
# 과방에
# 있고싶다
# 웹프는
# 출튀걸리면
# 안됑
# 아지낮
# 왜지
# 메일을쓰고
# 안오지
# 좀그렇다고
# 출튀는
# 출석부르자나
# 아하
# 너네그럼
# 있으럭
# 옹적어도
# 웹프끝날때까진
# 근데오늘은
# 4일
# 5월
# 같이알바하실분
# 개에바네
# 아침7시
# 강남에서
# 하는건데
# 국정원이
# 강남이랭
# 언제심
# 토욜이여
# 나할래
# 돈이라면
# 85000이면
# 9시간인데
# 최저정도네
# 구해준거라
# 말하면
# 신청됨
# 9시간
# 그날뻗지뭐
# 생노동하고
# 85000원
# 나오나
# 땅파서
# 부타캐
# 모르게따
# 쉽다던데
# 일은
# 출튀할꺼
# 셤
# 잘봐
# 곰마옹
# 🥰🥰
# 꿀잠자보욨다
# 잘칠게
# 잘봤엉
# 담주까지
# 수고해❤️❤️
# 뜻
# 추임새
# 셤치는데
# 충전기
# 싶었는데
# 좆됬다
# 자기78퍼라고
# 빌려줌
# 고마움
# 내같으면
# 못빌려주겠다
# 불안해서
# 스윗해🧡
# 짝씨
# 먹을꺼라도
# 사다줘야게다
# 월여일에
# 말만해
# 얼마든지
# 비타오백
# 젤리
# 사다주삼
# 레몬탄산수
# 끔찍
# 댓글이고아님
# 아까보고
# 캡쳐했던거같은데
# vs
# 쓸데없는
# 정성가득한
# 공부너무하기싫어서
# 청소중이다
# 프린터기
# 개꿀잼임
# 공부하는
# 흑우있나
# jmt겟다
# 유부초밥
# 아니나
# 웹프강의자료얼마나잇나봣는데리얼
# 졸라많아서개깜놀
# 그와중에
# 돌릴때마다놀랍다
# 파파고번역기
# 곱슬머리로둘러싸인CSS😋
# 손코딩이지
# 컴터로시험보는거아니지
# 코딩나와도
# 컴터로
# 코딩할걸
# 번역기
# 잣됫네
# 코딩한다고
# 둘다함
# 이론이랑
# 말도안돼
# 잣같네
# 말한
# 샤브샤브머그러옴
# 야혀녕지의
# 사실몰럄
# 머고
# 그르게
# 남자친구염
# 걔가서울왓네
# 척이지
# 척하면
# 척하면척이지는뭐냐
# 안외유면
# 어케해
# 태그
# 한쪽되지
# 어디까지야
# 데분
# 넘어가
# 몇장까지야
# 결코
# 못넘어가겟음
# 6장
# 6장도
# 족같음
# 배운거
# 어디까지냐고
# 안들어서
# 배운데가
# 어디까지인지
# 강의자료올라온거
# anybody
# else
# 아는
# 배운데까지겟지
# 학교인사람
# 맞으러감
# 입술필러
# 컵안에버블
# 슬라임만지다가
# 아미친존나웃겨
# 니남친
# 안돼안도
# 안된다니깐
# 조난애절하게
# 안들어
# 나도개당황해쑼
# 마지막에
# 웃음
# 개웃기넼케
# 맞으러움
# 양치
# 더럽게하시넴
# 양치가
# 마취크림발라논거라고
# 앎
# 후크
# 뒤로돌리세염
# 관찰력
# 목걸이가
# 돌림
# 친절하시네염
# 입술
# 필러맞으면
# 두꺼워지는고임
# 두껍기도허고
# 모양이
# 예뻐짐
# 이사람이
# 이롷세
# 오동통통
# Up
# Volume
# 함정있는데요
# 3일간
# 부어있어서
# 끼구
# 댕김
# 입하
# 탱글탱글하다
# 물어뜯고싶다
# 77
# 입술조심해야댈듯
# 조만간
# 터지게따
# 찡떡개존맛탱
# 너오늘
# 노네
# 알차게
# 풀코스로
# 찐탱이네
# 55
# 군대가기전
# 마지막이야
# 갠톡이랑
# 단톡
# 답장잘못한거
# 갠톡인줄알고
# 아님아님
# 종맛턍
# 어디누
# 그리네임또
# 그리네에
# 앞에
# 존잘남있씀
# 후후
# 번따
# 따냐
# 존잘이라구
# 봐야됨
# 인지궁금
# 잘생겼다는사람
# 몰래
# 찍어줄까
# 범죄임
# 존잘남
# 개부어있는데
# 범죄
# 에바쓰
# 잘생겨서
# 저남자
# 쳐다봤는데
# 힐끗
# 의식하는듯
# 고만봐
# 그만보고싶은데
# 글로감
# 그만봐
# 씨댕
# 집간다
# 왜가는데
# 눈치채게하면
# 흘끗보는거
# 남자들은
# 으쓱거린다고
# 잘난줄알고
# 안그래도
# 알껄
# 지잘난거
# 거울봐서
# 공부하러와서
# 책펴놓고
# 폰하고
# 노트북만
# 존나하다가
# 그런겨
# 개도랏다
# 양
# 어디하구있써
# 웹프해
# ...
# 보겠슴다
# 꽃이
# 마녀의
# 짱똥맞아보일까봐
# 개오래되
# 부츠컷이
# 스키니
# 안입은지
# 핏이쁨
# 길이
# 복사뼈보이고
# 부츠컷은
# 짧아야
# 할말없음
# 개좋아하넼
# 신났뉴
# 아웃뎌
# 다운받도록
# 움짤이니까
# 새복많
# 야두라
# 아쉽당
# 수열
# 난6시에
# 알바끝나융
# 보둥거
# 아닌교
# 부모님이
# 서울올라가지마래
# 코로나때메
# 거기있는거
# 보내줬지
# 울엄마아빠는
# 잘만
# 힝구
# 모르게써
# 부모님이랑
# 얘기하는즁
# 동아리도
# 연구실이랑
# 무작정가지말라카면
# 부모님
# 이해는
# 입장도
# 바뿌자나
# 어쩌자는거야
# 밥주러가야하는데
# 우리햄찌
# 쓰고댕긴자고해
# 탕쳐서
# 얘기하긴했는데
# 조율중
# 가지마랬움
# 보름이나
# 봐야하는데
# 호메영현이도
# 위험발언에바지
# 왜위험해
# 나만모르냐
# 씨바
# 배째짐
# 알바중인데
# 이씨바
# 삭제도했는데
# 얘기할래써
# 사랑햌
# 눈치껏
# 와그겈
# 나인스타
# 윤지의로만
# 도배되있어서
# 인스타로
# 아예전역한거
# 완죠니
# 대박끄
# 그래두
# 시간금방갔다
# 짱조아
# 행복하겠구만
# 도배되는거맞제
# 이재
# 도배중
# 도배되서
# 윤지위로만
# 인스타잘안봄
# 좋아요까지
# 잘안본댘
# 남산의부장들
# 재밋나
# 그거잼씀
# 잼
# 존잼은
# 어재봤음
# 오바쪼
# 아니야잼남
# 볼만함
# 진부할거가아서
# 뻔할것같아서
# 진현영개웃굨
# 레전드거리
# 뽑아줘서
# 이항아에서
# 김영현만남
# 더블데이트
# 각이냐
# 근데너무
# 조용해서
# 참앗음
# 볶음밥먹늠중임
# 시밬우리는
# 이제시작
# 뵀다
# 정원씨
# 아삼겹살먹는단게
# 거기였냐
# 왜학교근처에있어
# 동물정원띠
# 신비의
# 토익다니는데
# 끝났을건데
# 진즉에
# 토익
# 머하고놀앗지
# 간지오래됬었음
# 금지
# 오해
# 데리러온거임
# 야근데너네오빠
# 야식만먹고집가는건아니쥬
# 대화가
# 왜그러냐
# 나아니냐
# 최초로봄거
# 너라고
# 너언제봄
# 최초는
# 깨빙
# 군자에서
# 만나서옴
# 미안한데
# 외박했
# 어디사봐
# 7시
# 만나는건
# 먹으실
# 구랴
# 건대는
# 사넘많이고
# 건대가면
# 사람쥰내많아서
# 코로나걸릴듯
# 거기가바
# D27
# 전역축하드려요
# 퍼벙
# 펑
# ☺️
# 😆
# 🥳
# 🎉💃🏻🕺
# 전역이라니
# 전역축하
# d27은
# 거긴가
# 조용하던데
# 7시까지
# 음식잘하는거같던데
# 랜선
# 검색해봣는데
# 좋으면
# 고르삼
# 둘중
# 따라갈게유
# 검색해봐
# 미주류는
# 쫌쫍음
# 이쁜건
# 미주류인데
# 좁고
# D27이
# 좋은거가태
# 조움
# 국
# 내학생증
# 들고오시길
# 삼색볼펜
# 죽여버린다진짜
# 빌려주기가
# 이럴줄알고
# 림들
# 지갑이거살라는데
# 저거사준다고
# 무래
# 저거벨트인데
# 지갑임
# 내지갑
# 내가왜사줌
# 지꺼
# 근데너
# 비슷한거
# 있지않냐
# 옶오
# 반지갑임
# 긋
# 주아요
# 무난무난
# 지갑
# 더예쁜거
# 있을고같음
# 맞죵
# 니집으로
# 배송해줄랬는데
# 볼팬
# 사러가기
# 심
# 그돈이나
# 볼펜
# 사는거나
# 새거
# 시켜주께
# 주소
# 8분안에
# 도착한데
# 시키면
# 내나
# 됐삼
# 필요없엌
# 너네오빠가
# 만든거임
# 와플
# 집에있던거임
# 올영
# 사온거
# 딸기도
# 씻어줌
# 논다고
# 야니
# 안오기만해봐
# di
# 져
# 뿔렉스
# 해버림
# 맛잇겟노
# 가져와
# 213목
# 잘들어가쏲
# 존나먹고싶어
# 홀리쉣
# 초코크루아상인가
# 단거
# 땡기네
# 고구마인줄
# 쩔지않야
# 화창해
# 개잘찍었다
# 날씨조타
# 화양리갬성
# 지기네고마
# 무난한건
# 이뻤는데
# 첨봤를땐
# 다시봤을땐
# 별로고
# 뭐가다르죠
# 1이뽀
# 오케에엥
# 0명
# 옶음
# 우한월요일로
# 한명도
# 현재까지
# 역대급
# 사장님어떡해
# 모이는고징
# 네고객늼
# 되는뎁쇼
# 옼히
# 왜맨날목요일이냐
# 수요일이었는데융
# 그녀••
# 12일
# 알바있어욥
# 언냐돼
# 목열인데
# 어쩔수없즁
# 늦참할수있으면
# 할랭
# 알바가야돼
# 대역죄를
# 저질렀습니다••••
# 안됩니까
# 가눙이여
# 복받으실거에요
# 몇명더잇어요
# 사장들
# 허락구하시길
# 난담주
# 불가
# 안되는
# 요일이
# 적어봐
# 늦참10시
# 늦참9시
# 담주는
# 월금
# 엽주는
# 수금안됑
# 담주목금만
# 되는디
# 정리해봐써
# 아무요일도
# 개오램만
# 우리그래서목욜에
# 봅니까
# 안봄니까
# 다수결
# 된이상
# 이라케
# 되는날짜
# 수토일
# 엽주
# 요번주면
# 일용도
# 하비않나
# 엽주고뭐고
# 염증난듯
# 쉬발
# 죤나배아파몇일동안
# 코로노아니제
# 감기증상••
# 엽주는근데
# 요번주의
# 사투리냐
# 아프겠다
# 개아픔
# 똥은안나와
# 그놈의폰부터
# 수리햌
# 살빠지겠노
# 괜찮아진거같으면
# 맛있는거쳐먹고
# 몇일동안
# 아팠다가
# 어랏괜찮나
# 어제도오빠랑애슐리먹고오늘도방이샵샤브쳐먹
# 또아파
# 이런썅
# 아프다돈데
# 그만먹고
# 약을먹어
# 그만먹곸
# 더먹자
# 약을
# 어랏괜찮나할때
# 아프겟다
# 잘잠
# 잠은
# 고통이
# 그나마잊어짐
# 잠자면
# 잠깨면
# 죤나또아픔
# 너네근데
# 휴학신청했니
# 2월7일까지돈데
# 깜빡해서
# 학교다니게되는
# 왠열
# 기대했는뎅
# 어캄을
# 꿀맛
# 찐
# 몬데
# 카라멜팝콘
# 영화보고
# 클로젯봄
# 네일아트
# 또하셨네요
# 흰죽••
# 노잼
# 클로젯
# 멋잇러보임
# 저것마저
# 판타지
# 뛰쳐나갈뻔
# 요즘들어
# 최고노잼은
# 미스터주임
# 개쓰레기영화
# 그게머임
# 몽미
# 다봐서
# 저거까지봤더니
# 잠만자다나옴
# 클로젝
# 잼없슴
# 클러젯
# 기대중인데
# 볼만혀
# 갑툭튀부분에서
# 다른사람들은
# 조용한데
# 정원이혼자서
# 재밌던데
# 으아아아아아악
# 오빠때매더놀램
# 어떤사람이
# 영상찍어서
# 유튜브올렸는데
# 썸네일부터
# 개좆가탘
# 신고때릴거야
# 개어이없어
# 미친메친
# 그와중이뿌다
# 신고해줄까
# 뇨뇨
# 유튜브
# 개깐깐해서
# 신고
# 본인만
# 넘고맙
# 마음은
# 찾은거도
# 알려쥼
# 일하는
# 도라인가
# 개이뿐데
# 눈대박많이와
# 누니와
# 개추워
# 탈색에바
# 샛노랑
# 은데요
# 이쁠거가
# 답정너여써
# 눈조와😍
# 같운뎅
# 괜찮을
# 아이거진짜
# 봤다가
# 시뱅
# 호기심에
# 후회중
# 이와중에
# 누텔라아깝자
# 똥몰카
# 토스트로
# 에바짘
# 마요네즈를
# 올리는건
# 개꿀조합임
# 잘먹을거가틈
# 나야
# 유튭
# 언니야
# 후련
# 님들님들
# 색깔
# 스페이스그레이
# 실버
# 은색과
# 회색•¥
# 무슨차이지
# 보여죠
# 고민된다
# 할거
# 케이스라
# 블랙계열도
# 실번데
# 원랜
# 이쁘던데
# 넣는
# 사긴살언데
# 아이패드랑
# 프로
# 상관없겠다
# 파우치면
# 얻음
# 그레이
# 까리해서
# 스페이스
# 하고싳음
# 매년
# 주는거잇는데
# 판다길애
# 나주라그랫음
# 괜찮은듯
# 고민끄
# 간지느는데
# 그레이가
# 안질리기엔
# 깐지나
# 스그가
# 스그사
# 임마
# 답정너엿음
# 스그
# 아니가
# 니가게에
# 있닝
# 두래
# 살려눈데
# 울집앞에
# 핑크랑
# 화이트
# 담아먹을라구
# 울오빠랑
# 생겼누
# 카톡안읽냐
# 죽을래
# 카톡했닝
# 운동가방
# 이고임
# 운동하니
# 개웃교
# 민수는
# 살언제빼냐
# 배꼽이
# 운동전에
# 알아봐주라
# 텀블러
# 같긴한데
# 있을것
# 주문할수
# 오래걸랴도
# 딴거사겠다
# 배꼽
# 캡쳐해봤어
# 텐동빼고
# 하루종일함
# 누메로도스우디집혹은bbhay
# 강력하게
# 주장합니다
# 케이크맛있겠땅
# bbhay가
# 조켓군요
# 몇시집햅
# 알바몇시야
# 나6시
# 2시집합하실
# 2시로
# 결정되었습니다
# 장소는
# 뚝섬역이여
# 성수역이여
# 이주위나와라
# 누메bbh
# 일케갈라면
# 15분은
# 걸릴거같은데
# 걸어서
# 20분
# 더걸리네유
# 오이쿠
# 우디집까지는
# 금요일에먹어야되지
# 내일못먹지
# 다른학과수업은
# 잠깐질문
# 웅우애
# 가깝쓰
# 우디집이
# 쫌더
# 택시차고
# 하던디
# 뚝섬역
# 케쿠
# 네엥
# 왜연락안돼
# 네네
# 배부르려나
# 쬐끔먹어
# 앵권
# 이거먹어도
# 뚝섬
# 유원지가아니고
# 뚝섬역이지
# 우리밥먹으러
# 바로가나
# 2호선
# 밥머그러
# 웅바로
# 뚝섬유원지
# 생각했다
# 와악
# 말해줌
# 정원이가
# 서울사람이
# 왜헷갈리냐고
# 재밌겠더어어
# 서울지리
# 뷰러좀
# 가져와주실분
# 록됚어
# 못가겠다
# 부러는
# 챙기기로함
# 배불렁
# 지의얌
# 그랴
# 오등강
# 카페라도
# 그게더귀찮을려나
# 나쫌
# 늦을듯
# 교환하는데
# 기다리는즁
# 기사님
# 오신데서
# 커튼
# 집에서나옴
# 도착하거나
# 제때
# 5분정도
# 지각이라구
# 자니
# 쟈철탐
# 도착이념
# 오디요
# 현뇽
# 내림
# 하나뒤
# 다행몬
# 4번출구에
# 잇서요
# 우리7번출구로가야되던디
# 7번이나잇다고
# 유원지
# 식겁하개
# 으유
# 그래서몇번출구가
# 젤빠름니까
# 7
# 7번이나잇어
# 뚝섬에
# 7도
# 낮에모이니까
# 8까지잌어요
# 6번으로감니다
# 술약속
# 잡자
# 창원가
# 2월안에
# 불가일둣
# 술은
# 거절당한
# 지금일어나서
# 언제자면
# 지금인나는고
# 7번옴
# 아6번지나치고
# 슈밸
# 6쪽으로
# 가고있엇는데
# 디질랴
# 다시가는중
# 7로
# 7로감
# 6다옴
# 등또돌림
# 디질
# 화낼것까진넙자나
# 영화라두
# 갑분영홬
# 6시에잠
# 으이그잘하는짓이다
# 카톡복붙아님
# 누메
# 시키고
# 페텀
# 잘못건거지
# 페탐
# 잘못걸엇대
# 보스따뜻해서
# 내리기싫다
# 끝까지가
# 타고
# 먹는동안
# 버스타고있울까
# 여음
# 으로와
# 네이버지도
# 찍고왕
# 식당이름
# 내리지말걸
# 후귱
# ☝🏻뭔데
# 생일선물을
# 찍은거융
# 지냐냥
# 디엠안버
# 세상치명적인
# 자세로
# 코파기
# 관능적이다야
# 나저거도촬하다가
# 발로차일뻔함
# 니동생
# 왤케커
# 남성인데
# 수준이
# 애기가
# 자는
# zzzzzz
# 이사함
# 이주된거같긴한뎅
# 해쏘
# 혼자살아
# 카페NA
# 위로옴
# 넓음
# 넓은데로
# 이사가곱다
# 저번보단
# 공간이있움
# 2년
# 계약
# 살던데
# 안됬자나
# 나저번
# 일년해써
# 2년계약이라
# 집들이
# 헐야너
# 안가기로한거
# 다녀오고
# 쭉이써
# 2주만
# 가야겟지만
# 갓다오게
# 야쓰
# 앵쥬
# 토익835나왓다
# 김민수보다잘봄오빠는800나옴
# 겨울에
# 여름이나
# 학원다녀야징
# 컷트
# 개뻐네
# op
# 좋게따
# 지녀년
# op가
# 우리과는
# 700만
# 넘으면될껄
# 와아아
# 어케한번먼에
# 통과햇댜
# 뿌듯하겟고만
# 취업2뇬안에못하쥬
# 무서운거같애
# 시험땐가
# 빈강의실에서
# 가사
# 무서운해석
# 섬그늘에
# 낮방
# 본거
# 기억나냨
# 지이언니없었을껄나랑
# 남음
# 엽떡은
# 에섴
# 멎음
# 복도
# 집가는데
# 통금때매
# 존나무사워서
# 데려다줌
# 현관까지
# 못한다니
# 가꿀맛
# 공부하다가
# 먹우면
# 식은거
# 눈물을
# 이불에
# 훔칠것같군요
# 정원이잇자나
# 개추억이누
# 왜있지했는데
# 김부각먹고있넼
# 걍존나맛잇겟담
# 밥타노스
# 7시부터
# 공사
# 때문이
# 옆집
# 소도둑옴
# 이시간부터
# 3개월
# 걸린데
# 아재한데
# 구청에
# 내공10000
# 신고하는방법쫌
# 오빠집으로
# 피신
# 갈려고
# 난리임
# 코로나
# 병원에서
# 뿐
# 자는거
# 자려면
# 코로나걸러서
# 에바야•••
# 개꿀맛집
# 곱창전골
# 서울시람들아
# 머거봄
# 부산이랑
# 순천에서
# 곱창전골케
# 오늘부로
# 퇴사했슴다
# 축하드림다
# 촹미나
# 퇴사축하한드아
# Zzzzzzzzzz
# 가수들은
# 딴
# 방탄앨범나올때
# 앨범내야겠노
# 피해서
# 들어봐야겠다
# 핸번
# 샤브샤브집
# 후문쪽에
# 몇주전에먹었는디
# 네이버지도에안나옴
# 검색했는데
# 개식겁때림
# 검색왜해봣어
# 만날사람
# 고쳐
# 만지고싶다
# 아이거대박이야진짜
# 뚱땡이
# 코로나때먀
# 못보든중
# 콧잔등봐진짜
# 귀이워
# 새
# 강아지마스크도
# 판다던데
# 볼터치
# 죤내귀엽다
# 누가저렇레
# 잘찍어쥬뇨
# 염색중인고팀
# 실시간인쥴
# 목가
# 글치
# 가족둥에
# 보내준줄
# 잘찍었다는거
# 아니었나
# 못가고
# 영화보러도
# 넘무슬픈것
# 강쥐도
# 걸린대
# 조심쓰
# 정직한후보
# 코로난데
# 잘싸돌아댕김
# 되게많이햇더라
# 외출
# 너코로나라는줄
# 조심행애애액
# 뭐하고살아
# 련영이는
# 집콕스
# zzzzz나도
# 알바•••
# 집콕
# 이태원클라쓰보셈
# 웹툰도
# 개재밌지
# 본방보는즁
# 이서
# 다미
# 어떠냐구
# 글케잼남
# 안보는즁
# 웹툰만
# 정주행하고
# 볼레
# 완결나면
# 그때가면
# 아이걸
# 이런다고
# 이제봤지
# 그반응
# 사랑의불시착때도
# 똑같았는뎈
# 비슷하게잼쑴
# 없당
# 요즘밖에
# 주말알바
# 짤릴각임
# 그래없움
# 난리구나
# 심할까
# 가게하는사람들
# 불상하다
# 마지막이지싶다•••
# 레알로
# 웅가서
# 같이일하는데
# 두명이
# 사장이
# 싹다조정하랬거든
# 일하게
# 관두고싶다햌자나
# 알바하나
# 잘됐지
# 자하는데
# 2층에
# 커피엎질러서
# 개뛰어댕김
# 관둘래
# 짲나
# 그3층짜리
# 이디얀가보네
# 좔됐다
# 주이
# 일중임
# 집와땅
# 퇴근하고
# 뚝섬이네
# 지나감
# 별러냐
# 난이뿐데
# 이거올림
# 자체는
# 젤이뿐듯
# 구도
# 얼굴말고
# 다이쁘긴함
# 개기여
# 존나예쁨
# 영현이다
# 나라는거야
# 짱무서워
# 키킥
# 작품
# 죤나예뻐
# 술파티할건데
# 나요
# 다됨메라
# 주말빼고
# 고르세영
# 화수목금중에
# 다가능
# 홍보중
# 🎉
# 뭐야개쩔어
# 알바끝나고바야징
# 감솹니다
# 꾸미는
# 다이어리
# 블로그
# 해라
# 인스타는
# 다올려놓으면
# 잘될듯
# 정보같은거
# 박제당함
# 블로그에
# 신고는
# 안됩니다
# 초상권침해
# 박제당하고싶다
# 잘꾸마내
# 넘길수있는거
# 아거
# 이제암
# 나도방금암
# 정성이다
# 모태
# 감삽니다
# 뿌듯하네염
# 방곰다봄
# 쌉미쳤네
# 죤나잘꾸미네레알
# 습탱
# 천재다
# 다봣다는줄
# 이태원클라쓰
# 족발야시장
# 회식했는데
# 이태원클라쓰얘기만함
# 박선균인데
# 사장님이름
# 박선균이장사하는
# 사람이야
# 오백번들음
# 다봤다는줄
# 요즘영화뭐본거있는사람
# 인비저블맨빼고
# 1917이나
# 정직한후보중에
# 지푸라기나
# 뭐재밌는거있삼
# 네이버후기못믿겠삼
# 지푸라기가짐승이제
# 봤음그거
# 본애들
# 배유가
# 연기를
# 절헌다고
# 뭐래재밌대
# 재미는있는데
# 식상
# 스토리가
# 그렇군
# 1917이
# 보고싶다눈
# 사람많던뎅
# 1917
# 내가그거보면서
# 연출은대박인데
# 잘지안잘지의문
# 내용이재밌나
# 고만쫌자
# 또자면
# 민수개난리칠듯
# 대환장파티네
# 재밌겠돈데
# 보고시픔
# 기대작말고
# 리뷰를
# 원합니다
# 정직한후보본사람
# 너가먼저보고
# 후기알랴주라
# 잼없을까봐무서움
# 영화관이냐구
# 미리온다면
# 않을것같음
# 외롭지
# 미리언제요
# 12시도
# 블로그에박제해줘
# 파티도
# 안귀찮으묜
# 12시요
# 쌉가능
# 동아리지원
# 미루고미루다가
# 겨우냈네
# 야너오빠가
# 낸거보심
# 냄
# 댔다고
# 이상하게
# 다고름
# 하나만고르라한거
# 개대충씀
# 나도걍
# 다고른거같은뎈
# 동아리신청해써
# 영현이남친동아리
# 뭔동아린데
# 머신러닝
# 인공지능
# 암말도
# 언급안햇고
# 만든동아리임
# 만든지는
# 나카펜데
# 전화한다고
# 내음료
# 이십분째
# 안만들어줌
# 케잌도
# 창립멤버일걸
# 이시뱅
# 가서따져
# 아야아아아어애간장타는데
# 너무먹고싶은데
# 너무먹고싶은지이
# 아근
# 고르고
# 상관없대
# 물어볼거래
# 머하고싶은지
# 2개햇던거같데
# 마이
# 호
# 하고싶은게없는데
# 우짜냐
# 그럼지원왜해
# 그게아니고
# 아무것도모르는
# 백지의
# 상태
# 하고싶은게
# 배우고싶다
# 이거아니엿
# 기초해
# 배울지도
# 모두를위딥러닝인가
# 그거나들어볼까
# 이딴거하고있는데
# 존나하나도모르겠어서
# 쩐당
# 강사님
# 설명개못하는것같음
# 얼마주고
# 세일할때
# 강좌당
# 5마넌
# 개싸지
# 10마넌인거야
# 기간한정
# 니꺼
# 살라고
# 한강의당
# 기간
# 놓쳐서
# 드갔는데
# 두배뻥튀기네
# 내가샀을때가
# 쌌을걸
# 갑자기또
# 호덜덜
# 머할라그랫는뎅
# 이름좀
# 지르셈
# 어떠
# 이름뭐셈
# 가봤는데
# 직강들을라고
# 직강까쥐
# 듣고싶엇는데
# 직강
# 다가는데
# 일주일
# 존나비싸지안하
# 10시부터
# 나누겠지
# 시간대를
# 텐투텐
# 샀어
# 몇천이었음
# 얼마였지
# 아니그거
# 이름뭐냐곸
# campus
# fast
# 아맞당
# 저번에들었는데까먹
# 그돈으로
# 유학감
# 산건
# 비추
# 유학
# 너뭐뭐
# 몇천
# 딥러닝인공지능
# 머신러닝과데이터분석이랑
# 앞에꺼박에
# 안들어봤는데
# 동아리에서
# 배우려는거네
# SAT
# 유학알아봐줬는데
# 필요하데서
# 할려는데
# 더므고
# 어려울득
# SAT가
# 어려운데
# 영어도
# 수능
# 도랐냐
# 쎄빌
# 못하는데
# 수능도
# 유학보내준다면
# 노력은
# 해볼거강틈
# 해석만하면
# 가고나야
# 유학을
# 칠수있지
# 쉽데
# 맞춤법일까
# 야그면
# 도전해봐
# 알아들어
# 타자
# 힘들거든
# 학원댕겨야지
# 아빠같다
# 진심이라고
# 개멋지겠다
# 영어잘해지면
# sexy
# 갈수있음
# 영어를
# 일댄
# 잘해야지
# 유학을가야
# 잘해지지않냐
# 모순점
# 대학들어가는거라서
# 열심히해면
# 학원댕기고
# 수학같은거
# 어느정도만
# 하면되고
# 훨신쉽데
# 할거삼
# 키우고픔
# 나쟤알아
# 강아지랑보드카페
# 거기잇는
# 고양아냐
# 헉니유학간다고
# 준비를
# 해본다구
# 굠둥
# 강쥐보단
# 고냥이키우고싶음
# 보리제외
# 나도쟤있음
# 이쁘제
# 저거뭔데
# 산거임
# 양초
# 현영하나만
# 골르라해서
# 봄제주고름
# 제주도인
# 선물받는겨
# 봄제주랑
# 월정리가
# 젤이쁘다
# 에메뢀드
# 4가
# 예뿐데
# 다지나갔네
# 카톡이제봄
# 핫플
# 강의녹화했는데
# 깊은좌절을느끼며
# 겨수님들
# 돈받고
# 할일
# 동영상올리기
# 얼마나싫었을까
# 싫었는데
# 알았을때도
# 프로젝트올려야하는거
# 깊은좌절
# 강의도
# 올려하잖
# 쥰비해서
# 좌절감
# 집배경
# 다나온데
# 갸웃김
# 고민상담
# 들어줄사람
# 없어도
# 일단말하고보겠음
# 어서읽어라
# Hurry
# her
# we
# 가져야지
# 뭘안되
# 시간을
# 안되긴
# 일주일동안연락을안하면
# 미치겠어서
# 식음
# 오빠헌데
# 그런거같기도하고
# 그동안
# 뭐했난지
# 믿음이
# 시간갖자고
# 연락안하면
# 의심가고
# 못만날껄
# 처음이랑
# 만나보다가
# 맘떨어질때
# 헤어지셈
# 근데헤어지고
# 그리워하면서
# 울면
# 진짜맘떨어질때가언제일까•••
# 기준을몰겠삼
# 연애
# 아직은
# 질껑
# 갤러리
# 뒤적거릴거같은데
# 때문에
# 불가능일껄
# 있기
# 잘지내는건
# 정이
# 헤어져도
# 홀가분하게
# 이때
# 재밌었지
# 그러니깐
# 내가지금
# 사랑해서
# 정으로만나는건지
# 만나는건지
# 구분이안됨
# 고민도
# 헤어져야될때는
# 헤어지고
# 여즘
# 짜증남
# 잘못해서
# 혼나도
# 내가혼나는게
# 짜증나고
# 진심으로
# 풀어주고싶지가않음
# 너무많이혼나
# 혼나서
# 그런거아님
# 삐지고
# 화내는것도잇는듯
# 갑니다
# 공감
# 누르고
# 고랭자주
# 그런걸수도
# 싸워서
# 내가잘못했는데도
# 싸우는게지쳐벌읨
# 그런거임
# 맘이
# 맘이뜨먄
# 꼴보기
# 사과하기
# 싫고
# 잘못해도
# 져주기
# 사과하기싫고
# 원래도
# 내문제인건가
# 찐이당
# 귀찮음이란
# 나일거야
# 부정할수없다
# 뭐때매
# 화내길래
# 글겡
# 뭐잘못했오
# 오빠가화난부분은
# 남자친구랑
# 비교하는말을했삼
# 자기집에데려다달라하고
# 지윤이남자친구는
# 집데려다주는데누구는
# 개화냄
# 오빠개빡쳐서
# 안붙잡아서
# 더화냄
# 장난스럽게했으면
# 저말을
# 그렇게말할수도잇지
# 안붙잡음
# 비교하는거
# 잘못이긴한데
# 안델따주고
# 왜집에
# 니보고
# 델따달라함
# 영화봤는데
# 바로앞에서
# 지하철탈수있었믄데
# 15분정도
# 걸어가야있거던
# 오빠집
# 오빠집까지데려다줄래
# 이래가지고
# 안잡고
# 지하철타고
# 지쳤으면
# 집데려다달라는건
# 전드긴
# 보여주면
# 안된디
# 야막캡쳐해서
# 그려져서
# 그장면이
# 머리에
# 빡이쳐하
# 멀어져가는뒷모습
# 뒤돌아보지도않길래
# 런어웨이
# 지하철로
# 뒤
# 못돌아보지
# 사나이
# 존심에
# 그럴거면
# 안갔지
# 안잡지
# 왜언잡지
# 가려웠을걸
# 왜안잡냐고
# 전화로
# 개짜증나겎다
# 난감당불가능
# 쉽지않다
# 지금또
# 뭐할지
# 정하는중
# 지랄해주기도
# 에너지낭비
# 어쩔꺼야
# 내가잘못해서
# 지랄은못함
# 잠수탐
# 나쁜놈
# 너상황이었으면
# 난또
# 나만모르는
# 응아냐
# 썸남
# 있는줄
# 남자는무슨
# 여자도
# 주변에
# 3개중에
# 원픽
# 넘힘든것
# 우열가리기
# 진짜개힘들다
# 야나저거
# 노랑색으로있는뎈
# 고터에서삼
# 1은너무
# 차도녀같은걸
# 자연스러움
# 3은
# 배제했어
# 그림그리는카풰
# 민수작품
# 왼쪽
# 잘그림
# 이거보고그림
# 빡취네
# 손놓고
# 자존거
# 타는거
# 지료버림
# 허세
# 현영이거봐
# 멋있지
# 동네
# 아개시름
# 초딩형들이
# 하던거
# 말았는데
# 언급하려다
# 그림느낌있다
# with
# 세발자전거
# 실제상황이냐
# 농락
# 소비자
# 손상모
# 실시간
# 찍을시간있냐
# 같이읶음
# 화장실간사이에
# 휴지가지러
# 지이언니집에서
# 에바야저거
# 각자집가는데
# 언니노트북은
# 말짱한날이업다
# 블투키보드
# 언니집
# 몇명있어
# 햄토리
# 죨라웃겨
# 양산가써
# 동물안되서
# 이사한집
# 너무너무
# 사고싶은데
# 돈지랄인가
# 막상사면
# 안쓸거같기도
# 하긴해
# 사과템에
# 애초에
# 기능도잘모름
# 맞셈
# 조용한
# 톡방
# 아닌데욤
# 담주임
# 담주야
# 이번준줄
# 갈뻔
# 슈잘
# 휴갬새
# 12일이라고
# 말핵던거같은데
# 옥
# 카잇헤헷
# 담주라서
# 나돗
# 큰일날사람들이네
# 개놀랬네
# 이건뭐지
# 가관이다
# 어빠가
# 화이트데이선물사줌
# 아직도안샀었음
# 잘쓸려면이제
# 갈자
# 폰액정
# 클라스
# 에어팟2임
# 간지난다
# 사과
# 쇼핑백에
# 관심없던
# 드뎌
# 어피치
# 죤귀
# 대고
# 밥먹을때도
# 통화했었는데
# 이제액정만갈자
# 댓글봐
# 내가보냄
# 구라치지맠
# 현영믿는다구
# ꉂꉂᵔᗜᵔ
# 푸항항
# 3일무료
# 이용권줌
# 지금왓챠에서
# 5마리
# 헤흿
# 비친
# 사랑스러워
# 와저렇개
# 짱쿤
# 처음봐
# 콧구멍
# 았
# 들어간다굿
# 오백원두
# 보여주라
# 동전들어간다길래
# 저금통이야긴줄
# 님둘아
# 모일거야
# 세은이더
# 진혀녕이랑
# 얘기하지않았어
# 상관없우
# 와도
# 먹여봐
# 뽀리
# 뭐냨
# 눙물자국
# 무행
# 비내려서
# 어데가지도못하고
# 비내리기시작
# 라멘먹고싶어
# 미치겠는데
# 안함니더
# 갑분라멘
# 학교갈랬눈데비온다니
# 학교왜강
# s나
# 피료해서
# 휴학증명서
# 이해감
# 남희석
# 둘다이미봄남희석개웃겨
# 맘터
# 이지랑
# 만나는거
# 맞조
# 맞숩니당
# 예엥
# 뭐머그꺼야
# 먹을랭
# 6묭이여서
# 마니시켜야하나
# 괜츈
# 레쓰기릿
# 다좋긴해
# 남자애들
# 오는애들
# 붉은악마티
# 졸많
# 졸사찍은애들
# 안입어서
# 오빠보고
# 붉은악마티입은
# 오빠였음
# 있었다했는데
# 입은듯우리
# 홍팀백팀이었음
# 홍팀일때
# 아무도안입은거같지
# 울학고는
# 체육대회때
# 잘생각해봐
# 붉은악마티받고
# 검색해도
# 안나오네
# 이런거였는데
# 거도
# 입음
# 장난침
# 이거알제
# 곰팡이
# 해골
# 여자애들은
# 치렝입음
# 진리
# 챠콜색
# 엌생각도못했자
# 메신저백
# 백팩안매고
# 메신저백매는애들
# 선두주자
# 트렌드
# 일진들
# 그시절
# 맨다고저거완전
# 머릿속
# 메신저백을
# 반항아니야허걱
# 선생님에대한
# 에엣백팩을안매고
# 현영이의
# 디키즈
# 입어야징
# 우예앎
# 홍보대산거
# 카페갔는데
# 갬성적이라
# 해석해보니2층은10시반에문닫는다는뜻
# 갬성에속아
# 잊지말자••
# 해석을
# 20살때도
# 홍보대사였자나
# 귀여웠던
# 다없애버리고싶다
# 졸사
# 초중고
# 놀라운점
# 저날은
# 여름이었다
# 대기하다가
# 존나남
# 아니었다는게
# 초등학생때가
# 세상놀랍다
# 고딩때임
# 고삼
# 졸사임
# 배개
# 우애한거야
# 졸사촬영현장
# 받쳐줌
# 욱갸
# 단정
# 이쁜척
# 귀뒤로넘김
# 찍기전
# 틴트바르고
# 개공감애들
# 거울
# 난리
# 빌려달라고
# 아니그래서
# 지중해언제부터가는뎈
# 다행임
# 안망하면
# 사장님불쌍해
# 하루에3팀옴
# 숨겨져있음
# 간판을
# 졸라거대하게
# 제작하라고해봐
# 족발집가면서
# 지중해탐내냐고
# 가게안에
# 장미인테리어
# 죤나비싼
# 팔아버리고
# 족발
# 주말만해서
# 부족
# 경력좀쌓아봐
# 나대신
# 대타쓰게
# 이디야함
# 10개월차
# 고인물임당
# 읻야
# 고였다
# 10개월
# 쌉고엿다
# 9갸월정도
# 했던듯
# 가져올사람
# 종이컵
# 없눈제사갈게
# 개많이팔잖아
# 헫
# 아까워
# 가져오게
# 그런벙법이
# 많움
# 3개있는데
# 컵은
# 6개
# 넉넉하게
# 건대입구
# 모요라
# 심심한사람
# 심한사람
# 얼룽와77
# 넘어서자서
# 열두시
# 일곱시에
# 밥먹구가
# 뭐먹지요
# 엥왜
# 우리뭐머걸
# 나도배고차
# 뭐먹을랭
# 안먹는거지
# 5묭이서
# 몇개시켜야하지
# 엽떡족발
# 개조이나
# 2개면
# 되겠제
# 먹을꼬
# 술도
# 맥주정도만
# 생각못하고지금나옴
# 하퇴근깅
# 일찍나올걸••
# 그엄
# 마실까
# 맥주만
# 음식은
# 웅조아
# 마왕족발
# 중자랑
# 시켰어염
# 얍떡
# 초보맛
# 50분내로온대염
# 나쫌늦우모
# 빨리갈겡
# 주위언제옴
# 나지금사는즁
# 맥주는
# 먹곱
# 맥주사올사람
# 여기줄랑이없어
# 줄랑이없오
# 잘랑
# 앜줄랑잘랑
# 51000원이라서
# 엽떡이랑졷발
# 8500원씩
# 돼여
# 보내주시면
# 누가계산햇져
# 맥주랑
# 재밌었오
# 1500014000
# 이라서
# 4800원씩
# 됩니당
# 계좌적어즁
# 세으니한테도
# 전달할게
# 3700
# 재밌었다
# 8500
# 15일에
# 보내줘두됨
# 용돈날이라
# 랭
# 고랭지농업
# 반응
# 안해줬네
# 와아무도
# 보냈수
# 확완
# 집에가서
# 검색해봤눈데
# 배터리
# 내증상이랑
# 다된거래
# 수명이
# 컴퓨터에
# 10마넌대래
# 교체는
# 다행이라고
# 할순없지만
# 다행인가
# 걱정까지
# 메인보드가는
# 했짜나
# 쏟은사람
# 간적이
# 없자너
# 구석에있덤거
# 글로안갔자낭
# 키긴켰었나
# 1020분전에
# 오기
# 켜놨음
# 일단오캐
# 엎어져있어
# 근데왜그게지금발견되는겨
# 가질않았거즌
# 그때이후로
# 킨적이
# 세워져있는데
# 오빠한테도물어봐야겍다
# 캔들이
# 한적이없거든
# 침대쪽에있던거아냐
# 꺼매
# 그때이후로안켰우면
# 날은
# 논
# 무저권
# 구석탱이에
# 잇던거
# 발견안될수가없는디••
# 구석탱이라
# 근처를
# 몰랏음
# 물어줘야항텐데
# 벽지
# 굳었으면
# 벗겨지지않나
# 꺼먼초가다있었음
# 떼도
# 벽지는
# 얼룩지더라
# 일일이
# 검정색써가지고
# 개심각하네
# 어째
# 그날이면
# 왔을때
# 침대
# 발견했지않울까
# 와저거어째
# 오늘왔우니
# 침대가
# 좆됐으여
# 껐을거아냐
# 켰던것같은데
# 한두번
# 개빡치네젠짜
# 잇니
# 난1번
# 혀녕은
# 들어봤는데
# 싸강
# 그런게있음
# 30분이면
# 끝내는데
# 남들
# 소개하는거
# 인트로덕션
# 1시간
# 수업하심
# 아니뭔강의야
# 한양대수업
# 한양대가신거
# 금융개론
# 들었어
# 한양대꺼
# 수업들어서
# 방송소음오진다고
# 개비싼거샀는데
# 상상됨
# 내려오는
# 마이크라서
# 방송하는것같이
# 위에서
# 마이크까지샀대
# 신기해서
# 쳐다보면서
# 하게되네요
# 이러면서
# 비싼게
# 좋긴하네요
# 확실히
# 송재욱교수님도
# 투머치토커임
# 웃기넼
# 설렜냐고
# 한양대가서
# 말개많아
# 알려주시겠다만은
# 아부럽다
# 로제파스타
# 분모자중국당면
# 영현이집에서
# 해드실분
# 행동력
# 언제가는데
# 말해버린다고
# 개먹고싶네
# 리뷰보고있었다구
# 삼겹살무한리필
# 잇
# 힝
# 너어제
# 먹었자나
# 미정
# 언젠제는
# 다이어트라
# 저탄고지
# 리뷰또보는거
# 다른곳으로
# 삼지순례
# 중당
# 개마늠
# 들구감
# 이제서냐
# 4화
# 슈우우우발
# 죤나꿀잼
# 넘재밌어서
# 욕나오누
# 날짜잡자
# 훠훠
# 빨래걷자
# 아무도안봐주는
# 현영톡•••
# 날잡아
# 거의암때나가능
# 4월로
# boyfriend
# your
# 안다하는사람
# 클래식
# 하아짜파게티
# 1도몰라요
# 아웃
# 알수도있으니까
# 빠바밤
# 빠밤
# 빠암
# 빰
# 빰빰
# 노래거든
# 녹음해서
# 들려줘
# 음성메시지
# 익숙할걸
# 이름모름
# 제목
# 기둘
# 지인찬스
# 내녹음
# 들려주는거
# 맞는뎅
# 개대충했는데
# 잘했음
# 딱들으면
# 제목알고싶다
# 개귀엽넼
# 아7
# 알거같은데
# 신서유기에
# 나왓얶는데
# 기에
# 신성
# 내가맞출거야
# 신세계
# 드모르작
# 그사람아냐
# 신세계러부터
# 맞추고잔다
# 지렼다
# 싱서유기
# 존나많이봐서
# 알려줌
# 장후도
# 지분
# 너네오빠도뭐님
# 오케스트라
# 동아리잖아
# 첫부분
# 죠스노래같다
# 두둔
# 두둔두둔두둔두둔
# 개지렸다
# 두분다
# ˃̣̣̥᷄⌓˂̣̣̥᷅
# 감사함당
# 왜궁금
# 알수없는그녀
# 어따써먹을랴고
# 스토리에
# 재키와이가
# 멜로디
# 알려달라그랬거든
# 맞춰
# 디엠보냈음
# 스토리로
# 올려주면
# 답장왔음
# 빨리알려준사람
# 있을거같음
# 아찌발
# 보냈는데
# 다시보냄
# 모르네
# 제목은
# 왜따라하신겈
# 몰랔
# 난또아는줄
# 저분프사에
# 존예각인데
# 턱좀
# 돌려깎았음
# 깎기전후
# 턱
# 동영상만든거나보여줌
# 대웃김
# 배찢어질거같음
# 킬포
# 나도아는줄알았다곸
# 모냐고
# 물소리
# 샤워중이래
# 방구썰웃긴거개많음
# 나중에알랴줌
# 뭐드라
# 베라에서
# 같이쿼터먹는디
# 둘이서
# 암살방구꼈는디
# 맡고
# 아이씨
# 썩은무국냄샤너
# 음성지원된다고
# 그만껴
# 방구
# 아존나울겨
# 무가
# 무국에있는
# 썩은냄새다
# 정확히말하면
# 맡기실헝
# 유리창보면서
# 먹었는데
# 똥좀
# 고양이가
# 뛰어서지나갔는데
# 도망가잖아
# 아개쳐웃기네
# 전나어러
# 더러
# 똥을
# 우리앞에선
# 참아줘서
# 파티에서쫓겨날거같아서
# 사람들이거든
# 왜녀면
# 우린진짜
# 쫒아낼
# 뚝떨어짐
# 입맛이
# 광인데
# 조지고
# 짜파게티
# 아픈교
# 어데가
# hoxy••
# 이시국으로미루어볼때
# hoxy
# seolma
# 너네들도
# 격리됨
# 이동경로중
# 인터넷에
# 친구집
# 화양동소재
# 두통
# 안나고
# 열은
# 기침안하면
# 된겨
# 기침도
# 갑자기왜
# 두통은
# 병원가볼라고
# 집에만있어서
# 두통있믄거아님
# 그러던데
# 나가눈대
# 두통이
# 아니넹
# 병원갔다가
# 시국에
# 더걸린다굿
# 아프니까
# 참을랚는데
# 먹어봤어
# 잡아달라햐봐
# 특실로
# 병실
# 두통약
# 괜찬은데
# 나이동갑애가
# 아니두통이
# 암걸리고
# 생지
# 암걸린애는
# 말안해줫자너
# 원래자주오니까
# 편두통은
# 괜찮을겨
# 받았대
# 시한부
# 암으로
# 건강검진
# 받으셈
# 받을라고
# 나이에도
# 암이옴
# 언제가냐
# 허얼
# 주기적으로
# 검진받아
# 간호학과라서
# 건강검진받았는데
# 멀쩡한데
# 암발견했데
# 초기라서
# 나이에
# 암걸리면
# 위험하데
# 개무섭겠다
# 세포활동이
# 엄청빠르게
# 전이된데
# 혈기왕성하니껜
# 나타나면
# 말기라서
# 손못쓴데
# 암은
# 증상이
# 6개월
# 건강했난데
# 그러더니
# 댕기고
# 못걷겠다
# 받았데
# 병원가니까
# 암말기라소
# 옴청
# 운동도
# 톡방애들중한명
# 대구라서
# 면회도
# 인사한데
# 창문으로
# 노노아님
# 사람이란게
# 죽을지
# 오늘을
# 행복하게
# 언제죽어도
# 여한없움
# 과외할듯
# 과외를
# 수학과외
# 중2
# 엥무슨과목
# 뭔과외
# 맞는거
# 벌어
# 앜대박
# 왜맞냐고
# 내친구학원알바하는데
# 2시간씩
# 35마넌
# 주2회에
# 주3하면
# 졸라웃기네
# 쏠쏠하다
# 중2면
# 구햇어
# 이란이
# 개마니버네
# 할만할듯
# 가방잘알
# 모셔봅니다•••
# 거리에서
# 보인대
# 생긴
# 아시는뷴
# 요즘은자물쇠가유행이냐
# 유행알못현양
# 멀라나도
# 알게되면
# 연락주삼
# 이필터
# 양파망쓴줄
# 몰라혀
# 안써서
# 필터를
# 개욱기게
# 세상억울상
# 누군데
# 귀엽닼
# 똥개야
# 머리털이
# 사잔데
# 양같은뎈
# 진즉
# 저게뭐람
# 첨앎
# 개극혐이다
# 나두함
# 나이뚜
# 이거봐버림
# 에셈알이고뭐고
# 프로듀스101
# 아이즈원이었나
# 열어분
# 놀자놀자
# 너네집가지말라묘
# 흥칫뿡
# 밖에서놀쟈고
# 인터넷기사에
# 친오빠
# 도용당험
# 오빠여친
# 인스타인데
# 갖다썼나봄
# 실화냐역시
# 인사이트
# 머여언니한테
# 왜구러셨어요
# 누구세요
# 동아리사람임
# ingi
# 동아리임
# 어님어님
# 얘둘야퓨
# 이게무슨일이야
# 환영합니다
# 계약써서
# 단톡방에
# 초대되자마자
# 마감할때
# 시세맞춰놓도가거든
# 4800원이나
# 부족한게
# 빈다는거임
# 아는거임
# 계산을
# 말도안되잖아
# 몇개월이나
# 메꾸고
# 속상한채로
# 집가는둥인데
# 5천원
# 기사님이
# 가져가거지고
# 비는거였음
# 울뻔햇다
# 다행이닼
# 너잘못
# 다행이다진짴
# 명예
# 복구
# 매니저님인데
# 감사합니다햇다
# 울면서
# 속상했죠
# 착하다
# 스췻해라
# 윗
# 괜처나
# 그치만
# 속상했어
# 마음졸였을꼬
# 얼매나
# 연혀니
# 스췻한건
# 꾹
# 눙물
# 탐았다
# 오해풀고싶은데
# 말하긴
# 잘못없눈뎅
# 뭔느낌인지
# 오해를
# 파리지앵들의
# 풀고자
# 15명이나있는데
# 수치플
# 실수
# 아니에요
# 열허분
# 하고싶네
# 쪽이냐고
# 현영의
# 잘했더
# 쩔지
# 헤헷뚝섬사람
# 줫나줜나
# 날씨존나좋자나
# 나도놀러가는즁
# 멋있겠다
# 와개쩔어
# 어디가셈
# 서촌
# 멀리
# 뭐로만든거
# 입은
# 흰색
# 취주
# 치즈
# 앜마늘인줄
# 가고싶었는디
# 매늘은좀
# 우리한테도
# 해줘
# 어이쿠저런두번은모태
# 우리도시락먹고배1도안차서
# 황금올리브반반시킴
# 아니이거
# 뚜레쥬르
# 배달안되냐
# 빠바랑
# 쿠키는
# 받아봤는데
# 푸는
# 노가다로
# 머리로
# 풀거나
# 풀수
# 있더라고
# 좆됬음
# 중딩은
# 푸는방법이
# 그떄그때
# 다까먹음
# 공부해가야됨
# 선생님다신안함
# 짲응나서
# 후회된다
# 개쩌는게
# 우도에서
# 지갑잃어버렸는데
# 서귀포파출수에서
# 받기로함
# 노트북을
# 두고왔었다네
# 들고간
# 공항갔는데
# 찜질방에서
# 정진수
# 재택근무함
# 생각하면
# 진수탈출이
# 꿈만같다
# 다시금
# 행복함을
# 어케살았냨
# 살랑해요
# 후족발야시장
# 야요즘
# 잘되지않냐
# 따뜻해서
# 식당
# 잘된다는디
# 공항가는길에
# 공항가소
# 난리도
# 발견됬데
# 신분증없어서
# 아니었음
# 없어진고
# 우도
# 해수욕장에서
# 2팀
# 어이쿠
# 그돈
# 알바비로
# 주셨겠네
# 사장넴
# 안타까운
# 삼겹살먹을깨
# 스낵랩
# 쟁반짜장
# 스낵랩은뭐냐
# 디저트로
# 말한거지
# 엽떡먹음
# 목음
# 에엣
# 누구긴
# 비어서
# 오빠집에서시킴
# 배참
# 스낵랩3개
# 간고야
# 부타
# 삽겹살
# 한쵸
# 한표
# 짜장
# 노맛이라매
# 유튜버들도
# 애매하다함
# 오매개쉬
# 오아아아아아악
# 비계
# 잘못걸림
# 따흑
# 얼려놨더거든
# 한번먹을양으로
# 주방장같은데
# 제육도만듬
# 제대로네
# 강쥐같지않아
# 강쥔줄
# 아들아
# 팔도비빔면은
# 라면이야
# 딱말해
# 라면이지
# 비빔면이지
# 개빡치네
# 답은
# 있었던거야
# 정해져
# 내기해쏘
# 비빔면
# 계란후라이랑
# 맛있씀
# 식혜좋아햐는사람
# 식혜빡
# 이임
# 빠순이임
# 식혜한병주까
# 만드는거임
# 식혜맛임
# 대구갔다와서
# 줄께
# 가져갈래
# 달래도
# 개꿀맛임
# 달래
# 만들어서
# 비벼먹으면
# 양념장
# 콩나물밥에
# 넣어먹고
# 된장에
# 뿌리는
# 20대
# 캔거다
# 달래캠
# 쑥이랑
# 아앗
# 식혜
# 캔거냐곸
# 달래양념장비빔밥
# 지의집가서
# 양념장도
# 다가져가
# 밥빼고
# 안만들었냠
# 양염장
# 달래양념장을
# 왜만들어
# 안만듦
# 지의다시읽어보니
# 야영현집들이한지
# 이주지남
# 안만들었는데
# 양념장아직
# 뭘달라는거야
# 만남을
# 뭐만드는거
# 정모
# 예쁜쓰레기
# 만드는거야
# 뭘로
# 굳히면
# 끈적한액첸데
# 딱딱해짐
# 레진이라는걸로
# 만듦
# 처음에는
# 틀에부어서
# 뉑정답
# 달래양념장
# 톡내용오이로냨
# 단톡인줄
# 맘들
# 구니깤
# 붕알친구랑키스하기vs친구붕알에
# 키스하기
# 닌뭐임
# 뒷북뭐야
# 뒷북임
# 같은애라면
# 전자
# 성살했다
# 상상
# 붕알에할바에
# 감고
# 귀챊아서
# 그와중에도
# 꾿꾿이
# 자는척하는데
# 유튜부하냐
# 꿋꿋이
# 하는더같던데
# 먹꼬사라요
# 대박임
# 배웠데
# 유투브보고
# 편집
# 초3인대
# 요즘초딩들
# 유튜버
# 장래희망1위
# 11명
# 구독자
# 위도우저격수
# 꽃남
# 놀았는데
# 초3땐
# 패러디하고
# 60명찍어봤어
# 영우도
# 뭐올리는데
# 영우는
# 게임영상
# 5개로
# 구독해준건
# 자기계정
# 안비밀
# 꽃밍아웃
# 5명
# 놀았잖아
# 금잔디
# 동년배로안침
# 스키
# 안해봤으면
# 젤이뻐
# 다저장해야즤
# 졸구탱
# 왤캐좋아진짜
# 무적권1
# 무적권1나도
# 와개졸귀0
# 비교돼
# 확대한거야
# 귀여워귀여운데
# 저것두
# 쮸발
# 예쁜거야
# 그건맞아
# 강쥐래
# 댕청댕청해
# 남의개임
# 길가다만남
# 무슨종인지
# 아눈사람
# 세종대
# 종이들
# 저아이
# 잡종같은데
# 비숑푸들
# 기억이안나
# 다른견종이
# 이쁜
# 즐길줄아는
# 풍경을
# 올만이넹
# 마늘바게트
# 썰다가
# 떨어뜨렸는데
# 점심으로
# 해결
# 내가계산할뻔
# 아시방개웃
# 그녀의귀여운
# 미스테잌
# 저거보단
# 손가락
# 케잌에
# 푹
# 웃을일이
# 슬라임급
# 촉감
# 아씨케이크슬라임
# 슬라임의
# 남다르구나
# 스케일을
# 이친구
# 크게노네
# 덤
# 미움받는건
# 추천
# 한번씩
# 해보세요
# 손담갔다빼야겠다
# 족발에
# 손담궈도됨
# 커피에
# 죨라웃기네
# 맥주마실사람
# 아수욜저녁
# 개빠르당
# 외않자
# 지금😊
# 돼지다
# 지대로먹이시네
# 이럳때먹어야지
# 야나두
# 양념막창
# 니들은
# 그런사람
# 만족을
# 안정적이고
# 육체적으로
# 정신적으로
# 줄수있는사람
# 1번이랑
# 사귀면서
# 파트너해
# 1번을고르면
# 스킨쉽을못함
# 고르는건
# 둘중에
# 동의
# 개소리였다
# 라해
# 만낭
# 좋아하는
# 어어어니어낭
# 반갑다
# 개비교돼
# 내말
# 만날수있는사람
# 영혀니랑
# 팟
# 해줄사람
# 혹싀
# 저욧
# 언제정햤어
# 당사자
# 모르고있었던것
# 꺄아
# 대환영
# 시험기간이지만
# 같이만나자
# 기억나가지고
# 난좋은데
# 시험주라서모르겠다
# 이러지않았나
# 같이못머거둥
# 저녁정도는
# 함께할수있음
# 밥이라도
# 세은이도온다고해서
# 간맥할사람은
# 헤어지던가
# 밥만같이먹고너네술먹어도되고욤
# 조앙
# 구러장
# 나두나두
# 올만에
# 찾아봐여디
# 새로운거
# 새로운데
# 하고싶따
# 나도찾아봐야즤
# 🥺♥️
# ❤️❤️❤️
# 고마어
# 일빠따로
# 축하해주네
# 시간맞춰서
# 축하못해줄까버큐
# 개강이얌
# 너네두
# 몰느는
# 휴학생
# 부럽넹
# 입학하자마자
# 휴학하고싶어
# 다니는
# 아니야😢😢
# 화이트크림
# 크림
# 화이트닝
# 구만원에서
# 삼만원
# 반사광
# 지의스탈
# 올싸강됐데
# 확정남
# 언니뭐라고
# 왤캐놀럌
# 와웅결국
# 나왔음
# 너넨개강해
# 안나왔어
# 세종대도
# 기대한다
# 존버
# 싸강할듯
# 개강은에바야4
# 450
# 싸강에
# 합리적이네
# 돌려주겠지
# 양심있으묜
# 돌려줄꺼같음
# 안돌려줄거같은데
# 450이
# 들까
# 물도
# 안쓰는데
# 전기도
# 남는장사네
# 이사장
# 개이즉
# 대학다닌다지만
# 학위따러
# 이건쩜
# 우리학굔
# 1라도
# 남아있으묜
# 양심이
# 상업적잉라서
# 정떨어짐
# 뱉어내
# 위로금이라도
# 상업적으로
# 생각하는거밖에
# 학생을
# 위한
# 학교시설도
# 학굔데
# 학생보단
# 돈버는
# 용이고
# 외부인용이고
# 상업단지를
# 이럴거면
# 지어야지
# 학교말고
# 에스컬레이터가동
# 외부인올때만
# 헤어지고왓어
# 뻥찼지
# 란잔하자
# 다음주에
# 썰은
# 술마시면서
# 로주
# 롼잔하자
# 로주롼잔은누가알려줬니
# 가구싶네잉
# 글쿠나
# 영현이이이
# 잘했어
# 울컥스여
# 잘했다는
# 날잡고
# 놀러왕
# 언제한번
# 끝나면은
# 모르겠지만
# 볼지
# 코다차야가
# 민수가
# 쥰나많이갔다는디
# 압구정이래
# 지점여러개임
# 근데그때
# 술안먹는애들
# 있지않나
# 자구시험이야
# 칭긔들
# 근데뭐
# 가고싶은대로가면되지모
# 놀애들
# 에바당
# 멀리가면
# 오메근데
# 시험은
# 오프라인으로봄
# 그럴라했는데
# 바꼈으면
# 시험도
# 좋겠당헤헷
# 과제대체했으묜
# 에이가자
# 절대평가다같이
# 웨않자
# 깨있는
# 시간아냐
# 이시간은
# 고롬
# 서식시간인걸
# 새삼
# 웨않자냐니
# 당여나지
# 하위다들
# 밤이되었습니다
# 고개를
# 들어주세요
# 마피아들은
# 죽일게요
# 스륵••
# 마피아야
# 두명이었던거임
# 마피아
# 6명인데마피아가
# 둘이라••
# 쉽구만
# 공분는
# 잘하고있나유
# 시험기간인게
# 그래써
# 학교다닐땨도
# 근데싸강으로
# 대학수업들으면
# 시험안칠확률이
# 높다고하니까
# 궁금하다
# 엌던지
# 더실감안남
# 같고
# 듣기싫어
# 개조은디
# 아니근학교안가서
# 우주공강두없구
# 죳망했는데
# 미룰수있어서
# 좋긴해
# 장점이라면
# 딱인데
# 기분도
# 휴학한
# 나중은
# 과제라
# 그래성
# 설문조사
# 해주랑
# 해쏘요
# 앉았는
# 임산부삭
# 나두했삼
# 고마워❤
# 맛집
# 있찌
# 열불날개
# 먹어봄
# 날개랑
# 닭발은
# 막창
# 였던거같움
# 막창사랑해
# 마싯음
# 막창이
# 왜너네만가
# 암되겟다
# 헤쳐모여
# 월요일이나
# 바쁘지
# 놀아줄
# 아루바이투
# 일욜이면
# 고고
# 다닌당
# 미술학원
# 너근데좀잘그림
# 꿈꾸며•••
# 전과를
# 좋겠당
# 오일파스텔
# 개부러
# 유화
# Wow
# 미완성인데
# 요오
# 눈썹같은거
# 밑색칠한고
# 크게크게
# 그렸네👍👍
# 잘한다
# 달리밴퓌카소
# 등쟝
# 그려줘라
# 유명해지기전에
# 그럴일없어
# 일주일기다림
# 재밌어서
# 취미미술인데
# 뿌듯할듯뿌듯뿌듯
# 완성되면
# 개잘했다
# 와멋지다
# 미밴드
# 3만원대
# 기능
# 그게뭐죠
# 방수
# 애플워치
# 다할수있으몀
# 애플워치급
# 3만원이야
# 다되는데
# 샤오미라
# 싸당
# 없는겨
# 저거말고
# 다되면
# 좋을거같은데
# 지의아니지
# 토너오
# 맞데
# 맞긴뭘맞앜
# 이거해보고싶따
# 디자인하게
# 나랑할래
# 재밌겠당
# 저번껀데
# 완성
# 미완성
# 완성되고있씀
# 사람되는중
# 어렵노
# 유화는
# 처음이라
# 한번그려보고
# 옹사람이
# 저번보다
# 하얘짐
# 이디야임
# 지원할까말까
# 주말
# 사람많아
# 없진않은거같운데
# 거를게
# 많은건
# 아닌거같고
# 왜언급나두몰랑
# 가족같이
# 근무할
# 내가족은
# 집에잇어요
# 우리떠
# 정모해야지
# 7월
# after
# ❓
# 기말기간임
# 네고갠님
# 주인윗몸일으키기도와주는개
# 심쿵
# 견주
# 가능여
# 이천번
# 저런강쥐잇으면
# 댓글
# 여친
# 저기안에
# 들어있다고
# 크기보면
# 1개뿐이거든
# 같이들가더라
# 공용화장실
# 남녀
# 좁은데를
# 미췬것들
# 담주부턴
# 딴그림
# 강아지봐
# 그리는거야
# 나중엔
# 명화같다
# 잘안잡힘
# 예쁘당

# %%
# 사람이 이해할 수 있는 형태로 코퍼스 사전 재구성 해보기 (term-frequency)
[[(dictionary[id], freq) for id, freq in cp] for cp in corpus[:]]
# Out:
# [[('결국', 1.0), ('안먹음', 1.0), ('엥', 1.0)],
#  [('가는거야', 1.0),
#   ('그', 1.0),
#   ('그래서', 1.0),
#   ('너', 1.0),
#   ('야구부', 1.0),
#   ('엠티는', 1.0)],
#  [('안가', 1.0)],
#  [('근엄마한테갈거라고말해놓긴햇는디', 1.0)],
#  [('보내준다허면', 1.0)],
#  [('개이득', 1.0)],
#  [('파리타임', 1.0)],
#  [('마커롱', 1.0), ('먹고싶따', 1.0)],
#  [('마카롱임', 1.0)],
#  [('바보야', 1.0)],
#  [('야웃김', 1.0)],
#  [('고딩때보내줫는데', 1.0), ('내', 1.0), ('내친구가', 1.0)],
#  [('리얼', 1.0)],
#  [('얼굴이', 1.0)],
#  [('프라이팬', 1.0)],
#  [('아개웃곀', 1.0)],
#  [('그린줄', 1.0), ('동그라미임', 1.0), ('컴퍼스로', 1.0)],
#  [('그', 1.0), ('뭐지', 1.0), ('반응은', 1.0)],
#  [('고딩때야', 1.0)],
#  [('개똑같아', 1.0), ('지금이랑', 1.0)],
#  [('귀엽지', 1.0), ('얘그라', 1.0), ('이거어때', 1.0)],
#  [('똑같다니', 1.0), ('야', 1.0)],
#  [('귀여오', 1.0)],
#  [('시부랭', 1.0)],
#  [('이주희', 1.0), ('작가임', 1.0)],
#  [('에바참치쌈싸서', 1.0), ('저얼굴이면', 1.0), ('지금도', 1.0), ('한입에털어넣야됨', 1.0)],
#  [('털어넣으셈', 1.0)],
#  [('근데', 1.0), ('똑같음', 1.0)],
#  [('참치쌈싸서', 1.0), ('털어놓어야함', 1.0)],
#  [('똑같다고', 1.0), ('레알', 1.0)],
#  [('개충격', 1.0), ('시방', 1.0)],
#  [('컴퍼스', 1.0)],
#  [('잠깐만', 1.0)],
#  [('레알똑같넼', 1.0)],
#  [('시부랰', 1.0)],
#  [('진현영대잔치', 1.0)],
#  [('아닠', 1.0)],
#  [('다른점', 1.0)],
#  [('떡지고', 1.0), ('안떡진고', 1.0), ('앞머리가', 1.0)],
#  [('개좋앜', 1.0)],
#  [('앜', 1.0)],
#  [('미틴', 1.0)],
#  [('존나', 1.0), ('행복하다', 1.0)],
#  [('깜찍', 1.0)],
#  [('왴', 1.0)],
#  [('개욱겨', 1.0), ('아근데', 1.0)],
#  [('널', 1.0), ('좋아해버렷', 1.0)],
#  [('똑같이', 1.0), ('생겼는데', 1.0)],
#  [('똑같으면', 1.0)],
#  [('쌈싸목는다', 1.0), ('에바', 1.0)],
#  [('쓸거얌', 1.0), ('으로', 1.0), ('저거', 1.0), ('진짜', 1.0)],
#  [('레알똑같을줄은', 1.0), ('아니', 1.0)],
#  [('자가', 1.0)],
#  [('겟아웃오브히얼', 1.0)],
#  [('이거', 1.0), ('잘못하더거', 1.0)],
#  [('단톡에', 1.0), ('데사', 1.0), ('보낼뻔', 1.0)],
#  [('야', 1.0)],
#  [('보내지', 1.0), ('아', 1.0)],
#  [('진짜', 1.0)],
#  [('죽을뻔', 1.0)],
#  [('너', 1.0), ('죽일뻔', 1.0)],
#  [('보내면', 1.0)],
#  [('진현영', 1.0)],
#  [('자퇴할까봐', 1.0)],
#  [('레알', 1.0)],
#  [('휴학신청서', 1.0)],
#  [('끄적', 1.0)],
#  [('야주희', 1.0)],
#  [('몰겠눙데', 1.0), ('물어봐도되나', 1.0), ('이런거', 1.0)],
#  [('걍', 1.0), ('물오봄', 1.0)],
#  [('사귀제', 1.0), ('정우철이랑', 1.0)],
#  [('헐', 1.0)],
#  [('눈치로', 1.0), ('다아네', 1.0), ('뭐야', 1.0)],
#  [('나만눈치가', 1.0), ('준내없엇군', 1.0)],
#  [('언제부터야', 1.0)],
#  [('준내', 1.0)],
#  [('2주됫데', 1.0)],
#  [('시방', 1.0)],
#  [('왜비밀로함', 1.0)],
#  [('나도며칠전에앎', 1.0)],
#  [('몰라이제', 1.0)],
#  [('거의', 1.0), ('공개임', 1.0)],
#  [('애들다알어', 1.0)],
#  [('나만몰랐쓤', 1.0)],
#  [('나도몰랏음', 1.0)],
#  [('야넌근데', 1.0)],
#  [('17에도', 1.0), ('몇명은', 1.0), ('안댕', 1.0)],
#  [('눈치로', 1.0), ('안다', 1.0)],
#  [('난', 1.0), ('말안해줙음', 1.0)],
#  [('아니', 1.0), ('이걸', 1.0)],
#  [('평생', 1.0)],
#  [('이제물어본다고', 1.0)],
#  [('썸인줄', 1.0)],
#  [('젤늦게암', 1.0)],
#  [('그리고', 1.0), ('대답', 1.0)],
#  [('내가할랬는데', 1.0)],
#  [('진현영', 1.0), ('니가말해', 1.0), ('왜', 1.0)],
#  [('아니', 1.0), ('언니그때', 1.0)],
#  [('아', 1.0), ('나', 1.0)],
#  [('아니', 1.0)],
#  [('이언니', 1.0), ('주현', 1.0)],
#  [('그', 1.0)],
#  [('화욜날', 1.0)],
#  [('쉬는시간에', 1.0), ('씨', 1.0)],
#  [('웅웅', 1.0)],
#  [('편의점에서', 1.0)],
#  [('고백언헌더고', 1.0), ('정우철한데', 1.0)],
#  [('존나', 1.0), ('냐가', 1.0), ('지랄할때', 1.0)],
#  [('씨쉬는시간을쉬싸는시간으로봄', 1.0)],
#  [('다웃었잖아', 1.0), ('옆에', 1.0)],
#  [('맞아', 1.0)],
#  [('그때', 1.0)],
#  [('말안해주고', 1.0)],
#  [('배창현이', 1.0)],
#  [('그썰들었다', 1.0), ('지의야', 1.0)],
#  [('너무허다', 1.0)],
#  [('눈짓으로', 1.0)],
#  [('개웃기네', 1.0)],
#  [('이런거', 1.0), ('보는맛에', 1.0)],
#  [('조용히', 1.0), ('하라고', 1.0), ('함', 1.0)],
#  [('비밀로', 1.0), ('사겼지', 1.0)],
#  [('개사악해', 1.0)],
#  [('미친', 1.0)],
#  [('소리나', 1.0)],
#  [('그래서', 1.0)],
#  [('다웃는거', 1.0)],
#  [('그때는', 1.0), ('몰랐는데', 1.0)],
#  [('긱사와소', 1.0)],
#  [('생각하니까', 1.0)],
#  [('뭔가', 1.0), ('이상하길랴', 1.0)],
#  [('웃곀', 1.0)],
#  [('정우철카톡상메보니까', 1.0)],
#  [('되있길래', 1.0), ('생일축하해', 1.0)],
#  [('사귀는가', 1.0)],
#  [('이랬씀', 1.0)],
#  [('앜', 1.0)],
#  [('난', 1.0), ('그것도', 1.0), ('그럴수잇지', 1.0), ('보면서', 1.0), ('좋아하니까', 1.0)],
#  [('이럼', 1.0)],
#  [('드라마썼구나', 1.0), ('헌자', 1.0)],
#  [('스뱔', 1.0)],
#  [('진현영', 1.0)],
#  [('1도없어', 1.0), ('진짜눈치', 1.0)],
#  [('진현영', 1.0)],
#  [('도토리묵임', 1.0)],
#  [('현영이가', 1.0)],
#  [('나', 1.0), ('눈치은근잇는디스방', 1.0)],
#  [('알았어야돼', 1.0), ('젤마지막에', 1.0)],
#  [('도토리묵', 1.0), ('잠만', 1.0)],
#  [('뭐옄', 1.0)],
#  [('내가', 1.0), ('너무', 1.0), ('빨리말해줬다', 1.0)],
#  [('난', 1.0), ('왜', 1.0), ('말안해줘', 1.0)],
#  [('개답답', 1.0)],
#  [('당최', 1.0), ('무슨비유냐', 1.0)],
#  [('도토리묵', 1.0)],
#  [('딱이야', 1.0)],
#  [('윤지의', 1.0)],
#  [('뭔가', 1.0), ('되게', 1.0)],
#  [('관심이', 1.0), ('많아보이길래', 1.0)],
#  [('관심가지나', 1.0), ('언제까지', 1.0)],
#  [('궁금해소', 1.0)],
#  [('방금', 1.0)],
#  [('담푸허다가', 1.0)],
#  [('만났는데', 1.0), ('박도형', 1.0)],
#  [('사귀는가', 1.0)],
#  [('이제알았다니까', 1.0)],
#  [('왜', 1.0), ('알았네', 1.0), ('이제', 1.0)],
#  [('담푸가', 1.0)],
#  [('뭐여', 1.0)],
#  [('이제', 1.0), ('아냐고', 1.0), ('어떻게', 1.0)],
#  [('뭐여', 1.0), ('담푸는', 1.0), ('또', 1.0)],
#  [('맞아', 1.0)],
#  [('담배푸기', 1.0)],
#  [('담배', 1.0), ('퓌우기', 1.0)],
#  [('미친', 1.0)],
#  [('뭐야', 1.0), ('푸기는', 1.0)],
#  [('담푸라닠', 1.0)],
#  [('피기도아니고', 1.0)],
#  [('담피라하지않나', 1.0)],
#  [('원래', 1.0)],
#  [('기', 1.0), ('담푸', 1.0)],
#  [('이거임', 1.0)],
#  [('푸', 1.0)],
#  [('아니면', 1.0)],
#  [('고', 1.0), ('담타', 1.0)],
#  [('나내일', 1.0)],
#  [('개적절', 1.0), ('짤', 1.0)],
#  [('생리공결쓸래', 1.0)],
#  [('오', 1.0)],
#  [('엑스', 1.0)],
#  [('부럽다', 1.0)],
#  [('일찍일어나기', 1.0), ('쥰내귀찮아', 1.0)],
#  [('와', 1.0)],
#  [('아니', 1.0), ('왤케마니쎀', 1.0)],
#  [('시부랑', 1.0)],
#  [('차라리', 1.0)],
#  [('나는', 1.0), ('써버려서', 1.0), ('이미', 1.0), ('저번주에', 1.0)],
#  [('담주', 1.0)],
#  [('불가능', 1.0)],
#  [('나', 1.0), ('뭐래', 1.0), ('엠티때', 1.0), ('한번씀', 1.0)],
#  [('화욜날쓰지', 1.0)],
#  [('그럼', 1.0)],
#  [('담주화욜', 1.0)],
#  [('금토일월화수', 1.0), ('놀수있씀', 1.0)],
#  [('주현', 1.0), ('언냐는', 1.0), ('쩔수없이', 1.0)],
#  [('흠', 1.0)],
#  [('금토일월화숰', 1.0)],
#  [('지림', 1.0)],
#  [('화요일은', 1.0)],
#  [('실습있응게', 1.0)],
#  [('그냥', 1.0), ('오늘쓸래', 1.0)],
#  [('실습을', 1.0), ('챙긴다고', 1.0)],
#  [('문쓰발도', 1.0), ('하야되서', 1.0)],
#  [('그때', 1.0), ('나어차피', 1.0), ('잠', 1.0)],
#  [('화요일축제아님', 1.0)],
#  [('첫번째', 1.0)],
#  [('씨씨가', 1.0)],
#  [('또', 1.0), ('두번째', 1.0), ('씨씨', 1.0), ('있을꺼같으면', 1.0)],
#  [('말쫌', 1.0), ('미리', 1.0)],
#  [('제발', 1.0)],
#  [('나만', 1.0), ('늦게암', 1.0), ('맨날', 1.0)],
#  [('두번째씨씨', 1.0)],
#  [('진현영이항', 1.0)],
#  [('민준', 1.0), ('은비', 1.0)],
#  [('각', 1.0)],
#  [('탱', 1.0)],
#  [('임그거', 1.0)],
#  [('민준', 1.0)],
#  [('민준이오빠', 1.0)],
#  [('각이야', 1.0)],
#  [('아님', 1.0), ('은비는', 1.0)],
#  [('에이', 1.0)],
#  [('지랄', 1.0)],
#  [('레알임', 1.0)],
#  [('설마', 1.0)],
#  [('민준오빠가', 1.0)],
#  [('러브', 1.0), ('은비를', 1.0)],
#  [('둘이', 1.0)],
#  [('단둘이', 1.0), ('술도먹고', 1.0)],
#  [('밥도먹고', 1.0)],
#  [('씨할때보니깐', 1.0)],
#  [('민주니오빠가', 1.0)],
#  [('헐', 1.0)],
#  [('활짝웃느면서', 1.0)],
#  [('톡하길래', 1.0)],
#  [('뭐여', 1.0)],
#  [('단둘이', 1.0), ('술밥', 1.0)],
#  [('봣는데', 1.0)],
#  [('얼핏봣을때', 1.0)],
#  [('프사음비', 1.0)],
#  [('활짝웃는다', 1.0)],
#  [('그걸', 1.0), ('니', 1.0), ('훔쳐봄', 1.0)],
#  [('민쥰상', 1.0)],
#  [('왠만하면', 1.0)],
#  [('범죄아님', 1.0)],
#  [('씨할때', 1.0)],
#  [('안웃는데', 1.0)],
#  [('리얼', 1.0)],
#  [('화알짝', 1.0)],
#  [('가만냅도', 1.0)],
#  [('그래서', 1.0)],
#  [('뭘깡', 1.0)],
#  [('대체', 1.0)],
#  [('언제', 1.0), ('연애할꼬여', 1.0), ('현영이는', 1.0)],
#  [('차가운', 1.0)],
#  [('쥰상을', 1.0)],
#  [('드라마쓴다또', 1.0), ('진혀녕', 1.0), ('혼자', 1.0)],
#  [('그놈에', 1.0), ('자연스러운만넘', 1.0)],
#  [('웃게한', 1.0)],
#  [('그녀는', 1.0), ('누굴깡', 1.0)],
#  [('너무', 1.0), ('아진짜', 1.0), ('웃겨', 1.0)],
#  [('그래서', 1.0)],
#  [('니', 1.0), ('니는', 1.0), ('연애부터', 1.0), ('해야되', 1.0)],
#  [('염탐', 1.0)],
#  [('쥰상', 1.0)],
#  [('짤', 1.0)],
#  [('20년울', 1.0), ('어떠케', 1.0)],
#  [('모쏠이지', 1.0)],
#  [('시부랭', 1.0)],
#  [('그정도면', 1.0)],
#  [('윤지읰', 1.0)],
#  [('수녀아님', 1.0)],
#  [('윤지의', 1.0)],
#  [('모솔이', 1.0), ('어때서요', 1.0)],
#  [('욕을해', 1.0)],
#  [('수녀', 1.0)],
#  [('발락', 1.0)],
#  [('수녀가', 1.0)],
#  [('될거임', 1.0)],
#  [('진현영', 1.0), ('모쏠탈출프로젝트', 1.0), ('해줘야험', 1.0)],
#  [('곧', 1.0), ('마법사되는거', 1.0)],
#  [('아님', 1.0)],
#  [('센빠이', 1.0), ('주형이', 1.0)],
#  [('레알', 1.0)],
#  [('도와줘', 1.0)],
#  [('근데', 1.0), ('주형센빠이는', 1.0)],
#  [('얘들아', 1.0)],
#  [('넘사벽임', 1.0)],
#  [('쌉', 1.0)],
#  [('넘사', 1.0)],
#  [('도도', 1.0)],
#  [('야들아', 1.0)],
#  [('그냥', 1.0)],
#  [('높이가달라', 1.0)],
#  [('샙', 1.0)],
#  [('샵', 1.0)],
#  [('도도', 1.0)],
#  [('그', 1.0), ('근데', 1.0), ('나', 1.0), ('조교님', 1.0)],
#  [('왜나옴', 1.0)],
#  [('못만날것같어', 1.0)],
#  [('샵도돜', 1.0)],
#  [('아', 1.0)],
#  [('왜', 1.0)],
#  [('왜', 1.0)],
#  [('언냐', 1.0)],
#  [('언니', 1.0)],
#  [('다아는거임', 1.0)],
#  [('웅웅', 1.0)],
#  [('아래까지만해도', 1.0), ('어제', 1.0)],
#  [('귓속말로', 1.0), ('영현이한테', 1.0), ('했는데', 1.0)],
#  [('모른다고', 1.0), ('아무도', 1.0)],
#  [('입닫으랬는데', 1.0)],
#  [('벌써', 1.0)],
#  [('존나', 1.0), ('말함', 1.0), ('술자리에서', 1.0), ('크게', 1.0)],
#  [('다언덕', 1.0)],
#  [('야', 1.0), ('아니', 1.0), ('현영이', 1.0)],
#  [('미팅하는거', 1.0), ('소웨랑', 1.0)],
#  [('거기서', 1.0), ('잡아와야해', 1.0), ('한명', 1.0)],
#  [('미팅함', 1.0)],
#  [('나도', 1.0), ('미팅할래', 1.0)],
#  [('시방', 1.0)],
#  [('과팅', 1.0)],
#  [('소우', 1.0)],
#  [('소웨', 1.0)],
#  [('윤지의', 1.0), ('남친은', 1.0)],
#  [('과팅할래', 1.0), ('나고', 1.0)],
#  [('아니', 1.0), ('분위기만띄워주고', 1.0)],
#  [('쓸쓸히', 1.0)],
#  [('퇴장각', 1.0)],
#  [('난', 1.0), ('남친말고', 1.0)],
#  [('걍', 1.0)],
#  [('야너는', 1.0)],
#  [('갈꺼임', 1.0), ('뻘러', 1.0), ('술존너', 1.0)],
#  [('나단이나', 1.0)],
#  [('어케해봐', 1.0)],
#  [('다시안만나니', 1.0)],
#  [('나단이', 1.0), ('알면', 1.0)],
#  [('이제', 1.0), ('나단이', 1.0), ('버려', 1.0)],
#  [('헐', 1.0)],
#  [('야', 1.0), ('헤어짐', 1.0)],
#  [('앵', 1.0)],
#  [('엥', 1.0)],
#  [('이주희', 1.0)],
#  [('진짜', 1.0)],
#  [('감옥갔다왔나', 1.0), ('어디', 1.0)],
#  [('엥', 1.0)],
#  [('늦게암', 1.0), ('둘이', 1.0), ('제일', 1.0)],
#  [('엥또리', 1.0)],
#  [('서로', 1.0)],
#  [('감옥', 1.0)],
#  [('언젠데', 1.0), ('헤어진지가', 1.0)],
#  [('긘까', 1.0)],
#  [('왜', 1.0), ('서로', 1.0), ('모르냐', 1.0), ('우리', 1.0)],
#  [('야', 1.0)],
#  [('아니', 1.0), ('이건진짜', 1.0)],
#  [('시방감옥', 1.0)],
#  [('나도', 1.0), ('언젠데', 1.0), ('사귄지가', 1.0)],
#  [('비밀도', 1.0), ('아니었는데', 1.0)],
#  [('왜', 1.0), ('모르지', 1.0)],
#  [('그니깐', 1.0)],
#  [('말안했자너', 1.0)],
#  [('2주', 1.0), ('되지', 1.0), ('않았나', 1.0), ('지의도', 1.0)],
#  [('걍', 1.0), ('몰랏는데', 1.0), ('세상물정을', 1.0)],
#  [('리얼', 1.0)],
#  [('에쎄꽁인데', 1.0)],
#  [('넘었쓸껄', 1.0), ('이주', 1.0)],
#  [('에쎄꽁', 1.0)],
#  [('개쩐당', 1.0)],
#  [('아', 1.0), ('나도', 1.0), ('나갈랭', 1.0), ('미팅', 1.0)],
#  [('야', 1.0), ('근데', 1.0), ('우리', 1.0)],
#  [('과팅', 1.0), ('소웨', 1.0)],
#  [('간편', 1.0)],
#  [('나도', 1.0), ('미팅쫌', 1.0), ('접아조', 1.0)],
#  [('날짜', 1.0), ('언제잡아', 1.0)],
#  [('놀다오게', 1.0)],
#  [('남았니', 1.0), ('자리', 1.0)],
#  [('낼', 1.0)],
#  [('내말이', 1.0)],
#  [('윤지의', 1.0), ('안돼', 1.0)],
#  [('자리없어', 1.0)],
#  [('자리없어', 1.0)],
#  [('걍', 1.0), ('갈꼬임', 1.0)],
#  [('지의야', 1.0)],
#  [('뭐래', 1.0)],
#  [('레알', 1.0)],
#  [('미띤', 1.0)],
#  [('물어보면', 1.0), ('영주언니한테', 1.0)],
#  [('직빵임', 1.0)],
#  [('윤지의몰래', 1.0)],
#  [('갈거임', 1.0)],
#  [('안친해', 1.0)],
#  [('야야야야', 1.0)],
#  [('이언니', 1.0), ('주현', 1.0)],
#  [('나도', 1.0), ('않아', 1.0), ('친하진', 1.0)],
#  [('낼', 1.0), ('술', 1.0)],
#  [('술', 1.0)],
#  [('나이제', 1.0), ('코다나아서', 1.0)],
#  [('미띤넘', 1.0)],
#  [('되겄지', 1.0), ('먹어도', 1.0)],
#  [('안돼', 1.0)],
#  [('웅웅', 1.0)],
#  [('의사가안됀데', 1.0)],
#  [('안되징', 1.0), ('안된다면', 1.0)],
#  [('너빼고', 1.0), ('응', 1.0)],
#  [('그리구', 1.0)],
#  [('난낼', 1.0), ('약속있다', 1.0)],
#  [('누구랑', 1.0)],
#  [('헐', 1.0)],
#  [('나', 1.0)],
#  [('철’s랑', 1.0)],
#  [('내일', 1.0), ('면접가야되내', 1.0), ('알바', 1.0)],
#  [('철수', 1.0)],
#  [('철숰', 1.0)],
#  [('철수는', 1.0)],
#  [('누구옄', 1.0)],
#  [('철이와주희', 1.0)],
#  [('철쭈', 1.0)],
#  [('철수', 1.0)],
#  [('하앜', 1.0)],
#  [('진현영', 1.0), ('낼', 1.0), ('모해', 1.0)],
#  [('내일', 1.0)],
#  [('문쓰발하고', 1.0)],
#  [('과외감', 1.0)],
#  [('쓰발', 1.0)],
#  [('시방', 1.0)],
#  [('과외쓰발', 1.0)],
#  [('낼', 1.0), ('놀자', 1.0), ('제발류', 1.0)],
#  [('내일과외잇음여', 1.0)],
#  [('밤에', 1.0), ('술목저', 1.0)],
#  [('아', 1.0), ('닌', 1.0), ('술못먹잖아', 1.0), ('어자피', 1.0)],
#  [('아맞다', 1.0)],
#  [('가', 1.0), ('영현이랑', 1.0)],
#  [('주햔언냐', 1.0)],
#  [('오늘', 1.0)],
#  [('웅', 1.0)],
#  [('변씨랑', 1.0)],
#  [('술먹은거', 1.0)],
#  [('어땟음', 1.0)],
#  [('개웃김', 1.0), ('변씨', 1.0)],
#  [('그조교이름', 1.0), ('변씨임', 1.0)],
#  [('엥', 1.0)],
#  [('아닠', 1.0)],
#  [('엠티때', 1.0)],
#  [('변준영선배라고', 1.0)],
#  [('잇음', 1.0)],
#  [('아', 1.0)],
#  [('웃긴선배', 1.0)],
#  [('나', 1.0)],
#  [('그', 1.0), ('이제', 1.0), ('조교는', 1.0)],
#  [('반영준이랑', 1.0)],
#  [('얘들아', 1.0), ('잊어', 1.0)],
#  [('변준영이랑', 1.0)],
#  [('반영준', 1.0)],
#  [('구분못함', 1.0)],
#  [('반영준', 1.0)],
#  [('아니', 1.0)],
#  [('철이와주희', 1.0)],
#  [('실화냐', 1.0)],
#  [('반영준', 1.0), ('변준영', 1.0)],
#  [('시방', 1.0)],
#  [('미친것같어', 1.0)],
#  [('반영준이랑', 1.0), ('변준영이', 1.0)],
#  [('왜구분안돼', 1.0)],
#  [('맞아', 1.0)],
#  [('니들이', 1.0)],
#  [('엠티갔다와소', 1.0)],
#  [('반영준', 1.0)],
#  [('하도', 1.0)],
#  [('반영준', 1.0)],
#  [('거리길랴', 1.0)],
#  [('에이이잉', 1.0)],
#  [('구분언됨', 1.0)],
#  [('반영줔', 1.0)],
#  [('그거', 1.0), ('다', 1.0), ('변준영이야', 1.0)],
#  [('아존니욱곀', 1.0)],
#  [('반영준', 1.0), ('얘기함적도', 1.0), ('없다', 1.0)],
#  [('사고회로', 1.0), ('정지', 1.0)],
#  [('반영준', 1.0), ('1도안함', 1.0), ('얘기', 1.0)],
#  [('반영준', 1.0)],
#  [('하앜', 1.0)],
#  [('아', 1.0)],
#  [('변준영', 1.0), ('얘기', 1.0)],
#  [('아', 1.0), ('도랏나', 1.0), ('이름', 1.0)],
#  [('비슷함', 1.0), ('왜이래', 1.0)],
#  [('반영준그아이는', 1.0), ('왜말하는걸까', 1.0), ('자꾸', 1.0)],
#  [('그정도는', 1.0), ('아니거든', 1.0)],
#  [('그냥', 1.0), ('우리', 1.0), ('다', 1.0), ('얘기하는거는', 1.0)],
#  [('변씨라고', 1.0), ('생각해', 1.0)],
#  [('반영준', 1.0), ('변준영', 1.0)],
#  [('술목저', 1.0)],
#  [('기웃깈', 1.0), ('하', 1.0)],
#  [('얘들아', 1.0)],
#  [('먹자', 1.0), ('술쩜', 1.0)],
#  [('안돼', 1.0), ('내일은', 1.0)],
#  [('20살', 1.0), ('우리가', 1.0), ('해야될일은', 1.0)],
#  [('마자', 1.0)],
#  [('내일은', 1.0), ('참으렴', 1.0)],
#  [('밖에', 1.0), ('술먹는거', 1.0), ('없어', 1.0)],
#  [('아님', 1.0)],
#  [('박도령씨랑', 1.0)],
#  [('먹어', 1.0)],
#  [('맞아', 1.0)],
#  [('본업에', 1.0), ('우리의', 1.0), ('충실하자', 1.0)],
#  [('아닠오타', 1.0)],
#  [('존웃', 1.0)],
#  [('박도형이', 1.0), ('있었네', 1.0)],
#  [('박도령', 1.0)],
#  [('박도령', 1.0), ('괜찮다', 1.0)],
#  [('둘이', 1.0), ('먹으러고', 1.0)],
#  [('박도령이라고', 1.0), ('부르자', 1.0)],
#  [('뭐가괜차낰', 1.0)],
#  [('정말재밌겠따', 1.0)],
#  [('글고', 1.0)],
#  [('양씨', 1.0)],
#  [('술', 1.0), ('1도', 1.0), ('안채해서', 1.0), ('올듯', 1.0)],
#  [('그리고', 1.0)],
#  [('정영현씨', 1.0)],
#  [('긱사애들이랑', 1.0)],
#  [('모여서먹어', 1.0)],
#  [('기숙사', 1.0), ('만들어', 1.0), ('팸', 1.0)],
#  [('음', 1.0)],
#  [('똑같음', 1.0), ('나혼자', 1.0), ('먹으란말이랑', 1.0)],
#  [('리얼', 1.0), ('긱사팸', 1.0), ('존내부럽', 1.0)],
#  [('왴', 1.0)],
#  [('술먹음서', 1.0), ('친해져부러', 1.0)],
#  [('진짜', 1.0), ('심심함', 1.0), ('흥', 1.0)],
#  [('긱사팸', 1.0), ('기회', 1.0), ('흔치않아', 1.0)],
#  [('긱사팸좋다', 1.0)],
#  [('그치', 1.0)],
#  [('서울에', 1.0), ('없으니까', 1.0), ('칭구', 1.0)],
#  [('노잼임', 1.0)],
#  [('긱사팸', 1.0)],
#  [('왱', 1.0)],
#  [('긱사팸', 1.0), ('존잼인디', 1.0)],
#  [('나두끼구파', 1.0)],
#  [('나두', 1.0)],
#  [('센빠이', 1.0), ('나도', 1.0), ('서개쫌', 1.0), ('술잘마시는', 1.0)],
#  [('노린다', 1.0), ('다음', 1.0), ('학기를', 1.0)],
#  [('가지게', 1.0), ('술친구로', 1.0)],
#  [('잘마셔', 1.0), ('주형쎈빠이', 1.0)],
#  [('안돼', 1.0)],
#  [('그이는', 1.0)],
#  [('아', 1.0), ('그분이랑', 1.0)],
#  [('갑자기', 1.0), ('이렇게', 1.0)],
#  [('먹다가는', 1.0)],
#  [('건드리지마', 1.0), ('그이를', 1.0)],
#  [('뷰른다구', 1.0)],
#  [('있씀', 1.0), ('체할슈도', 1.0)],
#  [('아진짜', 1.0)],
#  [('왴', 1.0)],
#  [('만듬', 1.0), ('불편하게', 1.0), ('사람을', 1.0)],
#  [('너무', 1.0), ('웃겨', 1.0), ('저', 1.0)],
#  [('뭐야갑자기', 1.0)],
#  [('임티자랑', 1.0)],
#  [('아종나', 1.0)],
#  [('윤지의', 1.0)],
#  [('언냐', 1.0), ('아니주현', 1.0)],
#  [('이거', 1.0), ('진현영', 1.0)],
#  [('저', 1.0)],
#  [('개약오른다', 1.0)],
#  [('인절미', 1.0)],
#  [('임티', 1.0)],
#  [('완전', 1.0)],
#  [('인절미아니야', 1.0)],
#  [('자기자신임', 1.0)],
#  [('햄토리야', 1.0)],
#  [('나라니', 1.0)],
#  [('머줌', 1.0)],
#  [('인절미임', 1.0)],
#  [('얘들아', 1.0)],
#  [('이거임', 1.0)],
#  [('누가봐도', 1.0), ('햄스터야', 1.0)],
#  [('아', 1.0)],
#  [('쩔쩔이야', 1.0)],
#  [('완전', 1.0)],
#  [('걍', 1.0), ('언니임', 1.0)],
#  [('얘두라', 1.0)],
#  [('이거', 1.0), ('기엽찌', 1.0)],
#  [('웅', 1.0)],
#  [('비숑', 1.0)],
#  [('키우고파', 1.0)],
#  [('저거', 1.0), ('헐', 1.0), ('지의야', 1.0)],
#  [('정우철이', 1.0), ('존나많이쓰는거임', 1.0)],
#  [('진현영', 1.0), ('너무', 1.0)],
#  [('미친', 1.0)],
#  [('엥', 1.0)],
#  [('아싸발', 1.0)],
#  [('존나', 1.0), ('안어울려', 1.0)],
#  [('때려야겠다', 1.0)],
#  [('왜욕하는뎈', 1.0)],
#  [('아싸발', 1.0)],
#  [('바로', 1.0), ('욕나오눈거봐', 1.0)],
#  [('겨워💕', 1.0), ('겹따', 1.0)],
#  [('강아지', 1.0), ('더사고싶따', 1.0), ('한마리', 1.0)],
#  [('뭐야저마시멜로는', 1.0)],
#  [('말티푸개기여움', 1.0)],
#  [('말티즌데요', 1.0)],
#  [('아니', 1.0)],
#  [('병신아', 1.0)],
#  [('말티즈랑', 1.0)],
#  [('푸들썪은거', 1.0)],
#  [('말티푸라하거든', 1.0)],
#  [('레알', 1.0)],
#  [('아까부터', 1.0)],
#  [('쩝', 1.0)],
#  [('내가', 1.0), ('모를꺼같나', 1.0), ('이것도', 1.0)],
#  [('마커롱', 1.0), ('오타났는데', 1.0)],
#  [('마카롱임', 1.0)],
#  [('내가', 1.0), ('5인줄알아', 1.0), ('초', 1.0)],
#  [('초5', 1.0)],
#  [('마카롱이란당', 1.0), ('액희야마커롱아니구', 1.0)],
#  [('말티푸', 1.0)],
#  [('미쳤음', 1.0), ('졸귀임', 1.0)],
#  [('헐', 1.0)],
#  [('미쳤네', 1.0)],
#  [('개깜찍', 1.0)],
#  [('갈색강아지가', 1.0), ('예쁜듯', 1.0)],
#  [('야', 1.0), ('근데', 1.0)],
#  [('많으니까', 1.0), ('모르는사람', 1.0), ('아직도', 1.0)],
#  [('티내지마라', 1.0)],
#  [('누구있씀', 1.0)],
#  [('모르는사람', 1.0)],
#  [('염기웅씨', 1.0)],
#  [('불가능', 1.0), ('나열', 1.0)],
#  [('아니', 1.0)],
#  [('염기웅씨', 1.0), ('개뜬금', 1.0)],
#  [('아님', 1.0), ('박정욱씨', 1.0)],
#  [('다알지', 1.0), ('빼곤', 1.0), ('안음', 1.0)],
#  [('에바야', 1.0)],
#  [('모르는사람', 1.0), ('많아', 1.0)],
#  [('웅', 1.0)],
#  [('눈치로', 1.0),
#   ('그냥', 1.0),
#   ('다', 1.0),
#   ('말은', 1.0),
#   ('알라그랭', 1.0),
#   ('하지말구', 1.0)],
#  [('마자', 1.0)],
#  [('진혀녕', 1.0), ('이샛기', 1.0)],
#  [('염기웅앀', 1.0)],
#  [('개뜬금', 1.0)],
#  [('염염염염염', 1.0)],
#  [('묘하게', 1.0)],
#  [('중독되는', 1.0)],
#  [('염기웅씨', 1.0)],
#  [('너', 1.0), ('언제자게', 1.0)],
#  [('더', 1.0), ('일어나야되자나', 1.0), ('일찍', 1.0), ('통학이면', 1.0)],
#  [('난', 1.0), ('공결할래유', 1.0)],
#  [('미띤', 1.0)],
#  [('난아직도', 1.0), ('폰중', 1.0)],
#  [('냠냠', 1.0)],
#  [('나도', 1.0), ('공결', 1.0)],
#  [('나', 1.0), ('잠만', 1.0), ('눈뜸', 1.0), ('지금', 1.0)],
#  [('나도공결쓸래', 1.0)],
#  [('근데', 1.0), ('c도', 1.0), ('공결내게', 1.0), ('너네', 1.0), ('파이썬이랑', 1.0)],
#  [('아오늘', 1.0), ('파이썬있구나', 1.0)],
#  [('공결이지', 1.0), ('뭐', 1.0)],
#  [('시방', 1.0)],
#  [('c', 1.0)],
#  [('는', 1.0)],
#  [('당연히', 1.0), ('씨도', 1.0)],
#  [('이제', 1.0), ('나더', 1.0), ('일어남', 1.0)],
#  [('난', 1.0), ('씨끝날때쯤', 1.0), ('학교갈거', 1.0)],
#  [('공결', 1.0), ('지이언니도', 1.0)],
#  [('웅', 1.0)],
#  [('공결낼거야', 1.0), ('파이썬도', 1.0)],
#  [('헐', 1.0)],
#  [('아니면메닐만보내', 1.0)],
#  [('파이썬은', 1.0)],
#  [('듣자', 1.0)],
#  [('지금', 1.0), ('주섬주섬', 1.0), ('준비하자', 1.0)],
#  [('음', 1.0)],
#  [('그럼', 1.0), ('공결애아깝', 1.0)],
#  [('공결내면', 1.0)],
#  [('하루종일', 1.0)],
#  [('다빠질수', 1.0)],
#  [('있는거', 1.0)],
#  [('웅다빠지기가능', 1.0)],
#  [('헐', 1.0)],
#  [('근데', 1.0), ('이주히', 1.0)],
#  [('c끗낳때', 1.0)],
#  [('왜와', 1.0), ('학겨', 1.0)],
#  [('나도', 1.0), ('문쓰발해야되긴함', 1.0)],
#  [('문쓰발이요', 1.0)],
#  [('나도', 1.0)],
#  [('현영그럼', 1.0)],
#  [('파이썬우짤꺼', 1.0)],
#  [('습', 1.0)],
#  [('아근데', 1.0), ('나', 1.0), ('기말', 1.0)],
#  [('조질라햇는디', 1.0)],
#  [('언니', 1.0), ('글고', 1.0)],
#  [('언니는', 1.0), ('파이썬들을', 1.0)],
#  [('정도는', 1.0), ('하루수업', 1.0)],
#  [('이유가', 1.0)],
#  [('잇자나', 1.0)],
#  [('독학으로', 1.0), ('커버가능', 1.0)],
#  [('엑슼', 1.0)],
#  [('독학', 1.0), ('없음', 1.0), ('의지', 1.0)],
#  [('아', 1.0), ('씨', 1.0)],
#  [('또가면', 1.0), ('수업때', 1.0), ('저번', 1.0)],
#  [('또', 1.0), ('냉고', 1.0), ('숙제', 1.0), ('안해왔다고', 1.0), ('지랄비랄하겔지', 1.0)],
#  [('걍', 1.0), ('다', 1.0), ('안갈래', 1.0)],
#  [('씨', 1.0), ('숙제있어', 1.0)],
#  [('아', 1.0), ('검사맡고가라한거', 1.0), ('저번에', 1.0)],
#  [('그럼', 1.0), ('당연히', 1.0), ('안가야지', 1.0)],
#  [('옹', 1.0)],
#  [('다들', 1.0), ('빠지는군', 1.0), ('아예통째로', 1.0)],
#  [('흠냐리', 1.0)],
#  [('좀', 1.0), ('죄책감이드는디', 1.0)],
#  [('너네가', 1.0)],
#  [('근데공결신청서', 1.0), ('언제까지내는겨', 1.0)],
#  [('10일', 1.0), ('오늘부터', 1.0), ('이내', 1.0)],
#  [('같이사는언니', 1.0)],
#  [('알람겁나울려서', 1.0)],
#  [('못자겠음', 1.0)],
#  [('하', 1.0)],
#  [('언니가', 1.0)],
#  [('꺼줘', 1.0)],
#  [('걍', 1.0), ('파이썬은', 1.0), ('갈래', 1.0)],
#  [('레알', 1.0)],
#  [('씨는안가곸', 1.0)],
#  [('엥', 1.0)],
#  [('그건뭐야', 1.0)],
#  [('시방', 1.0)],
#  [('우리과톡에', 1.0), ('잘못보냄', 1.0)],
#  [('걍', 1.0), ('공결썻는데', 1.0), ('금같은', 1.0), ('다오지마', 1.0)],
#  [('앜', 1.0)],
#  [('지금', 1.0), ('그닠가', 1.0)],
#  [('공결', 1.0), ('개아까워', 1.0)],
#  [('근데', 1.0)],
#  [('걍', 1.0), ('결석한번으로할까', 1.0), ('미적', 1.0)],
#  [('공결쓰지말고', 1.0)],
#  [('파이썬이랑', 1.0), ('c는가게', 1.0)],
#  [('아', 1.0), ('고민되는데', 1.0), ('씨는', 1.0)],
#  [('걍', 1.0), ('다', 1.0), ('가지말자', 1.0)],
#  [('다가지말쟈', 1.0)],
#  [('와', 1.0), ('날씨', 1.0), ('미친거같음', 1.0)],
#  [('갑자기', 1.0), ('우박떨어짐', 1.0)],
#  [('헐', 1.0)],
#  [('밖에', 1.0)],
#  [('웅', 1.0)],
#  [('미쳤음', 1.0)],
#  [('미친', 1.0), ('천둥번개', 1.0)],
#  [('개무서워', 1.0)],
#  [('야', 1.0)],
#  [('대박', 1.0)],
#  [('아니', 1.0), ('왜이래', 1.0), ('날씨', 1.0), ('무서워', 1.0), ('아아아아', 1.0)],
#  [('무서워', 1.0)],
#  [('무서워아아', 1.0)],
#  [('신났지', 1.0), ('차지이', 1.0)],
#  [('꼭', 1.0), ('나갈거면', 1.0), ('들구나가', 1.0), ('우산', 1.0)],
#  [('개아파', 1.0), ('우박', 1.0)],
#  [('미친', 1.0)],
#  [('언우박맞아썽', 1.0)],
#  [('웅웅', 1.0)],
#  [('그냥', 1.0),
#   ('우산', 1.0),
#   ('나갔는데', 1.0),
#   ('비오늘', 1.0),
#   ('알구', 1.0),
#   ('없어서', 1.0),
#   ('줄', 1.0)],
#  [('존나', 1.0), ('아팠어', 1.0)],
#  [('개웃겨', 1.0)],
#  [('나', 1.0), ('우박', 1.0), ('주워왔는데', 1.0)],
#  [('우박녹았어', 1.0)],
#  [('개신기해', 1.0)],
#  [('아니', 1.0), ('왜', 1.0), ('신났냐고', 1.0), ('지이언니', 1.0)],
#  [('아', 1.0), ('또', 1.0), ('천둥친다', 1.0)],
#  [('천둥미쳤다', 1.0)],
#  [('배고픈가봄', 1.0)],
#  [('와', 1.0)],
#  [('아미쳤냐고진짜', 1.0)],
#  [('여기서', 1.0), ('우오', 1.0)],
#  [('1도', 1.0), ('안둘림', 1.0), ('천둥소리', 1.0)],
#  [('집에서', 1.0)],
#  [('곳이야', 1.0), ('신기한', 1.0), ('우리집은', 1.0), ('정말', 1.0)],
#  [('헐', 1.0)],
#  [('뭔뎈', 1.0)],
#  [('진짜', 1.0), ('언니', 1.0), ('갇혀사는거아니지', 1.0)],
#  [('단절되있어', 1.0), ('세상과', 1.0)],
#  [('진짜', 1.0), ('제일', 1.0), ('언니집이', 1.0), ('위험해', 1.0)],
#  [('진짜', 1.0), ('곳이야', 1.0), ('여기', 1.0), ('잠자는데', 1.0), ('최적화된', 1.0)],
#  [('진짜', 1.0), ('밖에', 1.0), ('모르겠다', 1.0), ('핵날라와도', 1.0)],
#  [('미쳤어', 1.0), ('핵', 1.0)],
#  [('우박뭐얔', 1.0)],
#  [('랰헥', 1.0)],
#  [('도랏나진짴', 1.0)],
#  [('아니', 1.0)],
#  [('밖에', 1.0), ('나중에', 1.0), ('어케낙냐고오오', 1.0), ('천둥좀안치게해봐', 1.0)],
#  [('난', 1.0), ('우박보다', 1.0)],
#  [('c교수님이', 1.0)],
#  [('더무서움', 1.0)],
#  [('존내오늘', 1.0)],
#  [('애들왜이러케', 1.0)],
#  [('안왓냐고', 1.0)],
#  [('또', 1.0), ('지롤하는거아님', 1.0)],
#  [('설마', 1.0)],
#  [('정신이잇는거냐없는거냐', 1.0)],
#  [('무서웡', 1.0)],
#  [('지이언니', 1.0), ('c듣는중', 1.0), ('머야', 1.0)],
#  [('중이었는데', 1.0), ('포켓몬고', 1.0)],
#  [('와이파이개안잦혀', 1.0)],
#  [('아니', 1.0), ('c수업', 1.0), ('갓음', 1.0)],
#  [('문쓰발땸시', 1.0), ('학교오는길에', 1.0)],
#  [('아뭐야혼자출석하구', 1.0)],
#  [('배신자엑스', 1.0)],
#  [('어차피', 1.0)],
#  [('아니', 1.0), ('저기', 1.0)],
#  [('죄송합니다', 1.0)],
#  [('언니도', 1.0)],
#  [('문쓰발혀', 1.0)],
#  [('웅', 1.0)],
#  [('내일발표야슈발', 1.0)],
#  [('대본도없는데', 1.0)],
#  [('다', 1.0), ('패고싶다', 1.0)],
#  [('zzzzz우리도지금', 1.0)],
#  [('백지상태임', 1.0)],
#  [('오늘시작', 1.0)],
#  [('그니깐', 1.0), ('우리도', 1.0), ('지금시작', 1.0)],
#  [('난', 1.0), ('몰빵에서', 1.0), ('문쓰발', 1.0), ('센이랑', 1.0), ('하러공', 1.0)],
#  [('우리도', 1.0), ('백지', 1.0)],
#  [('같이', 1.0), ('나방금', 1.0), ('들었느데', 1.0), ('사는', 1.0), ('언니한테', 1.0)],
#  [('그거', 1.0), ('무시하고', 1.0), ('술팔지말라는', 1.0), ('인하대에서', 1.0)],
#  [('그냥', 1.0), ('했다가', 1.0)],
#  [('3000만원인가', 1.0),
#   ('5년이랑', 1.0),
#   ('막', 1.0),
#   ('먹었대', 1.0),
#   ('벌금', 1.0),
#   ('인하대', 1.0),
#   ('징역', 1.0),
#   ('회장', 1.0)],
#  [('다', 1.0),
#   ('다른대학교들도', 1.0),
#   ('미쳐따', 1.0),
#   ('아예', 1.0),
#   ('안한대', 1.0),
#   ('주점', 1.0)],
#  [('홀', 1.0)],
#  [('미친거아냐', 1.0)],
#  [('징역', 1.0)],
#  [('헐', 1.0)],
#  [('술을', 1.0), ('안팔다니', 1.0)],
#  [('너네어떠조싶음', 1.0)],
#  [('주점', 1.0)],
#  [('안하고싶은데난', 1.0)],
#  [('흠', 1.0)],
#  [('난쉽게결정못하게써', 1.0)],
#  [('장사안될거같음', 1.0), ('저러면', 1.0)],
#  [('열정페이야', 1.0)],
#  [('적자에바야', 1.0)],
#  [('그건맞아또', 1.0)],
#  [('술', 1.0), ('된다고', 1.0), ('먹는건', 1.0), ('사와서', 1.0), ('하지만', 1.0)],
#  [('내년에', 1.0), ('할수도있고', 1.0)],
#  [('굳이', 1.0)],
#  [('맞아', 1.0)],
#  [('앗', 1.0), ('잠시', 1.0)],
#  [('나', 1.0), ('물리', 1.0), ('출튀', 1.0), ('할꺼얌', 1.0)],
#  [('앗', 1.0), ('선수치기냐', 1.0)],
#  [('나도', 1.0), ('고민중', 1.0)],
#  [('난', 1.0), ('이미', 1.0)],
#  [('물리출튀하고주현', 1.0), ('언니집가고싶다', 1.0)],
#  [('누워있씀', 1.0), ('아직', 1.0)],
#  [('걍나거소', 1.0),
#   ('다시', 1.0),
#   ('들와소', 1.0),
#   ('이상태로', 1.0),
#   ('잘꼬임', 1.0),
#   ('출석하고', 1.0)],
#  [('정말', 1.0), ('멋지다', 1.0)],
#  [('아나지금지하철탐', 1.0)],
#  [('늦을까', 1.0)],
#  [('니가', 1.0), ('알잖어', 1.0)],
#  [('얼마나걸림', 1.0)],
#  [('나도', 1.0), ('출튀', 1.0)],
#  [('아나11시에', 1.0), ('지하철에서내릴거같은디', 1.0)],
#  [('샹', 1.0)],
#  [('아직', 1.0), ('지하철', 1.0)],
#  [('지금', 1.0), ('군자임', 1.0), ('쉬부랭', 1.0)],
#  [('아', 1.0), ('쉬팽', 1.0), ('준내뛰어가서', 1.0), ('출튀해야겟다', 1.0)],
#  [('오분까지하묜됨', 1.0)],
#  [('오늘부터', 1.0), ('출석부른대', 1.0)],
#  [('헐', 1.0)],
#  [('에반데', 1.0)],
#  [('20분까지', 1.0), ('들어와', 1.0)],
#  [('진심', 1.0)],
#  [('오바야', 1.0)],
#  [('웅', 1.0), ('진짜야', 1.0)],
#  [('20분까지', 1.0), ('봐주면', 1.0)],
#  [('아니', 1.0)],
#  [('들엉면', 1.0)],
#  [('방금', 1.0), ('교수님이', 1.0), ('글케말했어', 1.0)],
#  [('봐준데', 1.0)],
#  [('웅웅', 1.0)],
#  [('띠로리', 1.0)],
#  [('아니', 1.0)],
#  [('근데', 1.0), ('지금', 1.0)],
#  [('걍', 1.0), ('아니냐', 1.0), ('찍히는거', 1.0)],
#  [('니깐', 1.0)],
#  [('그니깐', 1.0)],
#  [('걍', 1.0), ('들어가는거잖아', 1.0), ('얼굴', 1.0), ('찍히고', 1.0)],
#  [('근데', 1.0), ('1번인데', 1.0), ('결석', 1.0)],
#  [('1번은', 1.0)],
#  [('괜찮지않을까', 1.0)],
#  [('출석불렀씀', 1.0)],
#  [('20분에', 1.0), ('부른대', 1.0)],
#  [('씨발', 1.0)],
#  [('같네', 1.0)],
#  [('짐다시가는겔', 1.0)],
#  [('엥', 1.0)],
#  [('결석', 1.0), ('1번', 1.0)],
#  [('크게', 1.0), ('상관없지않냐', 1.0)],
#  [('짐출석부름', 1.0)],
#  [('왔는데', 1.0)],
#  [('출석안부름', 1.0)],
#  [('뭐임', 1.0)],
#  [('걍헌말인가', 1.0)],
#  [('아님', 1.0), ('마칠때하는가', 1.0)],
#  [('짐부름', 1.0)],
#  [('후', 1.0)],
#  [('언니도', 1.0), ('출튀함', 1.0)],
#  [('옹옹', 1.0)],
#  [('다들오댱', 1.0)],
#  [('쓰는사람없지', 1.0), ('아이폰6', 1.0), ('요기', 1.0), ('케이스', 1.0)],
#  [('나', 1.0)],
#  [('헐', 1.0), ('진자', 1.0)],
#  [('아니', 1.0), ('나', 1.0), ('언니', 1.0), ('오늘', 1.0), ('폰바꿨거든', 1.0)],
#  [('근데', 1.0), ('아이폰6', 1.0), ('케이스', 1.0), ('3개나', 1.0), ('주문시켰따고', 1.0)],
#  [('언니', 1.0),
#   ('나한테', 1.0),
#   ('말해조', 1.0),
#   ('살', 1.0),
#   ('의향있으면', 1.0),
#   ('혹시', 1.0)],
#  [('어떤건뎅', 1.0)],
#  [('나', 1.0), ('케이스', 1.0), ('많아져서', 1.0)],
#  [('구래', 1.0)],
#  [('잠만', 1.0), ('보여주께', 1.0)],
#  [('웅웅', 1.0)],
#  [('근데취소해도', 1.0)],
#  [('되지않아', 1.0)],
#  [('거의', 1.0), ('이미', 1.0), ('다', 1.0), ('도착', 1.0), ('해외배송이라', 1.0)],
#  [('나', 1.0),
#   ('이제', 1.0),
#   ('너무바빠쪄', 1.0),
#   ('봤당', 1.0),
#   ('앉아서', 1.0),
#   ('자리에', 1.0)],
#  [('오', 1.0), ('개이뻐', 1.0), ('채도', 1.0), ('첫번째꺼', 1.0)],
#  [('다', 1.0),
#   ('음', 1.0),
#   ('6쓰는애들한테도', 1.0),
#   ('물어봥', 1.0),
#   ('일단', 1.0),
#   ('헤', 1.0)],
#  [('모야', 1.0), ('바꿨는데', 1.0), ('자랑안하는건', 1.0), ('폰뭘로바꿈', 1.0)],
#  [('오오오옹', 1.0)],
#  [('바꿨더', 1.0), ('아이폰x로', 1.0)],
#  [('155만원', 1.0)],
#  [('미친', 1.0)],
#  [('개쩌러', 1.0)],
#  [('진짜', 1.0), ('155', 1.0), ('개쩜', 1.0)],
#  [('결국', 1.0), ('마쟠', 1.0), ('성공했어', 1.0)],
#  [('성공', 1.0), ('와앙', 1.0)],
#  [('수업', 1.0)],
#  [('안듣는애없어', 1.0)],
#  [('다', 1.0), ('앉아있어', 1.0), ('언니빼고', 1.0)],
#  [('못들어가', 1.0), ('이꼬라지로', 1.0)],
#  [('이거', 1.0), ('나', 1.0), ('뛰유왔더라', 1.0), ('목에끼우고', 1.0)],
#  [('시밤', 1.0)],
#  [('아', 1.0)],
#  [('개웃겨', 1.0)],
#  [('아', 1.0)],
#  [('현타오어', 1.0)],
#  [('아', 1.0), ('같애', 1.0), ('개쪽팔릴', 1.0), ('것', 1.0)],
#  [('그래서', 1.0), ('아예', 1.0), ('안니', 1.0), ('안들어오겡', 1.0)],
#  [('언니', 1.0), ('어디야', 1.0)],
#  [('나', 1.0), ('수업중인데', 1.0)],
#  [('존나', 1.0), ('들을', 1.0), ('필요없는득', 1.0)],
#  [('나', 1.0)],
#  [('밥먹고있었어', 1.0)],
#  [('어때어때', 1.0)],
#  [('과팅어때', 1.0)],
#  [('핫하냐', 1.0)],
#  [('재밌냐', 1.0)],
#  [('아', 1.0),
#   ('한명', 1.0),
#   ('개', 1.0),
#   ('꼴아서', 1.0),
#   ('보내야돼', 1.0),
#   ('집', 1.0)],
#  [('누구', 1.0)],
#  [('윤지의', 1.0), ('합류함', 1.0)],
#  [('아직', 1.0)],
#  [('김유현', 1.0)],
#  [('꼴아서', 1.0), ('집', 1.0), ('보냈어', 1.0), ('진현영도개', 1.0)],
#  [('미친', 1.0)],
#  [('현영이', 1.0), ('빠꾸없쥬', 1.0)],
#  [('보냈어', 1.0)],
#  [('지이언니', 1.0)],
#  [('어댜', 1.0)],
#  [('나집이야', 1.0)],
#  [('많이마신거야', 1.0), ('얼마나', 1.0)],
#  [('나', 1.0), ('누웠써', 1.0), ('씻고', 1.0), ('집도착해서', 1.0)],
#  [('잘해써', 1.0)],
#  [('나', 1.0),
#   ('오늘', 1.0),
#   ('결석', 1.0),
#   ('괜찮겠지', 1.0),
#   ('안갈레', 1.0),
#   ('한번하는거', 1.0)],
#  [('비에바쎄바', 1.0)],
#  [('난', 1.0), ('진심', 1.0), ('안가고싶다', 1.0)],
#  [('와', 1.0), ('많이', 1.0), ('비', 1.0)],
#  [('천둥소리', 1.0), ('들은것같기도하고', 1.0), ('새벽에', 1.0)],
#  [('지금은', 1.0)],
#  [('콧물정도밖에안옴', 1.0)],
#  [('근데즈금은', 1.0), ('많이옴', 1.0), ('엇', 1.0)],
#  [('난공걀', 1.0)],
#  [('씁니다', 1.0)],
#  [('미틴', 1.0)],
#  [('개꿀', 1.0)],
#  [('그래서', 1.0)],
#  [('아무도', 1.0), ('안오는거', 1.0)],
#  [('뭐야', 1.0)],
#  [('나만', 1.0)],
#  [('나만옴', 1.0)],
#  [('1분전에', 1.0), ('도착함', 1.0), ('존나뛰어', 1.0)],
#  [('나', 1.0), ('은비릉', 1.0)],
#  [('출튀함', 1.0)],
#  [('잘했어👍', 1.0)],
#  [('헐', 1.0)],
#  [('나', 1.0), ('이제', 1.0), ('일님', 1.0)],
#  [('파이썬도안오냥', 1.0)],
#  [('나', 1.0), ('지각해서', 1.0)],
#  [('눈치보여', 1.0)],
#  [('관성모멘트', 1.0), ('어케', 1.0), ('표', 1.0), ('해', 1.0)],
#  [('걍', 1.0), ('배끼면된댕', 1.0), ('인터넷검색해서', 1.0)],
#  [('아씨', 1.0)],
#  [('어떠케', 1.0)],
#  [('이제', 1.0), ('감', 1.0)],
#  [('미팅', 1.0), ('나갈사람', 1.0)],
#  [('선착한명', 1.0)],
#  ...]

# %% [markdown]
# ##### Run DTM model

# %%
# take a long time to run....
NUM_TOPICS = 4

if not os.path.exists('kakao(DTM)_model'):
    dtm_model = ldaseqmodel.LdaSeqModel(corpus=corpus, id2word=dictionary, time_slice=time_slice, num_topics=NUM_TOPICS, passes=10)
    dtm_model.save('kakao(DTM)_model')
else:
    dtm_model = ldaseqmodel.LdaSeqModel.load('kakao(DTM)_model')

# %% [markdown]
# ##### DTM 결과 보기

# %%
# 고정된 시간 내에서 전체 토픽보기
pprint(dtm_model.print_topics(time=1, top_terms=20))
# Out:
# [[('굿', 0.05831850538739241),
#   ('지금', 0.012331524778776757),
#   ('오', 0.0122166677634343),
#   ('역시', 0.010455539788893783),
#   ('내일', 0.009190718899343277),
#   ('이미', 0.008990207437333388),
#   ('왜', 0.007369435495622992),
#   ('낼', 0.005757033715288104),
#   ('야', 0.0051241059091660665),
#   ('아직', 0.004872538898427595),
#   ('시발', 0.0045842544466057865),
#   ('그래도', 0.004528226788699147),
#   ('사실', 0.004487026774860223),
#   ('없음', 0.004297307967381041),
#   ('하고', 0.004058918940601231),
#   ('아니면', 0.0035801679800862318),
#   ('가서', 0.0035703666039212257),
#   ('빨리', 0.0035260000564760795),
#   ('많이', 0.0034673740267698538),
#   ('대단', 0.00334297411317377)],
#  [('핳', 0.03620256743725127),
#   ('그럼', 0.017891407390810514),
#   ('나', 0.014458865122934468),
#   ('나도', 0.01339997787202228),
#   ('걍', 0.012045925968074068),
#   ('닥쳐', 0.011429731540920987),
#   ('나는', 0.009952254204843707),
#   ('핳핳', 0.009887808067018595),
#   ('뭐', 0.009682205321122319),
#   ('Search', 0.008825802051635289),
#   ('그래서', 0.007265567687011695),
#   ('후발', 0.0068387612725614244),
#   ('내', 0.006383795862432469),
#   ('그리고', 0.006351899338992419),
#   ('진짜', 0.0062014045135153585),
#   ('아니', 0.00604695376641414),
#   ('잘', 0.005900756118075859),
#   ('크으', 0.005194940235300809),
#   ('너', 0.004864045969963449),
#   ('함', 0.004793643801386372)],
#  [('아', 0.02210906965432367),
#   ('난', 0.011473428499934674),
#   ('음', 0.009178877503758395),
#   ('오늘', 0.008736621924946206),
#   ('일단', 0.007706724944217089),
#   ('다', 0.006729730613141478),
#   ('그냥', 0.006459893475380204),
#   ('솬', 0.004414683249180747),
#   ('흑', 0.00408539709200058),
#   ('너무', 0.003937975344398072),
#   ('같이', 0.0037365248161865153),
#   ('허허', 0.0036740927003780627),
#   ('오우', 0.003483779885298326),
#   ('흠', 0.0033674235569012057),
#   ('근데', 0.003344358260462343),
#   ('굿굿', 0.0033149649095804046),
#   ('좋음', 0.003197934478767247),
#   ('그건', 0.0029053469126389467),
#   ('이런', 0.0026881759140208205),
#   ('거의', 0.0023439212014939)],
#  [('프로도', 0.018715752188847568),
#   ('근데', 0.017351680689982794),
#   ('내가', 0.014828991758476632),
#   ('굳', 0.013596512561108486),
#   ('라이언', 0.0134231446121883),
#   ('이제', 0.012495109540412786),
#   ('어피치', 0.010511910116544046),
#   ('좀', 0.010166326283997454),
#   ('아님', 0.009585254109186344),
#   ('더', 0.008658745448605341),
#   ('그', 0.008527288812479059),
#   ('프로도이', 0.008255354588451),
#   ('넌', 0.007392724060415909),
#   ('임마', 0.006608181376941),
#   ('당연', 0.005890885468216906),
#   ('튜브', 0.005826004549928224),
#   ('와', 0.00569459304886482),
#   ('그거', 0.005169688398500956),
#   ('어제', 0.005129446879545085),
#   ('가능', 0.004980891569327191)]]

# %%
# 고정된 토픽 내에서 전체 시간 변화 보기
dtm_model.print_topic_times(topic=0, top_terms=20)
# Out:
# [[('굿', 0.05805158291676767),
#   ('오', 0.01257289751420625),
#   ('지금', 0.012317538191021923),
#   ('역시', 0.010446017713230754),
#   ('내일', 0.009090115508344862),
#   ('이미', 0.008981907367809726),
#   ('왜', 0.007362543829053719),
#   ('낼', 0.0057151185377723015),
#   ('야', 0.00514056792096524),
#   ('아직', 0.004834757285897352),
#   ('그래도', 0.004495242502305918),
#   ('사실', 0.0044546150915943895),
#   ('시발', 0.004425428506800929),
#   ('없음', 0.004283082178656709),
#   ('하고', 0.004040773275026179),
#   ('대단', 0.0036382537564949753),
#   ('빨리', 0.0035261972049233747),
#   ('가서', 0.0035020169139750867),
#   ('아니면', 0.0034876003188684113),
#   ('많이', 0.0034321705608634854)],
#  [('굿', 0.05831850538739241),
#   ('지금', 0.012331524778776757),
#   ('오', 0.0122166677634343),
#   ('역시', 0.010455539788893783),
#   ('내일', 0.009190718899343277),
#   ('이미', 0.008990207437333388),
#   ('왜', 0.007369435495622992),
#   ('낼', 0.005757033715288104),
#   ('야', 0.0051241059091660665),
#   ('아직', 0.004872538898427595),
#   ('시발', 0.0045842544466057865),
#   ('그래도', 0.004528226788699147),
#   ('사실', 0.004487026774860223),
#   ('없음', 0.004297307967381041),
#   ('하고', 0.004058918940601231),
#   ('아니면', 0.0035801679800862318),
#   ('가서', 0.0035703666039212257),
#   ('빨리', 0.0035260000564760795),
#   ('많이', 0.0034673740267698538),
#   ('대단', 0.00334297411317377)],
#  [('굿', 0.058458999896171225),
#   ('오', 0.01318768938720217),
#   ('지금', 0.012345509924141036),
#   ('역시', 0.010457226020679571),
#   ('내일', 0.00927301739119372),
#   ('이미', 0.008999566965103203),
#   ('왜', 0.007372318976450338),
#   ('낼', 0.005785046257038047),
#   ('야', 0.005102907486786641),
#   ('아직', 0.004895851667518349),
#   ('시발', 0.004636047295420518),
#   ('그래도', 0.004554571665843807),
#   ('사실', 0.004535471790038705),
#   ('없음', 0.00430242468998406),
#   ('하고', 0.0040695165053754616),
#   ('아니면', 0.0035407089883771397),
#   ('많이', 0.003529708851698141),
#   ('빨리', 0.0035274244976466356),
#   ('가서', 0.0033965644586508477),
#   ('대단', 0.0031908079602517704)]]

# %% [markdown]
# ### 4. coherence score 계산 함수 만들기

# %% [markdown]
# #### topic 개수 지정하기.

# %%
start=4; end=9; step=1; # 4,5,6,7,8개의 토픽 개수 보고자하는 것
times=[0, 1, 2] # timeslice가 3개니까

# %% [markdown]
# #### DTM과 coherence score 계산하는 함수

# %%
# 함수 작성.

# coherence score는 LDA 별로 계산됨
# LDA가 어떻게 있냐, 지금 DTM 1개인데 DTM 안에 LDA 3개 -> 토픽 개수만큼 있음
# 따라서 총 15개 (토픽 개수 5개 x LDA 3개)

def compute_coherence(dictionary, corpus, texts, times, start, end, step):
# 파라미터 : 토픽개수만큼 DTM 돌려야하니까 DTM에 들어있는 파라미터 모두 필요, 걔네들을 매번 time에 따라 계산해줘야하는
    model_list = [] # 토픽 개수 넣는 것에 따라 모델을 다 만들어야하니까 저장할 리스트
    coherence_score_list = []
    
    for num_topics in tqdm_notebook(range(start, end, step)):
        start_dtm = time() # 시작시간
        
        # DTM은 모델 하나하나 돌리는 데 시간이 아주 오래 걸려
        # 따라서 토픽을 줄 때마다 하나하나 저장하기 위한 규칙
        dtm_name = "kakao_dtm_model_" + str(num_topics)
        if os.path.exists(dtm_name):
            dtm_model = ldaseqmodel.LdaSeqModel.load(dtm_name)
        else: # 없으면 학습시켜줌
            dtm_model = ldaseqmodel.LdaSeqModel(corpus=corpus,
                                               id2word=dictionary,
                                               time_slice=times,
                                               num_topics=num_topics,
                                               passes=100) # 원래는 1000번 정도(하지만 어어어엄청 오래 걸리겠지)
            dtm_model.save(dtm_name)
        
        end_dtm = time()
        print('Elapsed Time for DTM in %d topics : %.2f sec' % (num_topics, (end_dtm - start_dtm)))
        
        topics_cs_list = []
        for time_slot in times: # 시간대 별 계신
            topics_dtm = dtm_model.dtm_coherence(time=time)
            cs = CoherenceModel(topics=topics_dtm, texts=texts, dictionary=dictionary, coherence='c_v')
            # texts는 tokenized된 토픽 모델링의 input으로 들어갔던 text임
            topic_cs_list.append(cs) #DTM 안의 토픽 개수 별 LDA 3개가 계산된 거 저장
        
        model_list.append(dtm_model)
        coherence_score_list.append(topic_cs_list)
        
        return model_list, coherence_score_list
    
# LDA 하나에 대해 coherence score가 계산됨 (LDA가 3개씩 있으니까 3개씩 5개 나옴)

# %%
# 함수 실행.
model_list, coherence_scores = compute_coherence(dictionaray=dictionary,
                                                corpus=corpus,
                                                texts=tokenized_data,
                                                times=times,
                                                start=start, end=end, step=step)

# %% [markdown]
# ##### 위 계산 결과 통째로 저장

# %%
import pickle

with open("kakao_dtm_models.pk", 'wb') as f:
    pickle.dump(model_list, f)
    
with open("kakao_dtm_cs.pk", 'wb') as f:
    pickle.dump(coherence_scores, f)

# %%
import pickle

with open("kakao_dtm_models.pk", 'rb') as f:
    model_list = pickle.load(f)
    
with open("kakao_dtm_cs.pk", 'rb') as f:
    coherence_scores = pickle.load(f)

# %% [markdown]
# ### 5. Topic Coherence 변화 그래프 그리기

# %% [markdown]
# - Topic Coherence score를 왜 계산했었냐면, 우리가 원하는 건 best topic을 모르니까 (k를 모르니까) 4,5,6,7,8 중 좋은걸 고르려고
# - topic 개수가 늘어나면 걸리는 시간도 조금씩 늘어남

# %%
print(model_list, coherence_scores)

# %%
pprint(coherence_scores)

# %%
# 편한 연산을 위해 numpy array로 변경.
import numpy as np

# DTM 하나에 LDA마다 나온 거니까 평균을 때릴거야
# DTM 하나에 coherence score를 하나씩 주는거야
# topic best를 고르기 위해 이것들중 하나를 골라야하니까!
np_coherence_scores = np.array(coherence_scores)
np_cs_avg_list = np_coherence_scores.mean(axis=1) # 행 별로 평균내줘
print(np_cs_avg_list) # 5개 나옴

# %%
# 그래프 출력을 위한 한글 글꼴 설정.

import matplotlib.pyplot as plt
import platform
from matplotlib import font_manager, rc
# %matplotlib inline

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
# 그래프 그리기
x = range(start, end, step)

plt.figure(figsize=(12, 10)) 
plt.plot(x, np_cs_avg_list, '-b')
plt.xlabel("토픽 수")
plt.ylabel("평균 일관성 점수 (avg of coherence score)")
plt.xticks(x)
plt.show()

# %% [markdown]
# ##### 위에서 구한 일관성 점수 기준으로 최적 토픽 모델 결정

# %%
# 최적 토픽 모델을 dtm_model로 할당
dtm_model = model_list[np.argmax(np_cs_avg_list)] #best coherence score를 가지는 model
# np.argmax() : numpy array 중에서 max값을 가지고있는 index를 뽑아줌
dtm_model.num_topics # 그래프에서 나온 best coherence score를 가지는 토픽 수가 제대로 나오는지 확인

# %% [markdown]
# ##### DTM 결과 보기

# %%
# 고정된 시간 내에서 전체 토픽보기
pprint(dtm_model.print_topics(time=1, top_terms=20))

# %%
# 고정된 토픽 내에서 전체 시간 변화 보기
dtm_model.print_topic_times(topic=0, top_terms=20)

# %% [markdown]
# ### 6. 문서별 토픽 비중 구하기

# %% [markdown]
# - 전체 data 중에서 이 토픽이 얼마나 중요, 전체 topic 중 얼마를 차지하냐
# - 어떤 문서가 어떤 topic인지 다 계산해주고, 계산된 결과를 가지고 비중을 계산
#
# > 1) 토픽 비중 계산을 위한 데이터 전처리
#
# > 2) OOM 문제 해결을 위한 샘플링
#
# > 3) DataFrame으로 만들어 excel 파일로 저장

# %%
# 문서별 시간 정보 추가.

# dtm에서 토픽이 변하는 걸 보고싶은거지 그래서 문서별로 시간 정보가 들어가야돼
# 그래야 시간대 별로 잡아서 계산해서 토픽 비중 구할 수 있으니까
doc_time = []
for doc_id in range(len(tokenized_data)):
    if doc_id < time_slice[0]: # 2018년도 데이터라는 것
        doc_time.append(0) # time_slice를 넣어주는거지
    elif doc_id < time_slice[0] + time_slice[1]: # time_slice[0] < doc_id < time_slice[1]
        doc_time.append(1)
    else:
        doc_time.append(2)
        
print(len(doc_time)) # data 개수만큼 나오면 잘 된 것
# Out:
# 22914

# %%
# time_slot 별로 1000개씩만 뽑기.
# 원래는 비율대로 sampling 뽑는게 좋지만 편의상 time_slice별로 1000개씩 뽑음
sample_idx1 = np.random.randint(0, time_slice[0], size=1000)
sample_idx2 = np.random.randint(time_slice[0], time_slice[0] + time_slice[1], size=1000)
sample_idx3 = np.random.randint(time_slice[0] + time_slice[1], time_slice[0] + time_slice[1] + time_slice[2],
                                size=1000)

print(sample_idx1[:10])
print(sample_idx2[:10])
print(sample_idx3[-10:])
# Out:
# [5871 5260 5486 3436 4989 4514 1831 3718 3527 4733]
# [17744 13312  9003 12080 16970  9118 10432 18792  7238  9906]
# [21763 22126 20013 20030 21825 21419 21617 21620 20938 22833]

# %%
# OOM(Out-of-Memory) 문제로 인해 1000개씩 샘플링 하여 실행.

processing_docs = []
processing_time = []

sample_indices = np.concatenate((sample_idx1, sample_idx2, sample_idx3))
# concatenate : 옆으로 붙여줌

for idx in sample_indices:
    processing_docs.append(tokenized_data[idx])
    processing_time.append(doc_time[idx])
    
print(len(processing_docs))
print(len(processing_time))
# Out:
# 3000
# 3000

# %%
# 문서별로 각 토픽에 속할 확률값을 계산.

# 비중 계산 어떻게? -> 문서를 DTM 모델에 넣어서 "이거 몇번 토픽이야?" 이거를 뽑아주고 다 누적해서 계산하면 돼
doc_dist = [] # 누적해서 모아주는 애
for doc_id in sample_indices:
    doc_list.append(dtm_model.doc_topics(doc_id)) # dtm_model.doc_topics() : doc_id 넣어주면 얘가 어떤 topic에 들어갈건지 정보가 나옴
    
doc_dist[:10] # 확률값이 쭉 나올 것임

# %%
# 원하는 형태의 DataFrame으로 바꿔주기 위한 전처리.

doc_dist = np.array(doc_dist)
doc_topic_dist =doc_dist.T
doc_topic_dist.shape

# %%
# 데이터값 확인.

NUM_TOPICS = dtm_model.num_topics

for i in range(NUM_TOPICS):
    print("%f" % doc_dist[0][i], end=", ")

print()

for i in range(NUM_TOPICS):
    print("%f" % doc_topic_dist[i][0], end=", ")

# %%
doc_topic_dist[0].shape

# %%
# DataFrame으로 만들고, excel파일로 저장.

dtm_df = pd.DataFrame({"Time" : processing_time, "Topic0" : doc_topic_dist[0], "Topic1" : doc_topic_dist[1],
                      "Topic2" : doc_topic_dist[2], "Topic3" : doc_topic_dist[3], "Topic4" : doc_topic_dist[4],
                       "Topic5" : doc_topic_dist[5], "Topic6" : doc_topic_dist[6], "Topic7" : doc_topic_dist[7]
                      })

print(dtm_df.head())
dtm_df.to_excel("kakao_dtm_8topic_dist.xlsx")

# %% [markdown]
# ### 7. 시간별 토픽비중 변화 추이

# %% [markdown]
# > 1) 토픽 비중 변화를 보기 위한 데이터 전처리
#
# > 2) 시간대별 토픽 비중 평균 계산

# %% [markdown]
# ##### timeslot별로 평균 구하기

# %%
# groupby 오브젝트 생성하기
doctopic_timeslot = dtm_df.groupby('Time')
doctopc_timeslot.groups
# 1000개씩 0,1,2 나오겠지

# %%
# mean() 함수 이용해서 Topic0~TopicN까지의 모든 열 평균 구하기
timeslot_avg = doctopic_timeslot.mean() # 시간대별 토픽비중 보고싶어서 평균!
timeslot_avg = timeslot_avg.reset_index()
timeslot_avg

# %%
# 시기별 모든 토픽 값들의 합은 1이다.
timeslot_avg.sum(axis=1) # 행 별로

# %% [markdown]
# ### 8. 6~7번 결과로 그래프 그리기

# %% [markdown]
# #### 시간별 토픽 비중변화 추이

# %%
# figure 하나당 4개씩 그래프 그리기

plt.figure()
plt.figure(figsize=(16, 12)) 
plt.plot(timeslot_avg['Time'], timeslot_avg['Topic0'], 'b*--', label='토픽0')
plt.plot(timeslot_avg['Time'], timeslot_avg['Topic1'], 'rs--', label='토픽1')
plt.plot(timeslot_avg['Time'], timeslot_avg['Topic2'], 'g^--', label='토픽2')
plt.plot(timeslot_avg['Time'], timeslot_avg['Topic3'], 'y--', label='토픽3')
plt.plot(timeslot_avg['Time'], timeslot_avg['Topic3'], 'p--', label='토픽4')
plt.plot(timeslot_avg['Time'], timeslot_avg['Topic3'], 'm--', label='토픽5')
plt.plot(timeslot_avg['Time'], timeslot_avg['Topic3'], 'k--', label='토픽6')
plt.plot(timeslot_avg['Time'], timeslot_avg['Topic3'], 'c--', label='토픽7')

#그래프에서 값 표시하는 annotate 방법 찾기
# 토픽들 결과를 그래프 위에 찍어주려고
for topic_id in ['Topic0', 'Topic1', 'Topic2', 'Topic3']:
    for x, y in zip(range(len(time_slice)), timeslot_avg[topic_id]):
        plt.annotate("%.4f"%y, (x, y), textcoords="offset points", xytext=(0,10), ha='center')

plt.title("8개의 대화 토픽", fontsize=14)
plt.xlabel("대화 시기", fontsize=13)
plt.ylabel("토픽의 비중 (%)", fontsize=13)
plt.xticks(timeslot_avg['Time'], ['2017년', '2018년', '2019년'])
plt.ylim([0.08, 0.15])
plt.legend(loc="best")
plt.savefig("kakao_topic_distribution_graph.png")
plt.show()

# %% [markdown]
# #### 시간별 단어의 토픽 비중변화 추이

# %%
from collections import defaultdict
# 단어의 확률 변화를 보고 싶은 topic 번호 

topic_id = 7 # 내가 보고싶은 topic 번호 정해줘

# 해당 토픽에서 포함할 단어목록 결정
topic_info = dtm_model.print_topic_times(topic=topic_id, top_terms=)
topic_dict = defaultdict(list)

#time별 특정 topic(topic_id)의 단어별 확률값.
for dist_inTime in topic_info:
    #time별로 단어와 확률값 저장.
    for word, prob in dist_inTime:
        topic_dict[word].append(prob)

# %%
print(topic_dict)

# %%
# 확률값 추이를 보고싶은 단어 목록
# 위에서 정해준 topic 번호에 대해서 그 단어의 확률값 추이를 나타내는 거임!!
keywords = ["야", "헐"] # 7번 topic에서의 "야", "헐" 단어의 확률값 추이

# time_slot
t = [i for i in range(len(time_slice))]

plt.figure(figsize=(16, 12))
for keyword in keywords:
    plt.plot(t, topic_dict[keyword], label=keyword)
    
    for x, y in zip(t, topic_dict[keyword]):
         plt.annotate("%.4f"%y, (x, y), textcoords="offset points", xytext=(0,10), ha='center')

plt.title("시간별 단어의 토픽비중 변화")
plt.xlabel("시간")
plt.ylabel("토픽 비중")
plt.legend(loc='best')
plt.savefig("dtm_kakao_topic_words-dist_overtime.png")
plt.show()
